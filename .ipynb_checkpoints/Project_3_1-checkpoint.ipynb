# %%
# Import dependent libraries
# JSON to interpret the API's response
# Requests to send GET requests to server
# Pandas to clean & analyze raw data

import json
import requests
import pandas as pd
import numpy as np
import time
pd.set_option("max_rows", None)
pd.set_option("max_columns", None)

# Credentials necessary to access API

headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "063a86c9f9ff41c06288c479fae7e244"
    }

# utilize season year and league id to request data

train_year_one = [2015]
train_year_two = [2016]
train_year_three = [2017]
train_year_four = [2018]
test_years = [2019]
current_year = 2020

epl_id = 39
la_liga_id = 140
serie_a_id = 135

league_id = epl_id

# %%
request_test = requests.get('https://v3.football.api-sports.io/fixtures?season=2016&league=39&team=33', headers=headers)

# %%
request_test.json()['response'][-1]
# Out:
# {'fixture': {'id': 17689,
#   'referee': 'Andre Marriner, England',
#   'timezone': 'UTC',
#   'date': '2016-08-14T12:30:00+00:00',
#   'timestamp': 1471177800,
#   'periods': {'first': 1471177800, 'second': 1471181400},
#   'venue': {'id': None, 'name': 'Vitality Stadium', 'city': 'Bournemouth'},
#   'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#  'league': {'id': 39,
#   'name': 'Premier League',
#   'country': 'England',
#   'logo': 'https://media.api-sports.io/football/leagues/39.png',
#   'flag': 'https://media.api-sports.io/flags/gb.svg',
#   'season': 2016,
#   'round': 'Regular Season - 1'},
#  'teams': {'home': {'id': 35,
#    'name': 'Bournemouth',
#    'logo': 'https://media.api-sports.io/football/teams/35.png',
#    'winner': False},
#   'away': {'id': 33,
#    'name': 'Manchester United',
#    'logo': 'https://media.api-sports.io/football/teams/33.png',
#    'winner': True}},
#  'goals': {'home': 1, 'away': 3},
#  'score': {'halftime': {'home': 0, 'away': 1},
#   'fulltime': {'home': 1, 'away': 3},
#   'extratime': {'home': None, 'away': None},
#   'penalty': {'home': None, 'away': None}}}

# %%
data = []

for i in train_year_one:
    
    team_request = requests.get(f"https://v3.football.api-sports.io/teams?league={league_id}&season={i}", headers=headers)
    team_request_responses = team_request.json()['results']
    team_ids = []
    
    for x in range(team_request_responses):
        
        team_ids.append(team_request.json()['response'][x]['team']['id'])
        
    for y in team_ids:
        
        fixtures_request = requests.get(f"https://v3.football.api-sports.io/fixtures?season={i}&team={y}&league={league_id}", headers=headers)
        
        time.sleep(0.03)
        
        fixtures_request_responses = fixtures_request.json()['results']
        
        for z in range(1, fixtures_request_responses):
            
            if fixtures_request.json()['response'][z]['teams']['home']['id'] == y:
                
                opp_id = fixtures_request.json()['response'][z]['teams']['away']['id']
                
            else:
                
                opp_id = fixtures_request.json()['response'][z]['teams']['home']['id']
            
            opp_fixtures_request = requests.get(f'https://v3.football.api-sports.io/fixtures?season={i}&team={opp_id}&league={league_id}', headers=headers)
            
            time.sleep(0.1)
            
            previous_fixture_id = fixtures_request.json()['response'][z-1]['fixture']['id']
            stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={previous_fixture_id}&team={y}', headers = headers)
            
            time.sleep(0.1)
            
            opp_prev_fixture_id = opp_fixtures_request.json()['response'][z-1]['fixture']['id']
            opp_stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={opp_prev_fixture_id}&team={opp_id}', headers = headers)
            
            time.sleep(0.1)
            
            
            if stats_request.json()['response'] == [] or opp_stats_request.json()['response'] == []:
                
                if fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:


                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                
                
                
            else:
                
                if fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:


                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        


                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],


                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],                    
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        
           
            
train_df_year_one = pd.DataFrame(data)
train_df_year_one.set_index('date', inplace=True)
train_df_year_one.loc[train_df_year_one['home_result'] == 'true', 'result'] = 1 
train_df_year_one.loc[train_df_year_one['home_result'] == 'false', 'result'] = -1
train_df_year_one.loc[train_df_year_one['home_result'] == 'None', 'result'] = 0
train_df_year_one.drop_duplicates(inplace=True)
train_df_year_one.dropna(inplace=True)
train_df_year_one.drop(columns=['home_result'], inplace=True)
train_df_year_one.sort_index(inplace=True)

# %%
data = []

for i in train_year_two:
    
    team_request = requests.get(f"https://v3.football.api-sports.io/teams?league={league_id}&season={i}", headers=headers)
    team_request_responses = team_request.json()['results']
    team_ids = []
    
    for x in range(team_request_responses):
        
        team_ids.append(team_request.json()['response'][x]['team']['id'])
        
    team_ids = [35]
        
    for y in team_ids:
        
        fixtures_request = requests.get(f"https://v3.football.api-sports.io/fixtures?season={i}&team={y}&league={league_id}", headers=headers)
        
        time.sleep(0.03)
        
        fixtures_request_responses = fixtures_request.json()['results']
        
        for z in range(2, fixtures_request_responses + 1):
            
            if fixtures_request.json()['response'][-z]['teams']['home']['id'] == y:
                
                opp_id = fixtures_request.json()['response'][-z]['teams']['away']['id']
                
            else:
                
                opp_id = fixtures_request.json()['response'][-z]['teams']['home']['id']
            
            opp_fixtures_request = requests.get(f'https://v3.football.api-sports.io/fixtures?season={i}&team={opp_id}&league={league_id}', headers=headers)
            
            time.sleep(0.1)
            
            previous_fixture_id = fixtures_request.json()['response'][-z+1]['fixture']['id']
            stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={previous_fixture_id}&team={y}', headers = headers)
            
            time.sleep(0.1)
            
            opp_prev_fixture_id = opp_fixtures_request.json()['response'][-z+1]['fixture']['id']
            
            opp_stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={opp_prev_fixture_id}&team={opp_id}', headers = headers)
            
            time.sleep(0.1)
            
            
            if stats_request.json()['response'] == [] or opp_stats_request.json()['response'] == []:
                
                if fixtures_request.json()['response'][-z]['teams']['home']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][-z]['teams']['home']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][-z]['teams']['away']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][-z]['teams']['away']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][-z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                
                
                
            else:
                
                if fixtures_request.json()['response'][-z]['teams']['home']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == y:


                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                elif fixtures_request.json()['response'][-z]['teams']['home']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        


                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                elif fixtures_request.json()['response'][-z]['teams']['away']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],


                    })
                        
                        

                elif fixtures_request.json()['response'][-z]['teams']['away']['id'] == y and fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][-z+1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],                    
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][-z+1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][-z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][-z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][-z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][-z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][-z+1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][-z+1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        
           
            
train_df_year_two = pd.DataFrame(data)
train_df_year_two.set_index('date', inplace=True)
train_df_year_two.loc[train_df_year_two['home_result'] == 'true', 'result'] = 1 
train_df_year_two.loc[train_df_year_two['home_result'] == 'false', 'result'] = -1
train_df_year_two.loc[train_df_year_two['home_result'] == 'None', 'result'] = 0
train_df_year_two.drop_duplicates(inplace=True)
train_df_year_two.dropna(inplace=True)
train_df_year_two.drop(columns=['home_result'], inplace=True)
train_df_year_two.sort_index(inplace=True)

# %%
sample_team = requests.get(f"https://v3.football.api-sports.io/fixtures?season=2016&team=33&league=39", headers=headers)

sample_team.json()['response'][-26]
# Out:
# {'fixture': {'id': 17438,
#   'referee': 'Kevin Friend, England',
#   'timezone': 'UTC',
#   'date': '2017-03-04T12:30:00+00:00',
#   'timestamp': 1488630600,
#   'periods': {'first': 1488630600, 'second': 1488634200},
#   'venue': {'id': None, 'name': 'Old Trafford', 'city': 'Manchester'},
#   'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#  'league': {'id': 39,
#   'name': 'Premier League',
#   'country': 'England',
#   'logo': 'https://media.api-sports.io/football/leagues/39.png',
#   'flag': 'https://media.api-sports.io/flags/gb.svg',
#   'season': 2016,
#   'round': 'Regular Season - 27'},
#  'teams': {'home': {'id': 33,
#    'name': 'Manchester United',
#    'logo': 'https://media.api-sports.io/football/teams/33.png',
#    'winner': None},
#   'away': {'id': 35,
#    'name': 'Bournemouth',
#    'logo': 'https://media.api-sports.io/football/teams/35.png',
#    'winner': None}},
#  'goals': {'home': 1, 'away': 1},
#  'score': {'halftime': {'home': 1, 'away': 1},
#   'fulltime': {'home': 1, 'away': 1},
#   'extratime': {'home': None, 'away': None},
#   'penalty': {'home': None, 'away': None}}}

# %%
compare_team = requests.get(f"https://v3.football.api-sports.io/fixtures?season=2016&team=35&league=39", headers=headers)

compare_team.json()['response'][-27]
# Out:
# {'fixture': {'id': 17438,
#   'referee': 'Kevin Friend, England',
#   'timezone': 'UTC',
#   'date': '2017-03-04T12:30:00+00:00',
#   'timestamp': 1488630600,
#   'periods': {'first': 1488630600, 'second': 1488634200},
#   'venue': {'id': None, 'name': 'Old Trafford', 'city': 'Manchester'},
#   'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#  'league': {'id': 39,
#   'name': 'Premier League',
#   'country': 'England',
#   'logo': 'https://media.api-sports.io/football/leagues/39.png',
#   'flag': 'https://media.api-sports.io/flags/gb.svg',
#   'season': 2016,
#   'round': 'Regular Season - 27'},
#  'teams': {'home': {'id': 33,
#    'name': 'Manchester United',
#    'logo': 'https://media.api-sports.io/football/teams/33.png',
#    'winner': None},
#   'away': {'id': 35,
#    'name': 'Bournemouth',
#    'logo': 'https://media.api-sports.io/football/teams/35.png',
#    'winner': None}},
#  'goals': {'home': 1, 'away': 1},
#  'score': {'halftime': {'home': 1, 'away': 1},
#   'fulltime': {'home': 1, 'away': 1},
#   'extratime': {'home': None, 'away': None},
#   'penalty': {'home': None, 'away': None}}}

# %%
data = []

for i in test_years:
    team_request = requests.get(f"https://v3.football.api-sports.io/teams?league={league_id}&season={i}", headers=headers)
    team_request_responses = team_request.json()['results']
    
    team_ids = []
    for x in range(team_request_responses):
        team_ids.append(team_request.json()['response'][x]['team']['id'])
    for y in team_ids:
        fixtures_request = requests.get(f"https://v3.football.api-sports.io/fixtures?season={i}&team={y}&league={league_id}", headers=headers)
        
        fixtures_request_responses = fixtures_request.json()['results']
        
        for z in range(1, fixtures_request_responses):
            
            if fixtures_request.json()['response'][z]['teams']['home']['id'] == y:
                opp_id = fixtures_request.json()['response'][z]['teams']['away']['id']
            else:
                opp_id = fixtures_request.json()['response'][z]['teams']['home']['id']
            
            opp_fixtures_request = requests.get(f'https://v3.football.api-sports.io/fixtures?season={i}&team={opp_id}&league={league_id}', headers=headers)
            
            time.sleep(0.025)
            
            previous_fixture_id = fixtures_request.json()['response'][z-1]['fixture']['id']
            stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={previous_fixture_id}&team={y}', headers = headers)
            
            time.sleep(0.025)
            
            opp_prev_fixture_id = opp_fixtures_request.json()['response'][z-1]['fixture']['id']
            opp_stats_request = requests.get(f'https://v3.football.api-sports.io/fixtures/statistics?fixture={opp_prev_fixture_id}&team={opp_id}', headers = headers)
            
            
            if stats_request.json()['response'] == [] or opp_stats_request.json()['response'] == []:
                
                if fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:


                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                        
                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : fixtures_request.json()['response'][z]['teams']['home']['winner'],
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : np.nan,
                        'last_home_shots_off_goal' : np.nan,
                        'last_home_total_shots' : np.nan,
                        'last_home_blocked_shots': np.nan,
                        'last_home_shots_insidebox': np.nan,
                        'last_home_shots_outsidebox': np.nan,
                        'last_home_fouls': np.nan,
                        'last_home_cornerkicks': np.nan,
                        'last_home_offsides': np.nan,
                        'last_home_ballpossession': np.nan,
                        'last_home_yellowcards': np.nan,
                        'last_home_redcards': np.nan,
                        'last_home_gk_saves': np.nan,
                        'last_home_pass_accuracy': np.nan,
                        'last_away_shots_on_goal' : np.nan,
                        'last_away_shots_off_goal' : np.nan,
                        'last_away_total_shots' : np.nan,
                        'last_away_blocked_shots': np.nan,
                        'last_away_shots_insidebox': np.nan,
                        'last_away_shots_outsidebox': np.nan,
                        'last_away_fouls': np.nan,
                        'last_away_cornerkicks': np.nan,
                        'last_away_offsides': np.nan,
                        'last_away_ballpossession': np.nan,
                        'last_away_yellowcards': np.nan,
                        'last_away_redcards': np.nan,
                        'last_away_gk_saves': np.nan,
                        'last_away_pass_accuracy': np.nan,                    
                        
                        })
                        
                        
                
                
                
            else:
                
                if fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:


                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['home']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        


                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['home']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],

                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],


                    })
                        
                        

                elif fixtures_request.json()['response'][z]['teams']['away']['id'] == y and fixtures_request.json()['response'][z-1]['teams']['away']['id'] == y:

                    if opp_fixtures_request.json()['response'][z-1]['teams']['home']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['home'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],                    
                    })
                        
                        

                    elif opp_fixtures_request.json()['response'][z-1]['teams']['away']['id'] == opp_id:

                        data.append({
                        'date' : fixtures_request.json()['response'][z]['fixture']['date'],
                        'home_result' : json.dumps(fixtures_request.json()['response'][z]['teams']['home']['winner']).replace('null', 'None'),
                        'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'home_team': fixtures_request.json()['response'][z]['teams']['home']['name'],
                        'away_team': fixtures_request.json()['response'][z]['teams']['away']['name'],
                        'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
                        'last_home_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_away_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
                        'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
                        'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
                        'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
                        'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
                        'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
                        'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
                        'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
                        'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
                        'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
                        'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
                        'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
                        'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
                        'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
                        'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
                        'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],
                    })
                        
                        
           
            
test_df = pd.DataFrame(data)
test_df.set_index('date', inplace=True)
test_df.loc[test_df['home_result'] == 'true', 'result'] = 1 
test_df.loc[test_df['home_result'] == 'false', 'result'] = -1
test_df.loc[test_df['home_result'] == 'None', 'result'] = 0
test_df.drop_duplicates(inplace=True)
test_df.dropna(inplace=True)
test_df.drop(columns=['home_result'], inplace=True)
test_df.sort_index(inplace=True)

# %%
test_df.to_csv(r'epl_test_df_3_1.csv')

# %% [markdown]
# ## Initialize ML model

# %%
# Declare Independent and Dependent Variables
train_y = train_df['result']
train_X = train_df[['last_home_goals', 'last_away_goals',
       'last_home_shots_on_goal', 'last_home_shots_off_goal',
       'last_home_total_shots', 'last_home_blocked_shots',
       'last_home_shots_insidebox', 'last_home_shots_outsidebox',
       'last_home_fouls', 'last_home_cornerkicks', 'last_home_offsides',
       'last_home_ballpossession', 'last_home_yellowcards',
       'last_home_redcards', 'last_home_gk_saves', 'last_home_pass_accuracy',
       'last_away_shots_on_goal', 'last_away_shots_off_goal',
       'last_away_total_shots', 'last_away_blocked_shots',
       'last_away_shots_insidebox', 'last_away_shots_outsidebox',
       'last_away_fouls', 'last_away_cornerkicks', 'last_away_offsides',
       'last_away_ballpossession', 'last_away_yellowcards',
       'last_away_redcards', 'last_away_gk_saves', 'last_away_pass_accuracy']]


test_y = test_df['result']
test_X = test_df[['last_home_goals', 'last_away_goals',
       'last_home_shots_on_goal', 'last_home_shots_off_goal',
       'last_home_total_shots', 'last_home_blocked_shots',
       'last_home_shots_insidebox', 'last_home_shots_outsidebox',
       'last_home_fouls', 'last_home_cornerkicks', 'last_home_offsides',
       'last_home_ballpossession', 'last_home_yellowcards',
       'last_home_redcards', 'last_home_gk_saves', 'last_home_pass_accuracy',
       'last_away_shots_on_goal', 'last_away_shots_off_goal',
       'last_away_total_shots', 'last_away_blocked_shots',
       'last_away_shots_insidebox', 'last_away_shots_outsidebox',
       'last_away_fouls', 'last_away_cornerkicks', 'last_away_offsides',
       'last_away_ballpossession', 'last_away_yellowcards',
       'last_away_redcards', 'last_away_gk_saves', 'last_away_pass_accuracy']]

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
league_model = LogisticRegression(solver='lbfgs',
                                max_iter=800,
                                random_state=1)
league_model
# Out:
# LogisticRegression(max_iter=800, random_state=1)

# %%
league_model.fit(train_X, train_y)
# Out:
# LogisticRegression(max_iter=800, random_state=1)

# %%
print(f"Training Data Score: {league_model.score(train_X, train_y)}")
print(f"Testing Data Score: {league_model.score(test_X, test_y)}")
# Out:
# Training Data Score: 0.5206216377764495
# Testing Data Score: 0.5128205128205128

# %%
test_df['prediction'] = league_model.predict(test_X)

# %%
test_df
# Out:
#                            previous_home_fixture          home_team  \
# date
# 2019-08-17T11:30:00+00:00                 157023            Arsenal
# 2019-08-17T14:00:00+00:00                 157015            Norwich
# 2019-08-17T14:00:00+00:00                 157022        Aston Villa
# 2019-08-17T14:00:00+00:00                 157019            Everton
# 2019-08-17T14:00:00+00:00                 157021           Brighton
# 2019-08-17T14:00:00+00:00                 157018        Southampton
# 2019-08-17T16:30:00+00:00                 157016    Manchester City
# 2019-08-18T13:00:00+00:00                 157017      Sheffield Utd
# 2019-08-18T15:30:00+00:00                 157024            Chelsea
# 2019-08-19T19:00:00+00:00                 157020             Wolves
# 2019-08-23T19:00:00+00:00                 157026        Aston Villa
# 2019-08-24T11:30:00+00:00                 157031            Norwich
# 2019-08-24T14:00:00+00:00                 157027           Brighton
# 2019-08-24T14:00:00+00:00                 157032      Sheffield Utd
# 2019-08-24T14:00:00+00:00                 157034  Manchester United
# 2019-08-24T14:00:00+00:00                 157034  Manchester United
# 2019-08-24T14:00:00+00:00                 157029            Watford
# 2019-08-24T14:00:00+00:00                 157029            Watford
# 2019-08-24T16:30:00+00:00                 157033          Liverpool
# 2019-08-25T13:00:00+00:00                 157026        Bournemouth
# 2019-08-25T15:30:00+00:00                 157034             Wolves
# 2019-08-25T15:30:00+00:00                 157030          Tottenham
# 2019-08-25T15:30:00+00:00                 157030          Tottenham
# 2019-08-31T11:30:00+00:00                 157037        Southampton
# 2019-08-31T14:00:00+00:00                 157041          Leicester
# 2019-08-31T14:00:00+00:00                 157043           West Ham
# 2019-08-31T14:00:00+00:00                 157039     Crystal Palace
# 2019-08-31T14:00:00+00:00                 157042          Newcastle
# 2019-08-31T14:00:00+00:00                 157040            Chelsea
# 2019-08-31T14:00:00+00:00                 157035    Manchester City
# 2019-08-31T16:30:00+00:00                 157044            Burnley
# 2019-09-01T13:00:00+00:00                 157036            Everton
# 2019-09-01T15:30:00+00:00                 157038            Arsenal
# 2019-09-14T11:30:00+00:00                 157046          Liverpool
# 2019-09-14T14:00:00+00:00                 157047      Sheffield Utd
# 2019-09-14T14:00:00+00:00                 157049             Wolves
# 2020-07-15T17:00:00+00:00                 0.809524    -1.0         1.0
# 2020-07-15T17:00:00+00:00                 0.863475     0.0        -1.0
# 2020-07-15T17:00:00+00:00                 0.721698     1.0         1.0
# 2020-07-15T19:15:00+00:00                 0.855842     1.0        -1.0
# 2020-07-16T17:00:00+00:00                 0.633466     1.0         1.0
# 2020-07-16T17:00:00+00:00                 0.735669     0.0        -1.0
# 2020-07-16T19:15:00+00:00                 0.794816    -1.0         1.0
# 2020-07-16T19:15:00+00:00                 0.764179     0.0         1.0
# 2020-07-17T19:00:00+00:00                 0.683544     1.0         1.0
# 2020-07-18T16:30:00+00:00                 0.710306    -1.0        -1.0
# 2020-07-19T13:00:00+00:00                 0.820771    -1.0        -1.0
# 2020-07-19T15:00:00+00:00                 0.792373     1.0         1.0
# 2020-07-20T17:00:00+00:00                 0.874751     0.0        -1.0
# 2020-07-20T17:00:00+00:00                 0.860045    -1.0         1.0
# 2020-07-20T19:15:00+00:00                 0.785047     1.0         1.0
# 2020-07-21T17:00:00+00:00                 0.884921    -1.0        -1.0
# 2020-07-21T19:15:00+00:00                 0.639860     1.0         1.0
# 2020-07-22T17:00:00+00:00                 0.639731     0.0         1.0
# 2020-07-22T19:15:00+00:00                 0.892487     1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.719298     0.0         1.0
# 2020-07-26T15:00:00+00:00                 0.604167    -1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.880074    -1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.865353    -1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.754237     1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.757576     0.0         1.0
# 2020-07-26T15:00:00+00:00                 0.788462     1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.811644    -1.0        -1.0
# 2020-07-26T15:00:00+00:00                 0.817204     1.0         1.0
# 2020-07-26T15:00:00+00:00                 0.663793     1.0         1.0

# %%
current_team_ids = []
    
current_team_request = requests.get(f"https://v3.football.api-sports.io/teams?league={league_id}&season={current_year}", headers=headers)
current_team_request_responses = team_request.json()['results']

upcoming_fixtures = []
    
for i in range(5):
    
    current_team_ids.append(current_team_request.json()['response'][i]['team']['id'])
    
for i in current_team_ids:
    upcoming_fixtures_request = requests.get(f'https://v3.football.api-sports.io/fixtures?season={current_year}&league={league_id}&next=1&team={i}', headers=headers)
    previous_fixtures_request = request.get(f')
    
    if upcoming_fixtures_request.json()['response'][0]['teams']['home']['id'] == i:
        
        upcoming_fixtures.append({
            
            'date' : upcoming_fixtures_request.json()['response'][0]['fixture']['date'],
            'previous_home_fixture' : opp_fixtures_request.json()['response'][z-1]['fixture']['id'],
            'home_team': upcoming_fixtures_request.json()['response'][0]['teams']['home']['name'],
            'away_team': upcoming_fixtures_request.json()['response'][0]['teams']['away']['name'],
            'previous_away_fixture': fixtures_request.json()['response'][z-1]['fixture']['id'],
            'last_home_goals': fixtures_request.json()['response'][z-1]['goals']['away'],
            'last_away_goals': opp_fixtures_request.json()['response'][z-1]['goals']['away'],
            'last_home_shots_on_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
            'last_home_shots_off_goal' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
            'last_home_total_shots' : float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
            'last_home_blocked_shots': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
            'last_home_shots_insidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
            'last_home_shots_outsidebox': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
            'last_home_fouls': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
            'last_home_cornerkicks': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
            'last_home_offsides': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
            'last_home_ballpossession': float(opp_stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
            'last_home_yellowcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
            'last_home_redcards': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
            'last_home_gk_saves': float(json.dumps(opp_stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
            'last_home_pass_accuracy': opp_stats_request.json()['response'][0]['statistics'][14]['value'] / opp_stats_request.json()['response'][0]['statistics'][13]['value'],
            'last_away_shots_on_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][0]['value']).replace('null', '0')),
            'last_away_shots_off_goal' : float(json.dumps(stats_request.json()['response'][0]['statistics'][1]['value']).replace('null', '0')),
            'last_away_total_shots' : float(json.dumps(stats_request.json()['response'][0]['statistics'][2]['value']).replace('null', '0')),
            'last_away_blocked_shots': float(json.dumps(stats_request.json()['response'][0]['statistics'][3]['value']).replace('null', '0')),
            'last_away_shots_insidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][4]['value']).replace('null', '0')),
            'last_away_shots_outsidebox': float(json.dumps(stats_request.json()['response'][0]['statistics'][5]['value']).replace('null', '0')),
            'last_away_fouls': float(json.dumps(stats_request.json()['response'][0]['statistics'][6]['value']).replace('null', '0')),
            'last_away_cornerkicks': float(json.dumps(stats_request.json()['response'][0]['statistics'][7]['value']).replace('null', '0')),
            'last_away_offsides': float(json.dumps(stats_request.json()['response'][0]['statistics'][8]['value']).replace('null', '0')),
            'last_away_ballpossession': float(stats_request.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01,
            'last_away_yellowcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][10]['value']).replace('null', '0')),
            'last_away_redcards': float(json.dumps(stats_request.json()['response'][0]['statistics'][11]['value']).replace('null', '0')),
            'last_away_gk_saves': float(json.dumps(stats_request.json()['response'][0]['statistics'][12]['value']).replace('null', '0')),
            'last_away_pass_accuracy': stats_request.json()['response'][0]['statistics'][14]['value'] / stats_request.json()['response'][0]['statistics'][13]['value'],

        })
# Out:
# [33, 34, 36, 39, 40]

# %%
upcoming_fixtures_request = requests.get(f'https://v3.football.api-sports.io/fixtures?season=2020&league=39&next=1&team=33', headers=headers)

upcoming_fixtures_request.json()['response'][0]['teams']['home']['id']
# Out:
# 33

# %%
 team_ids = []
    for x in range(team_request_responses):
        team_ids.append(team_request.json()['response'][x]['team']['id'])
    for y in team_ids:
        fixtures_request = requests.get(f"https://v3.football.api-sports.io/fixtures?season={i}&team={y}&league={league_id}", headers=headers)
