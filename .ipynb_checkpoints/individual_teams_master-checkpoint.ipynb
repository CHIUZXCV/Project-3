# %% [markdown]
# # Prework

# %%
# Import libraries
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans 
pd.set_option("max_rows", None)

# %%
#Load CSVs
file_path_2019 = Path("RESOURCES/2019.csv")
file_path_2018 = Path("RESOURCES/2018.csv")
file_path_2017 = Path("RESOURCES/2017.csv")
file_path_2016 = Path("RESOURCES/2016.csv")
file_path_2015 = Path("RESOURCES/2015.csv")
file_path_2014 = Path("RESOURCES/2014.csv")
file_path_2013 = Path("RESOURCES/2013.csv")
file_path_2012 = Path("RESOURCES/2012.csv")
file_path_2011 = Path("RESOURCES/2011.csv")
#Read in CSVs
df_2019 = pd.read_csv(file_path_2019, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True) 
df_2018 = pd.read_csv(file_path_2018, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2017 = pd.read_csv(file_path_2017, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2016 = pd.read_csv(file_path_2016, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2015 = pd.read_csv(file_path_2015, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2014 = pd.read_csv(file_path_2014, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2013 = pd.read_csv(file_path_2013, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2012 = pd.read_csv(file_path_2012, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2011 = pd.read_csv(file_path_2011, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %% [markdown]
# # Cleaning Data

# %%
#Concat Data
train_epl_df = pd.concat([df_2018, df_2017, df_2016, df_2015, df_2014, df_2013, df_2012, df_2011],axis="index", join="inner")

# %%
train_epl_df.sort_index(inplace=True)

# %%
#Pull the Testing Data for 2019
test_epl_df = (df_2019)
test_epl_df.sort_index(inplace=True)

# %%
# Check data for nulls, check for sum, for Train Data
train_epl_df.isnull().sum()
train_epl_df.dropna(inplace=True)
train_epl_df.isnull().sum().head()
# Out:
# Div         0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# FTAG        0
# dtype: int64

# %%
# Check data for nulls, check for sum, for Test Data
test_epl_df.isnull().sum()
test_epl_df.dropna(inplace=True)
test_epl_df.isnull().sum().head()
# Out:
# Div         0
# Time        0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# dtype: int64

# %%
#To check the columns for the Train dataframe
train_epl_df.head()
print(train_epl_df.columns.values)
# Out:
# ['Div' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR'
#  'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR' 'AR'
#  'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'WHH' 'WHD'
#  'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2' 'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA'
#  'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh'
#  'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']

# %%
#Drop Excess columns Train Data
train_epl_df = train_epl_df.drop(columns=['Div', 'Referee', 'HS', 'AS', 'HC', 'AC', 
                                        'BWA','BWH', 'BWD', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA',
                                        'Bb1X2', 'BbMxH', 'BbMxD', 'BbAvH','BbAvD', 'BbMxA', 'BbAvA',
                                         'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5',
                                         'BbAHh', 'BbAHh', 'BbAH', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
                                         ])
train_epl_df.head()
# Out:
#                HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HST  AST  \
# Date
# 2010-08-14       Wolves      Stoke     2     1   H     2     0   H    7    6
# 2010-08-14  Aston Villa   West Ham     3     0   H     2     0   H   11    2
# 2010-08-14    Blackburn    Everton     1     0   H     1     0   H    2   12
# 2010-08-14       Bolton     Fulham     0     0   D     0     0   D    9    7
# 2010-08-14      Chelsea  West Brom     6     0   H     2     0   H   13    4
#
#             ...  HY  AY  HR  AR  B365H  B365D  B365A   WHH   WHD    WHA
# Date        ...
# 2010-08-14  ...   0   2   0   0   2.30   3.25    3.2  2.30  3.20   3.20
# 2010-08-14  ...   1   2   0   0   2.00   3.30    4.0  1.91  3.25   4.33
# 2010-08-14  ...   2   1   0   0   2.88   3.25    2.5  2.88  3.20   2.50
# 2010-08-14  ...   1   3   0   0   2.20   3.30    3.4  2.15  3.20   3.50
# 2010-08-14  ...   1   0   0   0   1.17   7.00   17.0  1.17  6.50  19.00
#
# [5 rows x 22 columns]

# %%
#Check new columns for Train Data
train_epl_df.head()
print(train_epl_df.columns.values)
# Out:
# ['HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR' 'HST' 'AST'
#  'HF' 'AF' 'HY' 'AY' 'HR' 'AR' 'B365H' 'B365D' 'B365A' 'WHH' 'WHD' 'WHA']

# %%
#To check the columns for the test dataframe
test_epl_df.head()
print(test_epl_df.columns.values)
# Out:
# ['Div' 'Time' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'PSH'
#  'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'MaxH' 'MaxD' 'MaxA'
#  'AvgH' 'AvgD' 'AvgA' 'B365>2.5' 'B365<2.5' 'P>2.5' 'P<2.5' 'Max>2.5'
#  'Max<2.5' 'Avg>2.5' 'Avg<2.5' 'AHh' 'B365AHH' 'B365AHA' 'PAHH' 'PAHA'
#  'MaxAHH' 'MaxAHA' 'AvgAHH' 'AvgAHA' 'B365CH' 'B365CD' 'B365CA' 'BWCH'
#  'BWCD' 'BWCA' 'IWCH' 'IWCD' 'IWCA' 'PSCH' 'PSCD' 'PSCA' 'WHCH' 'WHCD'
#  'WHCA' 'VCCH' 'VCCD' 'VCCA' 'MaxCH' 'MaxCD' 'MaxCA' 'AvgCH' 'AvgCD'
#  'AvgCA' 'B365C>2.5' 'B365C<2.5' 'PC>2.5' 'PC<2.5' 'MaxC>2.5' 'MaxC<2.5'
#  'AvgC>2.5' 'AvgC<2.5' 'AHCh' 'B365CAHH' 'B365CAHA' 'PCAHH' 'PCAHA'
#  'MaxCAHH' 'MaxCAHA' 'AvgCAHH' 'AvgCAHA']

# %%
#Drop Excess columns half time (Test Data)
test_epl_df = test_epl_df.drop(columns=['Div', 'Time', 'Referee', 'HS', 'AS', 'HC', 'AC', 
                                        'Max>2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH','PAHA',
                                         'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'VCH', 'VCD', 'VCA', 
                                        'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5','B365<2.5','P>2.5','P<2.5','Max<2.5',
                                         'MaxAHH', 'MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH',
                                         'BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD',
                                         'WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD',
                                         'AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5',
                                        'AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA',
                                         'MaxCAHH','MaxCAHA','AvgCAHH','AvgCAHA'])
                                         
test_epl_df.head()
# Out:
#                   HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# Date
# 2019-08-09       Liverpool           Norwich     4     1   H     4     0   H
# 2019-08-10        West Ham          Man City     0     5   A     0     1   A
# 2019-08-10     Bournemouth  Sheffield United     1     1   D     0     0   D
# 2019-08-10         Burnley       Southampton     3     0   H     0     0   D
# 2019-08-10  Crystal Palace           Everton     0     0   D     0     0   D
#
#             HST  AST  ...  HY  AY  HR  AR  B365H  B365D  B365A    WHH  WHD  \
# Date                  ...
# 2019-08-09    7    5  ...   0   2   0   0   1.14  10.00  19.00   1.12  8.5
# 2019-08-10    3    9  ...   2   2   0   0  12.00   6.50   1.22  13.00  6.0
# 2019-08-10    3    3  ...   2   1   0   0   1.95   3.60   3.60   2.00  3.5
# 2019-08-10    4    3  ...   0   0   0   0   2.62   3.20   2.75   2.70  3.2
# 2019-08-10    2    3  ...   2   1   0   1   3.00   3.25   2.37   3.10  3.3
#
#               WHA
# Date
# 2019-08-09  21.00
# 2019-08-10   1.24
# 2019-08-10   3.80
# 2019-08-10   2.75
# 2019-08-10   2.35
#
# [5 rows x 22 columns]

# %%
# Check new columns for Train Data
test_epl_df.head()
print(test_epl_df.columns.values)
# Out:
# ['HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR' 'HST' 'AST'
#  'HF' 'AF' 'HY' 'AY' 'HR' 'AR' 'B365H' 'B365D' 'B365A' 'WHH' 'WHD' 'WHA']

# %%
# Rename Columns 
train_epl_df = train_epl_df.rename(columns={
    "FTHG": "FT_HomeGoals", "FTAG": "FT_AwayGoals", "FTR": "FT_Result", "HTHG": "HT_HomeGoals", "HTAG": "HT_AwayGoals", "HTR": "HT_Result", "HST": "HomeShotsonTarget", "AST": "AwayShotsonTarget",
    "HF": "HomeFouls", "AF": "AwayFouls", "HY": "HomeYellowCards", "AY": "AwayYellowCards", "HR": "HomeRedCards", "AR": "AwayRedCards",
    "B365H" : "Bet365_HomeWin_Odds", "B365D": "Bet365_Draw_Odds", "B365A": "Bet365_AwayWin_Odds", "WHH": "WilliamHill_HomeWin_Odds", "WHD": "WilliamHill_HomeDraw_Odds", "WHA": "WilliamHill_AwayWin_Odds"})
train_epl_df.head()
# Out:
#                HomeTeam   AwayTeam  FT_HomeGoals  FT_AwayGoals FT_Result  \
# Date
# 2010-08-14       Wolves      Stoke             2             1         H
# 2010-08-14  Aston Villa   West Ham             3             0         H
# 2010-08-14    Blackburn    Everton             1             0         H
# 2010-08-14       Bolton     Fulham             0             0         D
# 2010-08-14      Chelsea  West Brom             6             0         H
#
#             HT_HomeGoals  HT_AwayGoals HT_Result  HomeShotsonTarget  \
# Date
# 2010-08-14             2             0         H                  7
# 2010-08-14             2             0         H                 11
# 2010-08-14             1             0         H                  2
# 2010-08-14             0             0         D                  9
# 2010-08-14             2             0         H                 13
#
#             AwayShotsonTarget  ...  HomeYellowCards  AwayYellowCards  \
# Date                           ...
# 2010-08-14                  6  ...                0                2
# 2010-08-14                  2  ...                1                2
# 2010-08-14                 12  ...                2                1
# 2010-08-14                  7  ...                1                3
# 2010-08-14                  4  ...                1                0
#
#             HomeRedCards  AwayRedCards  Bet365_HomeWin_Odds  Bet365_Draw_Odds  \
# Date
# 2010-08-14             0             0                 2.30              3.25
# 2010-08-14             0             0                 2.00              3.30
# 2010-08-14             0             0                 2.88              3.25
# 2010-08-14             0             0                 2.20              3.30
# 2010-08-14             0             0                 1.17              7.00
#
#             Bet365_AwayWin_Odds  WilliamHill_HomeWin_Odds  \
# Date
# 2010-08-14                  3.2                      2.30
# 2010-08-14                  4.0                      1.91
# 2010-08-14                  2.5                      2.88
# 2010-08-14                  3.4                      2.15
# 2010-08-14                 17.0                      1.17
#
#             WilliamHill_HomeDraw_Odds  WilliamHill_AwayWin_Odds
# Date
# 2010-08-14                       3.20                      3.20
# 2010-08-14                       3.25                      4.33
# 2010-08-14                       3.20                      2.50
# 2010-08-14                       3.20                      3.50
# 2010-08-14                       6.50                     19.00
#
# [5 rows x 22 columns]

# %%
#Rename Columns for test Data
test_epl_df = test_epl_df.rename(columns={
    "FTHG": "FT_HomeGoals", "FTAG": "FT_AwayGoals", "FTR": "FT_Result", "HTHG": "HT_HomeGoals", "HTAG": "HT_AwayGoals", "HTR": "HT_Result", "HST": "HomeShotsonTarget", "AST": "AwayShotsonTarget",
    "HF": "HomeFouls", "AF": "AwayFouls", "HY": "HomeYellowCards", "AY": "AwayYellowCards", "HR": "HomeRedCards", "AR": "AwayRedCards",
    "B365H" : "Bet365_HomeWin_Odds", "B365D": "Bet365_Draw_Odds", "B365A": "Bet365_AwayWin_Odds", "WHH": "WilliamHill_HomeWin_Odds", "WHD": "WilliamHill_HomeDraw_Odds", "WHA": "WilliamHill_AwayWin_Odds"})
test_epl_df.head()
# Out:
#                   HomeTeam          AwayTeam  FT_HomeGoals  FT_AwayGoals  \
# Date
# 2019-08-09       Liverpool           Norwich             4             1
# 2019-08-10        West Ham          Man City             0             5
# 2019-08-10     Bournemouth  Sheffield United             1             1
# 2019-08-10         Burnley       Southampton             3             0
# 2019-08-10  Crystal Palace           Everton             0             0
#
#            FT_Result  HT_HomeGoals  HT_AwayGoals HT_Result  HomeShotsonTarget  \
# Date
# 2019-08-09         H             4             0         H                  7
# 2019-08-10         A             0             1         A                  3
# 2019-08-10         D             0             0         D                  3
# 2019-08-10         H             0             0         D                  4
# 2019-08-10         D             0             0         D                  2
#
#             AwayShotsonTarget  ...  HomeYellowCards  AwayYellowCards  \
# Date                           ...
# 2019-08-09                  5  ...                0                2
# 2019-08-10                  9  ...                2                2
# 2019-08-10                  3  ...                2                1
# 2019-08-10                  3  ...                0                0
# 2019-08-10                  3  ...                2                1
#
#             HomeRedCards  AwayRedCards  Bet365_HomeWin_Odds  Bet365_Draw_Odds  \
# Date
# 2019-08-09             0             0                 1.14             10.00
# 2019-08-10             0             0                12.00              6.50
# 2019-08-10             0             0                 1.95              3.60
# 2019-08-10             0             0                 2.62              3.20
# 2019-08-10             0             1                 3.00              3.25
#
#             Bet365_AwayWin_Odds  WilliamHill_HomeWin_Odds  \
# Date
# 2019-08-09                19.00                      1.12
# 2019-08-10                 1.22                     13.00
# 2019-08-10                 3.60                      2.00
# 2019-08-10                 2.75                      2.70
# 2019-08-10                 2.37                      3.10
#
#             WilliamHill_HomeDraw_Odds  WilliamHill_AwayWin_Odds
# Date
# 2019-08-09                        8.5                     21.00
# 2019-08-10                        6.0                      1.24
# 2019-08-10                        3.5                      3.80
# 2019-08-10                        3.2                      2.75
# 2019-08-10                        3.3                      2.35
#
# [5 rows x 22 columns]

# %%
# Convert H to 1 when HomeTeam wins, and 'A', 'D' to 0 
def conditions(s, team):
    if (s['HomeTeam'] == team) and (s['FT_Result'] == "H"):
        return 1
    elif (s['AwayTeam'] == team) and (s['FT_Result'] == "A"):
        return 1
    else:
        return 0
    
def HomeGoals(s, team):
    if (s['HomeTeam'] == team):
        s['Goals Scored Last Game'] = s['FT_HomeGoals']
        return s['Goals Scored Last Game']
    elif (s['AwayTeam'] == team):
        s['Goals Scored Last Game'] = s['FT_AwayGoals']
        return s['Goals Scored Last Game']
        
def AwayGoals(s, team):
    if (s['HomeTeam'] == team):
        s['Goals Scored On Last Game'] = s['FT_AwayGoals']
        return s['Goals Scored On Last Game']
    elif (s['AwayTeam'] == team):
        s['Goals Scored On Last Game'] = s['FT_HomeGoals']
        return s['Goals Scored On Last Game']

# %%
## Example: how to apply it to one team (Liverpool)
## train_epl_df['Result'] = train_epl_df.apply(lambda x: conditions(x, "Liverpool"), axis=1)

# %%
liverpool_df = pd.concat([train_epl_df.loc[train_epl_df["HomeTeam"] == "Liverpool"], train_epl_df.loc[train_epl_df['AwayTeam'] == "Liverpool"]], axis="index", join="inner")

# 2018-10-20                          0
# 2018-10-27                          1
# 2018-11-03                          1
# 2018-11-11                          0
# 2018-11-24                          0
# 2018-12-02                          0
# 2018-12-05                          1
# 2018-12-08                          0
# 2018-12-16                          1
# 2018-12-21                          0
# 2018-12-26                          0
# 2018-12-29                          1
# 2019-01-03                          2
# 2019-01-12                          0
# 2019-01-19                          3
# 2019-01-30                          1
# 2019-02-04                          1
# 2019-02-09                          0
# 2019-02-24                          0
# 2019-02-27                          0
# 2019-03-03                          0
# 2019-03-10                          2
# 2019-03-17                          1
# 2019-03-31                          1
# 2019-04-05                          1
# 2019-04-14                          0
# 2019-04-21                          0
# 2019-04-26                          0
# 2019-05-04                          2
# 2019-05-12                          0
#
# [303 rows x 24 columns]

# %% [markdown]
# # Separate DataFrames based on Team; Home vs Away, between Train and Test Data

# %%
#Create DataFrames for Each Team by HomeTeam for Train Data
everton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Everton"]
astonvilla_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Aston Villa"]
leicester_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Leicester"]
arsenal_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Arsenal"]
liverpool_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Liverpool"]
tottenham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Tottenham"]
chelsea_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Chelsea"]
leeds_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Leeds"]
newcastle_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Newcastle"]
westham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "West Ham"]
southampton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Southampton"]
crystal_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Crystal Palace"]
wolves_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Wolves"]
mancity_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Man City"]
brighton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Brighton"]
manutd_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Man United"]
westbrom_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "West Brom"]
burnley_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Burnley"]
sheffield_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Sheffield United"]
fulham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by HomeTeam for Test Data
everton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Everton"]
astonvilla_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Aston Villa"]
leicester_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Leicester"]
arsenal_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Arsenal"]
liverpool_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Liverpool"]
tottenham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Tottenham"]
chelsea_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Chelsea"]
leeds_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Leeds"]
newcastle_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Newcastle"]
westham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "West Ham"]
southampton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Southampton"]
crystal_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Crystal Palace"]
wolves_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Wolves"]
mancity_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Man City"]
brighton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Brighton"]
manutd_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Man United"]
westbrom_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "West Brom"]
burnley_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Burnley"]
sheffield_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Sheffield United"]
fulham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by AwayTeam for Train Data
everton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Everton"]
astonvilla_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Aston Villa"]
leicester_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Leicester"]
arsenal_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Arsenal"]
liverpool_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Liverpool"]
tottenham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Tottenham"]
chelsea_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Chelsea"]
leeds_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Leeds"]
newcastle_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Newcastle"]
westham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "West Ham"]
southampton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Southampton"]
crystal_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Crystal Palace"]
wolves_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Wolves"]
mancity_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Man City"]
brighton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Brighton"]
manutd_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Man United"]
westbrom_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "West Brom"]
burnley_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Burnley"]
sheffield_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Sheffield United"]
fulham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by AwayTeam for Test Data
everton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Everton"]
astonvilla_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Aston Villa"]
leicester_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Leicester"]
arsenal_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Arsenal"]
liverpool_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Liverpool"]
tottenham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Tottenham"]
chelsea_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Chelsea"]
leeds_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Leeds"]
newcastle_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Newcastle"]
westham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "West Ham"]
southampton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Southampton"]
crystal_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Crystal Palace"]
wolves_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Wolves"]
mancity_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Man City"]
brighton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Brighton"]
manutd_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Man United"]
westbrom_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "West Brom"]
burnley_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Burnley"]
sheffield_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Sheffield United"]
fulham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Fulham"]

# %%
liverpool_home_df.tail()
# Out:
#              HomeTeam    AwayTeam  FT_HomeGoals  FT_AwayGoals FT_Result  \
# Date
# 06-03-2011  Liverpool  Man United             3             1         H
# 11-04-2011  Liverpool    Man City             3             0         H
# 04-23-2011  Liverpool  Birmingham             5             0         H
# 01-05-2011  Liverpool   Newcastle             3             0         H
# 05-15-2011  Liverpool   Tottenham             0             2         A
#
#             HT_HomeGoals  HT_AwayGoals HT_Result  HomeShotsonTarget  \
# Date
# 06-03-2011             2             0         H                 10
# 11-04-2011             3             0         H                  7
# 04-23-2011             2             0         H                 13
# 01-05-2011             1             0         H                  5
# 05-15-2011             0             1         A                  2
#
#             AwayShotsonTarget  ...  AwayYellowCards  HomeRedCards  \
# Date                           ...
# 06-03-2011                  7  ...                3             0
# 11-04-2011                  4  ...                0             0
# 04-23-2011                  6  ...                0             0
# 01-05-2011                  3  ...                2             0
# 05-15-2011                  4  ...                1             0
#
#             AwayRedCards  Bet365_HomeWin_Odds  Bet365_Draw_Odds  \
# Date
# 06-03-2011             0                 2.80              3.20
# 11-04-2011             0                 2.60              3.20
# 04-23-2011             0                 1.44              4.33
# 01-05-2011             0                 1.44              4.33
# 05-15-2011             0                 1.73              3.80
#
#             Bet365_AwayWin_Odds  WilliamHill_HomeWin_Odds  \
# Date
# 06-03-2011                 2.60                      2.88
# 11-04-2011                 2.80                      2.50
# 04-23-2011                 7.50                      1.50
# 01-05-2011                 7.50                      1.50
# 05-15-2011                 4.75                      1.80
#
#             WilliamHill_HomeDraw_Odds  WilliamHill_AwayWin_Odds  Result
# Date
# 06-03-2011                       3.20                      2.50       1
# 11-04-2011                       3.20                      2.88       1
# 04-23-2011                       3.75                      8.00       1
# 01-05-2011                       4.20                      6.50       1
# 05-15-2011                       3.50                      4.50       0
#
# [5 rows x 23 columns]

# %% [markdown]
# # ReExport Team Based CSVs to prevent Lookahead Bias

# %%
#Shift Liverpool Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
liverpool_home_df = liverpool_home_df.shift(periods=-1)
liverpool_away_df = liverpool_away_df.shift(periods=-1)
liverpool_home_t_df = liverpool_home_t_df.shift(periods=-1)
liverpool_away_t_df = liverpool_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.


#liverpool_home_t_df.to_csv('Liverpool_Home_T.csv')
#liverpool_away_t_df.to_csv('Liverpool_Away_T.csv')
#liverpool_away_df.to_csv('Liverpool_Away_.csv')

# %%
#Read in newly adjusted Liverpool CSVs
liverpool_home_p = Path("RESOURCES/TeamCSVs/Liverpool_Home.csv")
liverpool_home_p_t = Path("RESOURCES/TeamCSVs/Liverpool_Home_T.csv")
liverpool_away_p = Path("RESOURCES/TeamCSVs/Liverpool_Away.csv")
liverpool_away_p_t = Path("RESOURCES/TeamCSVs/Liverpool_Away_T.csv")
#Read in CSVs
liverpool_home = pd.read_csv(liverpool_home_p)
liverpool_home_t = pd.read_csv(liverpool_home_p_t)
liverpool_away = pd.read_csv(liverpool_away_p)
liverpool_away_t = pd.read_csv(liverpool_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
liverpool_home = liverpool_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_home_t = liverpool_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_away = liverpool_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_away_t = liverpool_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
liverpool_home = liverpool_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_home_t = liverpool_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_away = liverpool_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_away_t = liverpool_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %% [markdown]
# # ML For Teams based on Home and Away Metrics

# %%
#Declare Independent and Dependent Variables
lph_y_train = liverpool_home['Result']
lph_X_train = liverpool_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
lph_y_test = liverpool_home_t['Result']
lph_X_test = liverpool_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(lph_X_train, lph_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(lph_X_train, lph_y_train)}")
print(f"Testing Data Score: {classifier.score(lph_X_test, lph_y_test)}")
# Out:
# Training Data Score: 0.738255033557047
# Testing Data Score: 0.9411764705882353

# %%
predictions = classifier.predict(lph_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": lph_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam  AwayTeam
# 8/24/2019  Liverpool Arsenal                    1       1
# 9/14/2019  Liverpool Newcastle                  1       1
# 5/10/2019  Liverpool Leicester                  1       1
# 10/27/2019 Liverpool Tottenham                  1       1
# 10/11/2019 Liverpool Man City                   1       1
# 11/30/2019 Liverpool Brighton                   1       1
# 4/12/2019  Liverpool Everton                    1       1
# 12/14/2019 Liverpool Watford                    0       1
# 12/29/2019 Liverpool Wolves                     1       1
# 2/1/2020   Liverpool Sheffield United           1       1
# 1/19/2020  Liverpool Man United                 1       1
# 1/2/2020   Liverpool Southampton                1       1
# 2/24/2020  Liverpool West Ham                   1       1
# 7/3/2020   Liverpool Bournemouth                1       1
# 6/24/2020  Liverpool Crystal Palace             1       1
# 5/7/2020   Liverpool Aston Villa                0       0
# 11/7/2020  Liverpool Burnley                    1       1

# %%
#Declare Dependent/Independent Variables
lpa_y_train = liverpool_away['Result']
lpa_X_train = liverpool_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
lpa_y_test = liverpool_away_t['Result']
lpa_X_test = liverpool_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(lpa_X_train, lpa_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(lpa_X_train, lpa_y_train)}")
print(f"Testing Data Score: {classifier.score(lpa_X_test, lpa_y_test)}")
# Out:
# Training Data Score: 0.68
# Testing Data Score: 0.6470588235294118

# %%
predictions = classifier.predict(lpa_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": lpa_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/31/2019  Burnley          Liverpool           0      -1
# 9/22/2019  Chelsea          Liverpool          -1      -1
# 9/28/2019  Sheffield United Liverpool           1       0
# 10/20/2019 Man United       Liverpool          -1      -1
# 2/11/2019  Aston Villa      Liverpool          -1      -1
# 11/23/2019 Crystal Palace   Liverpool          -1      -1
# 7/12/2019  Bournemouth      Liverpool          -1      -1
# 12/26/2019 Leicester        Liverpool           0      -1
# 11/1/2020  Tottenham        Liverpool          -1      -1
# 1/23/2020  Wolves           Liverpool          -1      -1
# 1/29/2020  West Ham         Liverpool           0      -1
# 2/15/2020  Norwich          Liverpool           1       1
# 2/29/2020  Watford          Liverpool           1       0
# 6/21/2020  Everton          Liverpool           1       1
# 2/7/2020   Man City         Liverpool          -1      -1
# 8/7/2020   Brighton         Liverpool           0       1
# 7/15/2020  Arsenal          Liverpool          -1      -1

# %%
#Shift Wolves Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
wolves_home_df = wolves_home_df.shift(periods=-1)
wolves_away_df = wolves_away_df.shift(periods=-1)
wolves_home_t_df = wolves_home_t_df.shift(periods=-1)
wolves_away_t_df = wolves_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

wolves_home_df.to_csv('Wolves_Home.csv')
wolves_home_t_df.to_csv('Wolves_Home_T.csv')
wolves_away_t_df.to_csv('Wolves_Away_T.csv')
wolves_away_df.to_csv('Wolves_Away_.csv')

# %%
#Read in newly adjusted Liverpool CSVs
wolves_home_p = Path("RESOURCES/TeamCSVs/Wolves_Home.csv")
wolves_home_p_t = Path("RESOURCES/TeamCSVs/Wolves_Home_T.csv")
wolves_away_p = Path("RESOURCES/TeamCSVs/Wolves_Away.csv")
wolves_away_p_t = Path("RESOURCES/TeamCSVs/Wolves_Away_T.csv")
#Read in CSVs
wolves_home = pd.read_csv(wolves_home_p)
wolves_home_t = pd.read_csv(wolves_home_p_t)
wolves_away = pd.read_csv(wolves_away_p)
wolves_away_t = pd.read_csv(wolves_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
wolves_home= wolves_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_home_t = wolves_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_away = wolves_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_away_t = wolves_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
wolves_home = wolves_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_home_t = wolves_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_away = wolves_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_away_t = wolves_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
wvh_y_train = wolves_home['Result']
wvh_X_train = wolves_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
wvh_y_test = wolves_home_t['Result']
wvh_X_test = wolves_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(wvh_X_train, wvh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(wvh_X_train, wvh_y_train)}")
print(f"Testing Data Score: {classifier.score(wvh_X_test, wvh_y_test)}")
# Out:
# Training Data Score: 0.8363636363636363
# Testing Data Score: 0.9411764705882353

# %%
predictions = classifier.predict(wvh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": wvh_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 8/25/2019  Wolves   Burnley                    0       0
# 9/14/2019  Wolves   Chelsea                    1       1
# 9/28/2019  Wolves   Watford                    0       0
# 10/19/2019 Wolves   Southampton                1       1
# 10/11/2019 Wolves   Aston Villa                0       0
# 1/12/2019  Wolves   Sheffield United           1       1
# 4/12/2019  Wolves   West Ham                   0       0
# 12/15/2019 Wolves   Tottenham                  1       1
# 12/27/2019 Wolves   Man City                   0       0
# 11/1/2020  Wolves   Newcastle                  0       0
# 1/23/2020  Wolves   Liverpool                  0       0
# 2/14/2020  Wolves   Leicester                  1       1
# 2/23/2020  Wolves   Norwich                    0       0
# 7/3/2020   Wolves   Brighton                   0       1
# 6/24/2020  Wolves   Bournemouth                0       0
# 4/7/2020   Wolves   Arsenal                    1       1
# 12/7/2020  Wolves   Everton                    1       1

# %%
#Declare Dependent/Independent Variables
wva_y_train = wolves_away['Result']
wva_X_train = wolves_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
wva_y_test = wolves_away_t['Result']
wva_X_test = wolves_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(wva_X_train, wva_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(wva_X_train, wvh_y_train)}")
print(f"Testing Data Score: {classifier.score(wva_X_test, wvh_y_test)}")
# Out:
# Training Data Score: 0.34545454545454546
# Testing Data Score: 0.47058823529411764

# %%
predictions = classifier.predict(wva_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": wva_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam         AwayTeam
# 1/9/2019   Everton          Wolves             1       0
# 9/22/2019  Crystal Palace   Wolves             0       0
# 6/10/2019  Man City         Wolves             1       0
# 10/27/2019 Newcastle        Wolves             0       0
# 2/11/2019  Arsenal          Wolves             0       0
# 11/23/2019 Bournemouth      Wolves             1       0
# 8/12/2019  Brighton         Wolves             0       0
# 12/21/2019 Norwich          Wolves             1       1
# 12/29/2019 Liverpool        Wolves             1       1
# 1/1/2020   Watford          Wolves             0       0
# 1/18/2020  Southampton      Wolves             0       0
# 1/2/2020   Man United       Wolves             0       0
# 1/3/2020   Tottenham        Wolves             0       0
# 6/20/2020  West Ham         Wolves             0       0
# 6/27/2020  Aston Villa      Wolves             1       1
# 8/7/2020   Sheffield United Wolves             1       0
# 7/15/2020  Burnley          Wolves             0       1
