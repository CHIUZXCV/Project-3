# %%
# Import dependent libraries
# JSON to interpret the API's response
# Requests to send GET requests to server
# Pandas to clean & analyze raw data

import json
import requests
import pandas as pd

# Credentials necessary to access API

headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "063a86c9f9ff41c06288c479fae7e244"
    }

# utilize season year and league id to request data
'''
39 - EPL
135 - Serie A
'''

r = requests.get('https://v3.football.api-sports.io/fixtures?season=2015&league=39', headers=headers)

# %%
'''
Save the number of responses in a variable so it may be used to in a for-loop 
for the exact number of fixtures
'''

number_of_responses = r.json()['results']

# %%
team_request = requests.get('https://v3.football.api-sports.io/teams?season=2015&league=39', headers=headers)
teams = []

for i in range(20):
    teams.append(team_request.json()['response'][i]['team']['name'])

team_1 = teams[0]
team_2 = teams[1]
team_3 = teams[2]
team_4 = teams[3]
team_5 = teams[4]
team_6 = teams[5]
team_7 = teams[6]
team_8 = teams[7]
team_9 = teams[8]
team_10 = teams[9]
team_11 = teams[10]
team_12 = teams[11]
team_13 = teams[12]
team_14 = teams[13]
team_15 = teams[14]
team_16 = teams[15]
team_17 = teams[16]
team_18 = teams[17]
team_19 = teams[18]
team_20 = teams[19]

# %%
d = []

for i in range(50):
    if r.json()['response'][i]['teams']['home']['winner'] == True:
        d.append(
        {
            'date': r.json()['response'][i]['fixture']['date'],
            'fixture_id': r.json()['response'][i]['fixture']['id'],
            'home_team': r.json()['response'][i]['teams']['home']['name'],
            'away_team': r.json()['response'][i]['teams']['away']['name'],
            'home_goals': r.json()['response'][i]['goals']['home'],
            'away_goals': r.json()['response'][i]['goals']['away'],
            'result': 1
        }
    )
    elif r.json()['response'][i]['teams']['home']['winner'] == False:
        d.append(
        {
            'date': r.json()['response'][i]['fixture']['date'],
            'fixture_id': r.json()['response'][i]['fixture']['id'],
            'home_team': r.json()['response'][i]['teams']['home']['name'],
            'away_team': r.json()['response'][i]['teams']['away']['name'],
            'home_goals': r.json()['response'][i]['goals']['home'],
            'away_goals': r.json()['response'][i]['goals']['away'],
            'result': -1
        }
    )
    else:
        d.append(
        {
            'date': r.json()['response'][i]['fixture']['date'],
            'fixture_id': r.json()['response'][i]['fixture']['id'],
            'home_team': r.json()['response'][i]['teams']['home']['name'],
            'away_team': r.json()['response'][i]['teams']['away']['name'],
            'home_goals': r.json()['response'][i]['goals']['home'],
            'away_goals': r.json()['response'][i]['goals']['away'],
            'result': 0
        }
    )
data_2015 = pd.DataFrame(d)
data_2015.set_index('date', inplace=True)

# %%
data_2015
# Out:
#                            fixture_id          home_team          away_team  \
# date
# 2015-08-08T11:45:00+00:00      192297  Manchester United          Tottenham
# 2015-08-08T14:00:00+00:00      192298        Bournemouth        Aston Villa
# 2015-08-08T14:00:00+00:00      192299            Norwich     Crystal Palace
# 2015-08-08T14:00:00+00:00      192300          Leicester         Sunderland
# 2015-08-08T14:00:00+00:00      192301            Everton            Watford
# 2015-08-08T16:30:00+00:00      192302            Chelsea            Swansea
# 2015-08-09T12:30:00+00:00      192303          Newcastle        Southampton
# 2015-08-09T12:30:00+00:00      192304            Arsenal           West Ham
# 2015-08-09T15:00:00+00:00      192305         Stoke City          Liverpool
# 2015-08-10T19:00:00+00:00      192306          West Brom    Manchester City
# 2015-08-14T18:45:00+00:00      192307        Aston Villa  Manchester United
# 2015-08-15T11:45:00+00:00      192308        Southampton            Everton
# 2015-08-15T14:00:00+00:00      192309           West Ham          Leicester
# 2015-08-15T14:00:00+00:00      192310            Swansea          Newcastle
# 2015-08-15T14:00:00+00:00      192311         Sunderland            Norwich
# 2015-08-15T14:00:00+00:00      192312          Tottenham         Stoke City
# 2015-08-15T14:00:00+00:00      192313            Watford          West Brom
# 2015-08-16T12:30:00+00:00      192314     Crystal Palace            Arsenal
# 2015-08-16T15:00:00+00:00      192315    Manchester City            Chelsea
# 2015-08-17T19:00:00+00:00      192316          Liverpool        Bournemouth
# 2015-08-22T11:45:00+00:00      192317  Manchester United          Newcastle
# 2015-08-22T14:00:00+00:00      192318     Crystal Palace        Aston Villa
# 2015-08-22T14:00:00+00:00      192319           West Ham        Bournemouth
# 2015-08-22T14:00:00+00:00      192320            Norwich         Stoke City
# 2015-08-22T14:00:00+00:00      192321         Sunderland            Swansea
# 2015-08-22T14:00:00+00:00      192322          Leicester          Tottenham
# 2015-08-23T12:30:00+00:00      192323          West Brom            Chelsea
# 2015-08-23T15:00:00+00:00      192324            Everton    Manchester City
# 2015-08-23T15:00:00+00:00      192325            Watford        Southampton
# 2015-08-24T19:00:00+00:00      192326            Arsenal          Liverpool
# 2015-08-29T11:45:00+00:00      192327          Newcastle            Arsenal
# 2015-08-29T14:00:00+00:00      192328            Chelsea     Crystal Palace
# 2015-08-29T14:00:00+00:00      192329        Bournemouth          Leicester
# 2015-08-29T14:00:00+00:00      192330        Aston Villa         Sunderland
# 2015-08-29T14:00:00+00:00      192331    Manchester City            Watford
# 2015-08-29T14:00:00+00:00      192332         Stoke City          West Brom
# 2015-08-29T14:00:00+00:00      192333          Liverpool           West Ham
# 2015-08-29T16:30:00+00:00      192334          Tottenham            Everton
# 2015-08-30T12:30:00+00:00      192335        Southampton            Norwich
# 2015-08-30T15:00:00+00:00      192336            Swansea  Manchester United
# 2015-09-12T11:45:00+00:00      192337            Everton            Chelsea
# 2015-09-12T14:00:00+00:00      192338            Norwich        Bournemouth
# 2015-09-12T14:00:00+00:00      192339     Crystal Palace    Manchester City
# 2015-09-12T14:00:00+00:00      192340          West Brom        Southampton
# 2015-09-12T14:00:00+00:00      192341            Arsenal         Stoke City
# 2015-09-12T14:00:00+00:00      192342            Watford            Swansea
# 2015-09-12T16:30:00+00:00      192343  Manchester United          Liverpool
# 2015-09-13T12:30:00+00:00      192344         Sunderland          Tottenham
# 2015-09-13T15:00:00+00:00      192345          Leicester        Aston Villa
# 2015-09-14T19:00:00+00:00      192346           West Ham          Newcastle
#
#                            home_goals  away_goals  result
# date
# 2015-08-08T11:45:00+00:00           1           0       1
# 2015-08-08T14:00:00+00:00           0           1      -1
# 2015-08-08T14:00:00+00:00           1           3      -1
# 2015-08-08T14:00:00+00:00           4           2       1
# 2015-08-08T14:00:00+00:00           2           2       0
# 2015-08-08T16:30:00+00:00           2           2       0
# 2015-08-09T12:30:00+00:00           2           2       0
# 2015-08-09T12:30:00+00:00           0           2      -1
# 2015-08-09T15:00:00+00:00           0           1      -1
# 2015-08-10T19:00:00+00:00           0           3      -1
# 2015-08-14T18:45:00+00:00           0           1      -1
# 2015-08-15T11:45:00+00:00           0           3      -1
# 2015-08-15T14:00:00+00:00           1           2      -1
# 2015-08-15T14:00:00+00:00           2           0       1
# 2015-08-15T14:00:00+00:00           1           3      -1
# 2015-08-15T14:00:00+00:00           2           2       0
# 2015-08-15T14:00:00+00:00           0           0       0
# 2015-08-16T12:30:00+00:00           1           2      -1
# 2015-08-16T15:00:00+00:00           3           0       1
# 2015-08-17T19:00:00+00:00           1           0       1
# 2015-08-22T11:45:00+00:00           0           0       0
# 2015-08-22T14:00:00+00:00           2           1       1
# 2015-08-22T14:00:00+00:00           3           4      -1
# 2015-08-22T14:00:00+00:00           1           1       0
# 2015-08-22T14:00:00+00:00           1           1       0
# 2015-08-22T14:00:00+00:00           1           1       0
# 2015-08-23T12:30:00+00:00           2           3      -1
# 2015-08-23T15:00:00+00:00           0           2      -1
# 2015-08-23T15:00:00+00:00           0           0       0
# 2015-08-24T19:00:00+00:00           0           0       0
# 2015-08-29T11:45:00+00:00           0           1      -1
# 2015-08-29T14:00:00+00:00           1           2      -1
# 2015-08-29T14:00:00+00:00           1           1       0
# 2015-08-29T14:00:00+00:00           2           2       0
# 2015-08-29T14:00:00+00:00           2           0       1
# 2015-08-29T14:00:00+00:00           0           1      -1
# 2015-08-29T14:00:00+00:00           0           3      -1
# 2015-08-29T16:30:00+00:00           0           0       0
# 2015-08-30T12:30:00+00:00           3           0       1
# 2015-08-30T15:00:00+00:00           2           1       1
# 2015-09-12T11:45:00+00:00           3           1       1
# 2015-09-12T14:00:00+00:00           3           1       1
# 2015-09-12T14:00:00+00:00           0           1      -1
# 2015-09-12T14:00:00+00:00           0           0       0
# 2015-09-12T14:00:00+00:00           2           0       1
# 2015-09-12T14:00:00+00:00           1           0       1
# 2015-09-12T16:30:00+00:00           3           1       1
# 2015-09-13T12:30:00+00:00           0           1      -1
# 2015-09-13T15:00:00+00:00           3           2       1
# 2015-09-14T19:00:00+00:00           2           0       1

# %%
if stats.json()['response'] == []:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
# Initialize empty lists to be used in a for-loop that will fill the home team's data

home_shots_on_goal = []
home_shots_off_goal = []
home_total_shots = []
home_blocked_shots = []
home_shots_insidebox = []
home_shots_outsidebox = []
home_fouls = []
home_cornerkicks = []
home_offsides = []
home_possession = []
home_yellowcards = []
home_redcards = []
home_gk_saves = []
home_pass_percentage = []

# Initialize empty lists to be used in a for-loop that will fill the away team's data

away_shots_on_goal = []
away_shots_off_goal = []
away_total_shots = []
away_blocked_shots = []
away_shots_insidebox = []
away_shots_outsidebox = []
away_fouls = []
away_cornerkicks = []
away_offsides = []
away_possession = []
away_yellowcards = []
away_redcards = []
away_gk_saves = []
away_pass_percentage = []

# for-loop that request statistics for each fixture in a season and stores it in
# the corresponding list

for i in data_2015['fixture_id']:
    stats = requests.get(f"https://v3.football.api-sports.io/fixtures/statistics?fixture={i}", headers=headers)
    if stats.json()['response'][0]['statistics'][0]['value'] == None:
        home_shots_on_goal.append(0)
    else:
        home_shots_on_goal.append(stats.json()['response'][0]['statistics'][0]['value'])
    if stats.json()['response'][0]['statistics'][1]['value'] == None:
        home_shots_off_goal.append(0)
    else:
        home_shots_off_goal.append(stats.json()['response'][0]['statistics'][1]['value'])
    if stats.json()['response'][0]['statistics'][2]['value'] == None:
        home_total_shots.append(0)
    else:
        home_total_shots.append(stats.json()['response'][0]['statistics'][2]['value'])
    if stats.json()['response'][0]['statistics'][3]['value'] == None:
        home_blocked_shots.append(0)
    else:
        home_blocked_shots.append(stats.json()['response'][0]['statistics'][3]['value'])
    if stats.json()['response'][0]['statistics'][4]['value'] == None:
        home_shots_insidebox.append(0)
    else:
        home_shots_insidebox.append(stats.json()['response'][0]['statistics'][4]['value'])
    if stats.json()['response'][0]['statistics'][5]['value'] == None:
        home_shots_outsidebox.append(0)
    else:
        home_shots_outsidebox.append(stats.json()['response'][0]['statistics'][5]['value'])
    if stats.json()['response'][0]['statistics'][6]['value'] == None:
        home_fouls.append(0)
    else:
        home_fouls.append(stats.json()['response'][0]['statistics'][6]['value'])
    if stats.json()['response'][0]['statistics'][7]['value'] == None:
        home_cornerkicks.append(0)
    else:
        home_cornerkicks.append(stats.json()['response'][0]['statistics'][7]['value'])
    if stats.json()['response'][0]['statistics'][8]['value'] == None:
        home_offsides.append(0)
    else:
        home_offsides.append(stats.json()['response'][0]['statistics'][8]['value'])
    home_possession.append(float(stats.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01)
    if stats.json()['response'][0]['statistics'][10]['value'] == None:
        home_yellowcards.append(0)
    else:
        home_yellowcards.append(stats.json()['response'][0]['statistics'][10]['value'])
    if stats.json()['response'][0]['statistics'][11]['value'] == None:
        home_redcards.append(0)
    else:
        home_redcards.append(stats.json()['response'][0]['statistics'][11]['value'])
    if stats.json()['response'][0]['statistics'][12]['value'] == None:
        home_gk_saves.append(0)
    else:
        home_gk_saves.append(stats.json()['response'][0]['statistics'][12]['value'])
    home_pass_percentage.append(stats.json()['response'][0]['statistics'][14]['value'] / stats.json()['response'][0]['statistics'][13]['value'])

# Continue loop for away team
    
    if stats.json()['response'][1]['statistics'][0]['value'] == None:
        away_shots_on_goal.append(0)
    else:
        away_shots_on_goal.append(stats.json()['response'][1]['statistics'][0]['value'])
    if stats.json()['response'][1]['statistics'][1]['value'] == None:
        away_shots_off_goal.append(0)
    else:
        away_shots_off_goal.append(stats.json()['response'][1]['statistics'][1]['value'])
    if stats.json()['response'][1]['statistics'][2]['value'] == None:
        away_total_shots.append(0)
    else:
        away_total_shots.append(stats.json()['response'][1]['statistics'][2]['value'])
    if stats.json()['response'][1]['statistics'][3]['value'] == None:
        away_blocked_shots.append(0)
    else:
        away_blocked_shots.append(stats.json()['response'][1]['statistics'][3]['value'])
    if stats.json()['response'][1]['statistics'][4]['value'] == None:
        away_shots_insidebox.append(0)
    else:
        away_shots_insidebox.append(stats.json()['response'][1]['statistics'][4]['value'])
    if stats.json()['response'][1]['statistics'][5]['value'] == None:
        away_shots_outsidebox.append(0)
    else:
        away_shots_outsidebox.append(stats.json()['response'][1]['statistics'][5]['value'])
    if stats.json()['response'][1]['statistics'][6]['value'] == None:
        away_fouls.append(0)
    else:
        away_fouls.append(stats.json()['response'][1]['statistics'][6]['value'])
    if stats.json()['response'][1]['statistics'][7]['value'] == None:
        away_cornerkicks.append(0)
    else:
        away_cornerkicks.append(stats.json()['response'][1]['statistics'][7]['value'])
    if stats.json()['response'][1]['statistics'][8]['value'] == None:
        away_offsides.append(0)
    else:
        away_offsides.append(stats.json()['response'][1]['statistics'][8]['value'])
    away_possession.append(float(stats.json()['response'][1]['statistics'][9]['value'].strip('%')) * 0.01)
    if stats.json()['response'][1]['statistics'][10]['value'] == None:
        away_yellowcards.append(0)
    else:
        away_yellowcards.append(stats.json()['response'][1]['statistics'][10]['value'])
    if stats.json()['response'][1]['statistics'][11]['value'] == None:
        away_redcards.append(0)
    else:
        away_redcards.append(stats.json()['response'][1]['statistics'][11]['value'])
    if stats.json()['response'][1]['statistics'][12]['value'] == None:
        away_gk_saves.append(0)
    else:
        away_gk_saves.append(stats.json()['response'][1]['statistics'][12]['value'])
    away_pass_percentage.append(stats.json()['response'][1]['statistics'][14]['value'] / stats.json()['response'][1]['statistics'][13]['value'])
    

# Add columnds of home team data to the season's dataframe

data_2015['home_shots_on_goal'] = home_shots_on_goal
data_2015['home_shots_off_goal'] = home_shots_off_goal
data_2015['home_total_shots'] = home_total_shots
data_2015['home_blocked_shots'] = home_blocked_shots
data_2015['home_shots_insidebox'] = home_shots_insidebox
data_2015['home_shots_outsidebox'] = home_shots_outsidebox
data_2015['home_fouls'] = home_fouls
data_2015['home_cornerkicks'] = home_cornerkicks
data_2015['home_offsides'] = home_offsides
data_2015['home_possession'] = home_possession
data_2015['home_yellowcards'] = home_yellowcards
data_2015['home_redcards'] = home_redcards
data_2015['home_gk_saves'] = home_gk_saves
data_2015['home_pass_percentage'] = home_pass_percentage

# Add columnds of away team data to the season's data frame

data_2015['away_shots_on_goal'] = away_shots_on_goal
data_2015['away_shots_off_goal'] = away_shots_off_goal
data_2015['away_total_shots'] = away_total_shots
data_2015['away_blocked_shots'] = away_blocked_shots
data_2015['away_shots_insidebox'] = away_shots_insidebox
data_2015['away_shots_outsidebox'] = away_shots_outsidebox
data_2015['away_fouls'] = away_fouls
data_2015['away_cornerkicks'] = away_cornerkicks
data_2015['away_offsides'] = away_offsides
data_2015['away_possession'] = away_possession
data_2015['away_yellowcards'] = away_yellowcards
data_2015['away_redcards'] = away_redcards
data_2015['away_gk_saves'] = away_gk_saves
data_2015['away_pass_percentage'] = away_pass_percentage
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-a67caf841bd4> in <module>
#      38 for i in data_2015['fixture_id']:
#      39     stats = requests.get(f"https://v3.football.api-sports.io/fixtures/statistics?fixture={i}", headers=headers)
# ---> 40     if stats.json()['response'][0]['statistics'][0]['value'] == None:
#      41         home_shots_on_goal.append(0)
#      42     else:
#
# IndexError: list index out of range

# %%
data_2015.head()
# Out:
#                            fixture_id away_team  away_goals  \
# date
# 2015-08-22T16:00:00+00:00      196403   AS Roma           1
# 2015-08-22T18:45:00+00:00      196404   Bologna           1
# 2015-08-23T16:00:00+00:00      196405   Udinese           1
# 2015-08-23T18:45:00+00:00      196406    Chievo           3
# 2015-08-23T18:45:00+00:00      196407  AC Milan           0
#
#                            home_shots_on_goal  home_shots_off_goal  \
# date
# 2015-08-22T16:00:00+00:00                   7                    4
# 2015-08-22T18:45:00+00:00                   9                    7
# 2015-08-23T16:00:00+00:00                   5                   10
# 2015-08-23T18:45:00+00:00                   4                    5
# 2015-08-23T18:45:00+00:00                   7                    3
#
#                            home_total_shots  home_blocked_shots  \
# date
# 2015-08-22T16:00:00+00:00                12                   1
# 2015-08-22T18:45:00+00:00                21                   5
# 2015-08-23T16:00:00+00:00                21                   6
# 2015-08-23T18:45:00+00:00                14                   5
# 2015-08-23T18:45:00+00:00                13                   3
#
#                            home_shots_insidebox  home_shots_outsidebox  \
# date
# 2015-08-22T16:00:00+00:00                     8                      4
# 2015-08-22T18:45:00+00:00                     9                     12
# 2015-08-23T16:00:00+00:00                    12                      9
# 2015-08-23T18:45:00+00:00                     9                      5
# 2015-08-23T18:45:00+00:00                     6                      7
#
#                            home_fouls  ...  away_shots_insidebox  \
# date                                   ...
# 2015-08-22T16:00:00+00:00           0  ...                    10
# 2015-08-22T18:45:00+00:00           0  ...                     5
# 2015-08-23T16:00:00+00:00           0  ...                     5
# 2015-08-23T18:45:00+00:00           0  ...                     9
# 2015-08-23T18:45:00+00:00           0  ...                     6
#
#                            away_shots_outsidebox  away_fouls  \
# date
# 2015-08-22T16:00:00+00:00                     10           0
# 2015-08-22T18:45:00+00:00                      4           0
# 2015-08-23T16:00:00+00:00                      1           0
# 2015-08-23T18:45:00+00:00                      3           0
# 2015-08-23T18:45:00+00:00                      3           0
#
#                            away_cornerkicks  away_offsides  away_possession  \
# date
# 2015-08-22T16:00:00+00:00                 7              2             0.68
# 2015-08-22T18:45:00+00:00                 3              4             0.44
# 2015-08-23T16:00:00+00:00                 2              0             0.34
# 2015-08-23T18:45:00+00:00                 5              4             0.43
# 2015-08-23T18:45:00+00:00                 5              4             0.42
#
#                            away_yellowcards  away_redcards  away_gk_saves  \
# date
# 2015-08-22T16:00:00+00:00                 1              0              5
# 2015-08-22T18:45:00+00:00                 1              0              8
# 2015-08-23T16:00:00+00:00                 3              0              5
# 2015-08-23T18:45:00+00:00                 2              0              4
# 2015-08-23T18:45:00+00:00                 4              1              5
#
#                            away_pass_percentage
# date
# 2015-08-22T16:00:00+00:00              0.852050
# 2015-08-22T18:45:00+00:00              0.749415
# 2015-08-23T16:00:00+00:00              0.676259
# 2015-08-23T18:45:00+00:00              0.720109
# 2015-08-23T18:45:00+00:00              0.787535
#
# [5 rows x 31 columns]
