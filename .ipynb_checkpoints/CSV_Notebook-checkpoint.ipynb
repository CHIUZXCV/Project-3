# %%
# Import dependent libraries
# JSON to interpret the API's response
# Requests to send GET requests to server
# Pandas to clean & analyze raw data

import json
import requests
import pandas as pd
import numpy as np

# Credentials necessary to access API

headers = {
    'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "063a86c9f9ff41c06288c479fae7e244"
    }

# utilize season year and league id to request data
'''
39 - EPL
135 - Serie A
'''

leagueMap = {"EPL",39}
TeamMap = {"EPL":["Arsenal","Leeds"]}

# %%
from pathlib import Path

file_path_train = Path("RESOURCES/train.csv")
file_path_test = Path("RESOURCES/test.csv")

train_df = pd.read_csv(file_path_train, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True) 
test_df = pd.read_csv(file_path_test, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %%
'''
Save the number of responses in a variable so it may be used to in a for-loop 
for the exact number of fixtures
'''
# Out:
# '\nSave the number of responses in a variable so it may be used to in a for-loop \nfor the exact number of fixtures\n'

# %%
team_request = requests.get('https://v3.football.api-sports.io/teams?season=2015&league=39', headers=headers)
teams = []

for i in range(20):
    teams.append(team_request.json()['response'][i]['team']['name'])

team_1 = teams[0]
team_2 = teams[1]
team_3 = teams[2]
team_4 = teams[3]
team_5 = teams[4]
team_6 = teams[5]
team_7 = teams[6]
team_8 = teams[7]
team_9 = teams[8]
team_10 = teams[9]
team_11 = teams[10]
team_12 = teams[11]
team_13 = teams[12]
team_14 = teams[13]
team_15 = teams[14]
team_16 = teams[15]
team_17 = teams[16]
team_18 = teams[17]
team_19 = teams[18]
team_20 = teams[19]

# %% [markdown]
# # Create Test/Train DataFrames

# %%
d = []
a = []
train_years = [2015, 2016, 2017, 2018]
test_years = [2019]

for i in train_years:
    r = requests.get(f'https://v3.football.api-sports.io/fixtures?season={i}&league=39', headers=headers)
    number_responses = r.json()['results']

    for i in range(380):
        if r.json()['response'][i]['teams']['home']['winner'] == True:
            d.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': 1
            }
        )
        elif r.json()['response'][i]['teams']['home']['winner'] == False:
            d.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': -1
            }
        )
        else:
            d.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': 0
            }
        )
            
for i in test_years:
    r = requests.get(f'https://v3.football.api-sports.io/fixtures?season={i}&league=39', headers=headers)
    number_responses = r.json()['results']

    for i in range(380):
        if r.json()['response'][i]['teams']['home']['winner'] == True:
            a.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': 1
            }
        )
        elif r.json()['response'][i]['teams']['home']['winner'] == False:
            a.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': -1
            }
        )
        else:
            a.append(
            {
                'date': r.json()['response'][i]['fixture']['date'],
                'fixture_id': r.json()['response'][i]['fixture']['id'],
                'home_team': r.json()['response'][i]['teams']['home']['name'],
                'away_team': r.json()['response'][i]['teams']['away']['name'],
                'home_goals': r.json()['response'][i]['goals']['home'],
                'away_goals': r.json()['response'][i]['goals']['away'],
                'result': 0
            }
        )

train_df = pd.DataFrame(d)
train_df.set_index('date', inplace=True)

test_df = pd.DataFrame(a)
test_df.set_index('date', inplace=True)

# %%
# Initialize empty lists to be used in a for-loop that will fill the home team's data

home_shots_on_goal = []
home_shots_off_goal = []
home_total_shots = []
home_blocked_shots = []
home_shots_insidebox = []
home_shots_outsidebox = []
home_fouls = []
home_cornerkicks = []
home_offsides = []
home_possession = []
home_yellowcards = []
home_redcards = []
home_gk_saves = []
home_pass_percentage = []

# Initialize empty lists to be used in a for-loop that will fill the away team's data

away_shots_on_goal = []
away_shots_off_goal = []
away_total_shots = []
away_blocked_shots = []
away_shots_insidebox = []
away_shots_outsidebox = []
away_fouls = []
away_cornerkicks = []
away_offsides = []
away_possession = []
away_yellowcards = []
away_redcards = []
away_gk_saves = []
away_pass_percentage = []

# for-loop that request statistics for each fixture in a season and stores it in
# the corresponding list

for i in train_df['fixture_id']:
    stats = requests.get(f"https://v3.football.api-sports.io/fixtures/statistics?fixture={i}", headers=headers)
    if stats.json()['response'] != []:
        if stats.json()['response'][0]['statistics'][0]['value'] == None:
            home_shots_on_goal.append(0)
        else:
            home_shots_on_goal.append(stats.json()['response'][0]['statistics'][0]['value'])
        if stats.json()['response'][0]['statistics'][1]['value'] == None:
            home_shots_off_goal.append(0)
        else:
            home_shots_off_goal.append(stats.json()['response'][0]['statistics'][1]['value'])
        if stats.json()['response'][0]['statistics'][2]['value'] == None:
            home_total_shots.append(0)
        else:
            home_total_shots.append(stats.json()['response'][0]['statistics'][2]['value'])
        if stats.json()['response'][0]['statistics'][3]['value'] == None:
            home_blocked_shots.append(0)
        else:
            home_blocked_shots.append(stats.json()['response'][0]['statistics'][3]['value'])
        if stats.json()['response'][0]['statistics'][4]['value'] == None:
            home_shots_insidebox.append(0)
        else:
            home_shots_insidebox.append(stats.json()['response'][0]['statistics'][4]['value'])
        if stats.json()['response'][0]['statistics'][5]['value'] == None:
            home_shots_outsidebox.append(0)
        else:
            home_shots_outsidebox.append(stats.json()['response'][0]['statistics'][5]['value'])
        if stats.json()['response'][0]['statistics'][6]['value'] == None:
            home_fouls.append(0)
        else:
            home_fouls.append(stats.json()['response'][0]['statistics'][6]['value'])
        if stats.json()['response'][0]['statistics'][7]['value'] == None:
            home_cornerkicks.append(0)
        else:
            home_cornerkicks.append(stats.json()['response'][0]['statistics'][7]['value'])
        if stats.json()['response'][0]['statistics'][8]['value'] == None:
            home_offsides.append(0)
        else:
            home_offsides.append(stats.json()['response'][0]['statistics'][8]['value'])
        home_possession.append(float(stats.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01)
        if stats.json()['response'][0]['statistics'][10]['value'] == None:
            home_yellowcards.append(0)
        else:
            home_yellowcards.append(stats.json()['response'][0]['statistics'][10]['value'])
        if stats.json()['response'][0]['statistics'][11]['value'] == None:
            home_redcards.append(0)
        else:
            home_redcards.append(stats.json()['response'][0]['statistics'][11]['value'])
        if stats.json()['response'][0]['statistics'][12]['value'] == None:
            home_gk_saves.append(0)
        else:
            home_gk_saves.append(stats.json()['response'][0]['statistics'][12]['value'])
        home_pass_percentage.append(stats.json()['response'][0]['statistics'][14]['value'] / stats.json()['response'][0]['statistics'][13]['value'])

# Continue loop for away team
    
        if stats.json()['response'][1]['statistics'][0]['value'] == None:
            away_shots_on_goal.append(0)
        else:
            away_shots_on_goal.append(stats.json()['response'][1]['statistics'][0]['value'])
        if stats.json()['response'][1]['statistics'][1]['value'] == None:
            away_shots_off_goal.append(0)
        else:
            away_shots_off_goal.append(stats.json()['response'][1]['statistics'][1]['value'])
        if stats.json()['response'][1]['statistics'][2]['value'] == None:
            away_total_shots.append(0)
        else:
            away_total_shots.append(stats.json()['response'][1]['statistics'][2]['value'])
        if stats.json()['response'][1]['statistics'][3]['value'] == None:
            away_blocked_shots.append(0)
        else:
            away_blocked_shots.append(stats.json()['response'][1]['statistics'][3]['value'])
        if stats.json()['response'][1]['statistics'][4]['value'] == None:
            away_shots_insidebox.append(0)
        else:
            away_shots_insidebox.append(stats.json()['response'][1]['statistics'][4]['value'])
        if stats.json()['response'][1]['statistics'][5]['value'] == None:
            away_shots_outsidebox.append(0)
        else:
            away_shots_outsidebox.append(stats.json()['response'][1]['statistics'][5]['value'])
        if stats.json()['response'][1]['statistics'][6]['value'] == None:
            away_fouls.append(0)
        else:
            away_fouls.append(stats.json()['response'][1]['statistics'][6]['value'])
        if stats.json()['response'][1]['statistics'][7]['value'] == None:
            away_cornerkicks.append(0)
        else:
            away_cornerkicks.append(stats.json()['response'][1]['statistics'][7]['value'])
        if stats.json()['response'][1]['statistics'][8]['value'] == None:
            away_offsides.append(0)
        else:
            away_offsides.append(stats.json()['response'][1]['statistics'][8]['value'])
        away_possession.append(float(stats.json()['response'][1]['statistics'][9]['value'].strip('%')) * 0.01)
        if stats.json()['response'][1]['statistics'][10]['value'] == None:
            away_yellowcards.append(0)
        else:
            away_yellowcards.append(stats.json()['response'][1]['statistics'][10]['value'])
        if stats.json()['response'][1]['statistics'][11]['value'] == None:
            away_redcards.append(0)
        else:
            away_redcards.append(stats.json()['response'][1]['statistics'][11]['value'])
        if stats.json()['response'][1]['statistics'][12]['value'] == None:
            away_gk_saves.append(0)
        else:
            away_gk_saves.append(stats.json()['response'][1]['statistics'][12]['value'])
        away_pass_percentage.append(stats.json()['response'][1]['statistics'][14]['value'] / stats.json()['response'][1]['statistics'][13]['value'])
    else:
        home_shots_on_goal.append(np.nan)
        home_shots_off_goal.append(np.nan)
        home_total_shots.append(np.nan)
        home_blocked_shots.append(np.nan)
        home_shots_insidebox.append(np.nan)
        home_shots_outsidebox.append(np.nan)
        home_fouls.append(np.nan)
        home_cornerkicks.append(np.nan)
        home_offsides.append(np.nan)
        home_possession.append(np.nan)
        home_yellowcards.append(np.nan)
        home_redcards.append(np.nan)
        home_gk_saves.append(np.nan)
        home_pass_percentage.append(np.nan)
        away_shots_on_goal.append(np.nan)
        away_shots_off_goal.append(np.nan)
        away_total_shots.append(np.nan)
        away_blocked_shots.append(np.nan)
        away_shots_insidebox.append(np.nan)
        away_shots_outsidebox.append(np.nan)
        away_fouls.append(np.nan)
        away_cornerkicks.append(np.nan)
        away_offsides.append(np.nan)
        away_possession.append(np.nan)
        away_yellowcards.append(np.nan)
        away_redcards.append(np.nan)
        away_gk_saves.append(np.nan)
        away_pass_percentage.append(np.nan)
    

# Add columnds of home team data to the season's dataframe

train_df['home_shots_on_goal'] = home_shots_on_goal
train_df['home_shots_off_goal'] = home_shots_off_goal
train_df['home_total_shots'] = home_total_shots
train_df['home_blocked_shots'] = home_blocked_shots
train_df['home_shots_insidebox'] = home_shots_insidebox
train_df['home_shots_outsidebox'] = home_shots_outsidebox
train_df['home_fouls'] = home_fouls
train_df['home_cornerkicks'] = home_cornerkicks
train_df['home_offsides'] = home_offsides
train_df['home_possession'] = home_possession
train_df['home_yellowcards'] = home_yellowcards
train_df['home_redcards'] = home_redcards
train_df['home_gk_saves'] = home_gk_saves
train_df['home_pass_percentage'] = home_pass_percentage

# Add columnds of away team data to the season's data frame

train_df['away_shots_on_goal'] = away_shots_on_goal
train_df['away_shots_off_goal'] = away_shots_off_goal
train_df['away_total_shots'] = away_total_shots
train_df['away_blocked_shots'] = away_blocked_shots
train_df['away_shots_insidebox'] = away_shots_insidebox
train_df['away_shots_outsidebox'] = away_shots_outsidebox
train_df['away_fouls'] = away_fouls
train_df['away_cornerkicks'] = away_cornerkicks
train_df['away_offsides'] = away_offsides
train_df['away_possession'] = away_possession
train_df['away_yellowcards'] = away_yellowcards
train_df['away_redcards'] = away_redcards
train_df['away_gk_saves'] = away_gk_saves
train_df['away_pass_percentage'] = away_pass_percentage

# %%
from pathlib import Path
file_path = Path('../Project-3/train.csv')
train_epl_df = pd.read_csv(file_path, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %% [markdown]
# ## Create Test DataFrame

# %%
# Initialize empty lists to be used in a for-loop that will fill the home team's data

test_home_shots_on_goal = []
test_home_shots_off_goal = []
test_home_total_shots = []
test_home_blocked_shots = []
test_home_shots_insidebox = []
test_home_shots_outsidebox = []
test_home_fouls = []
test_home_cornerkicks = []
test_home_offsides = []
test_home_possession = []
test_home_yellowcards = []
test_home_redcards = []
test_home_gk_saves = []
test_home_pass_percentage = []

# Initialize empty lists to be used in a for-loop that will fill the away team's data

test_away_shots_on_goal = []
test_away_shots_off_goal = []
test_away_total_shots = []
test_away_blocked_shots = []
test_away_shots_insidebox = []
test_away_shots_outsidebox = []
test_away_fouls = []
test_away_cornerkicks = []
test_away_offsides = []
test_away_possession = []
test_away_yellowcards = []
test_away_redcards = []
test_away_gk_saves = []
test_away_pass_percentage = []

# for-loop that request statistics for each fixture in a season and stores it in
# the corresponding list

for i in test_df['fixture_id']:
    stats = requests.get(f"https://v3.football.api-sports.io/fixtures/statistics?fixture={i}", headers=headers)
    if stats.json()['response'] != []:
        if stats.json()['response'][0]['statistics'][0]['value'] == None:
            test_home_shots_on_goal.append(0)
        else:
            test_home_shots_on_goal.append(stats.json()['response'][0]['statistics'][0]['value'])
        if stats.json()['response'][0]['statistics'][1]['value'] == None:
            test_home_shots_off_goal.append(0)
        else:
            test_home_shots_off_goal.append(stats.json()['response'][0]['statistics'][1]['value'])
        if stats.json()['response'][0]['statistics'][2]['value'] == None:
            test_home_total_shots.append(0)
        else:
            test_home_total_shots.append(stats.json()['response'][0]['statistics'][2]['value'])
        if stats.json()['response'][0]['statistics'][3]['value'] == None:
            test_home_blocked_shots.append(0)
        else:
            test_home_blocked_shots.append(stats.json()['response'][0]['statistics'][3]['value'])
        if stats.json()['response'][0]['statistics'][4]['value'] == None:
            test_home_shots_insidebox.append(0)
        else:
            test_home_shots_insidebox.append(stats.json()['response'][0]['statistics'][4]['value'])
        if stats.json()['response'][0]['statistics'][5]['value'] == None:
            test_home_shots_outsidebox.append(0)
        else:
            test_home_shots_outsidebox.append(stats.json()['response'][0]['statistics'][5]['value'])
        if stats.json()['response'][0]['statistics'][6]['value'] == None:
            test_home_fouls.append(0)
        else:
            test_home_fouls.append(stats.json()['response'][0]['statistics'][6]['value'])
        if stats.json()['response'][0]['statistics'][7]['value'] == None:
            test_home_cornerkicks.append(0)
        else:
            test_home_cornerkicks.append(stats.json()['response'][0]['statistics'][7]['value'])
        if stats.json()['response'][0]['statistics'][8]['value'] == None:
            test_home_offsides.append(0)
        else:
            test_home_offsides.append(stats.json()['response'][0]['statistics'][8]['value'])
        test_home_possession.append(float(stats.json()['response'][0]['statistics'][9]['value'].strip('%')) * 0.01)
        if stats.json()['response'][0]['statistics'][10]['value'] == None:
            test_home_yellowcards.append(0)
        else:
            test_home_yellowcards.append(stats.json()['response'][0]['statistics'][10]['value'])
        if stats.json()['response'][0]['statistics'][11]['value'] == None:
            test_home_redcards.append(0)
        else:
            test_home_redcards.append(stats.json()['response'][0]['statistics'][11]['value'])
        if stats.json()['response'][0]['statistics'][12]['value'] == None:
            test_home_gk_saves.append(0)
        else:
            test_home_gk_saves.append(stats.json()['response'][0]['statistics'][12]['value'])
        test_home_pass_percentage.append(stats.json()['response'][0]['statistics'][14]['value'] / stats.json()['response'][0]['statistics'][13]['value'])

# Continue loop for away team
    
        if stats.json()['response'][1]['statistics'][0]['value'] == None:
            test_away_shots_on_goal.append(0)
        else:
            test_away_shots_on_goal.append(stats.json()['response'][1]['statistics'][0]['value'])
        if stats.json()['response'][1]['statistics'][1]['value'] == None:
            test_away_shots_off_goal.append(0)
        else:
            test_away_shots_off_goal.append(stats.json()['response'][1]['statistics'][1]['value'])
        if stats.json()['response'][1]['statistics'][2]['value'] == None:
            test_away_total_shots.append(0)
        else:
            test_away_total_shots.append(stats.json()['response'][1]['statistics'][2]['value'])
        if stats.json()['response'][1]['statistics'][3]['value'] == None:
            test_away_blocked_shots.append(0)
        else:
            test_away_blocked_shots.append(stats.json()['response'][1]['statistics'][3]['value'])
        if stats.json()['response'][1]['statistics'][4]['value'] == None:
            test_away_shots_insidebox.append(0)
        else:
            test_away_shots_insidebox.append(stats.json()['response'][1]['statistics'][4]['value'])
        if stats.json()['response'][1]['statistics'][5]['value'] == None:
            test_away_shots_outsidebox.append(0)
        else:
            test_away_shots_outsidebox.append(stats.json()['response'][1]['statistics'][5]['value'])
        if stats.json()['response'][1]['statistics'][6]['value'] == None:
            test_away_fouls.append(0)
        else:
            test_away_fouls.append(stats.json()['response'][1]['statistics'][6]['value'])
        if stats.json()['response'][1]['statistics'][7]['value'] == None:
            test_away_cornerkicks.append(0)
        else:
            test_away_cornerkicks.append(stats.json()['response'][1]['statistics'][7]['value'])
        if stats.json()['response'][1]['statistics'][8]['value'] == None:
            test_away_offsides.append(0)
        else:
            test_away_offsides.append(stats.json()['response'][1]['statistics'][8]['value'])
        test_away_possession.append(float(stats.json()['response'][1]['statistics'][9]['value'].strip('%')) * 0.01)
        if stats.json()['response'][1]['statistics'][10]['value'] == None:
            test_away_yellowcards.append(0)
        else:
            test_away_yellowcards.append(stats.json()['response'][1]['statistics'][10]['value'])
        if stats.json()['response'][1]['statistics'][11]['value'] == None:
            test_away_redcards.append(0)
        else:
            test_away_redcards.append(stats.json()['response'][1]['statistics'][11]['value'])
        if stats.json()['response'][1]['statistics'][12]['value'] == None:
            test_away_gk_saves.append(0)
        else:
            test_away_gk_saves.append(stats.json()['response'][1]['statistics'][12]['value'])
        test_away_pass_percentage.append(stats.json()['response'][1]['statistics'][14]['value'] / stats.json()['response'][1]['statistics'][13]['value'])
    else:
        test_home_shots_on_goal.append(np.nan)
        test_home_shots_off_goal.append(np.nan)
        test_home_total_shots.append(np.nan)
        test_home_blocked_shots.append(np.nan)
        test_home_shots_insidebox.append(np.nan)
        test_home_shots_outsidebox.append(np.nan)
        test_home_fouls.append(np.nan)
        test_home_cornerkicks.append(np.nan)
        test_home_offsides.append(np.nan)
        test_home_possession.append(np.nan)
        test_home_yellowcards.append(np.nan)
        test_home_redcards.append(np.nan)
        test_home_gk_saves.append(np.nan)
        test_home_pass_percentage.append(np.nan)
        test_away_shots_on_goal.append(np.nan)
        test_away_shots_off_goal.append(np.nan)
        test_away_total_shots.append(np.nan)
        test_away_blocked_shots.append(np.nan)
        test_away_shots_insidebox.append(np.nan)
        test_away_shots_outsidebox.append(np.nan)
        test_away_fouls.append(np.nan)
        test_away_cornerkicks.append(np.nan)
        test_away_offsides.append(np.nan)
        test_away_possession.append(np.nan)
        test_away_yellowcards.append(np.nan)
        test_away_redcards.append(np.nan)
        test_away_gk_saves.append(np.nan)
        test_away_pass_percentage.append(np.nan)
    

# Add columnds of home team data to the season's dataframe

test_df['test_home_shots_on_goal'] = test_home_shots_on_goal
test_df['test_home_shots_off_goal'] = test_home_shots_off_goal
test_df['test_home_total_shots'] = test_home_total_shots
test_df['test_home_blocked_shots'] = test_home_blocked_shots
test_df['test_home_shots_insidebox'] = test_home_shots_insidebox
test_df['test_home_shots_outsidebox'] = test_home_shots_outsidebox
test_df['test_home_fouls'] = test_home_fouls
test_df['test_home_cornerkicks'] = test_home_cornerkicks
test_df['test_home_offsides'] = test_home_offsides
test_df['test_home_possession'] = test_home_possession
test_df['test_home_yellowcards'] = test_home_yellowcards
test_df['test_home_redcards'] = test_home_redcards
test_df['test_home_gk_saves'] = test_home_gk_saves
test_df['test_home_pass_percentage'] = test_home_pass_percentage

# Add columnds of away team data to the season's data frame

test_df['test_away_shots_on_goal'] = test_away_shots_on_goal
test_df['test_away_shots_off_goal'] = test_away_shots_off_goal
test_df['test_away_total_shots'] = test_away_total_shots
test_df['test_away_blocked_shots'] = test_away_blocked_shots
test_df['test_away_shots_insidebox'] = test_away_shots_insidebox
test_df['test_away_shots_outsidebox'] = test_away_shots_outsidebox
test_df['test_away_fouls'] = test_away_fouls
test_df['test_away_cornerkicks'] = test_away_cornerkicks
test_df['test_away_offsides'] = test_away_offsides
test_df['test_away_possession'] = test_away_possession
test_df['test_away_yellowcards'] = test_away_yellowcards
test_df['test_away_redcards'] = test_away_redcards
test_df['test_away_gk_saves'] = test_away_gk_saves
test_df['test_away_pass_percentage'] = test_away_pass_percentage

# %%
#test_df.to_csv('test.csv')

# %%
test_df.columns = ['fixture_id', 'home_team', 'away_team', 'home_goals', 'away_goals',
       'home_shots_on_goal', 'home_shots_off_goal',
       'home_total_shots', 'home_blocked_shots', 'home_shots_insidebox',
       'home_shots_outsidebox', 'home_fouls', 'home_cornerkicks',
       'home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards',
       'home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']

# %%
teams = ['Manchester United', 'Bournemouth', 'Norwich', 'Leicester',
       'Everton', 'Chelsea', 'Newcastle', 'Arsenal', 'Stoke City',
       'West Brom', 'Aston Villa', 'Southampton', 'West Ham', 'Swansea',
       'Sunderland', 'Tottenham', 'Watford', 'Crystal Palace',
       'Manchester City', 'Liverpool', 'Burnley', 'Hull City',
       'Middlesbrough', 'Huddersfield', 'Brighton', 'Fulham', 'Wolves',
       'Cardiff']

# Then iterate of keys OR values everywhere else in your code. Use the "mapping" dictionary anytime you want to see the name of the id (or vice-versa)


train_model = {}
for team in teams:
    train_model[team] = pd.concat([train_df.loc[train_df["home_team"] == team], train_df.loc[train_df['away_team'] == team]], axis="index", join="inner").copy()

# %%
teams = ['Manchester United', 'Bournemouth', 'Norwich', 'Leicester',
       'Everton', 'Chelsea', 'Newcastle', 'Arsenal', 'Stoke City',
       'West Brom', 'Aston Villa', 'Southampton', 'West Ham', 'Swansea',
       'Sunderland', 'Tottenham', 'Watford', 'Crystal Palace',
       'Manchester City', 'Liverpool', 'Burnley', 'Hull City',
       'Middlesbrough', 'Huddersfield', 'Brighton', 'Fulham', 'Wolves',
       'Cardiff']

test_model = {}
for team in teams: 
    test_model[team] = pd.concat([test_df.loc[test_df["home_team"] == team], test_df.loc[test_df['away_team'] == team]], axis="index", join="inner").copy()

# %%
#Train data frames for machine learning
arsenal_train = train_model['Arsenal']
manutd_train = train_model['Manchester United']
bourne_train = train_model['Bournemouth']
norwich_train = train_model['Norwich']
leicester_train = train_model['Leicester']
everton_train = train_model['Everton']
chelsea_train = train_model['Chelsea']
newcastle_train = train_model['Newcastle']
stoke_train = train_model['Stoke City']
westbrom_train = train_model['West Brom']
aston_train = train_model['Aston Villa']
southampton_train = train_model['Southampton']
westham_train = train_model['West Ham']
swansea_train = train_model['Swansea']
sunderland_train = train_model['Sunderland']
tottenham_train = train_model['Tottenham']
watford_train = train_model['Watford']
crystal_train = train_model['Crystal Palace']
mancity_train = train_model['Manchester City']
liverpool_train = train_model['Liverpool']
burnley_train = train_model['Burnley']
hullcity_train = train_model['Hull City']
middles_train = train_model['Middlesbrough']
hudders_train = train_model['Huddersfield']
brighton_train = train_model['Brighton']
fulham_train = train_model['Fulham']
wolves_train = train_model['Wolves']
cardiff_train = train_model['Cardiff']

# %%
#Test data frames for machine learning
arsenal_test = test_model['Arsenal']
manutd_test = test_model['Manchester United']
bourne_test = test_model['Bournemouth']
norwich_test = test_model['Norwich']
leicester_test = test_model['Leicester']
everton_test = test_model['Everton']
chelsea_test = test_model['Chelsea']
newcastle_test = test_model['Newcastle']
stoke_test = test_model['Stoke City']
westbrom_test = test_model['West Brom']
aston_test = test_model['Aston Villa']
southampton_test = test_model['Southampton']
westham_test = test_model['West Ham']
swansea_test = test_model['Swansea']
sunderland_test = test_model['Sunderland']
tottenham_test = test_model['Tottenham']
watford_test = test_model['Watford']
crystal_test = test_model['Crystal Palace']
mancity_test = test_model['Manchester City']
liverpool_test = test_model['Liverpool']
burnley_test = test_model['Burnley']
hullcity_test = test_model['Hull City']
middles_test = test_model['Middlesbrough']
hudders_test = test_model['Huddersfield']
brighton_test = test_model['Brighton']
fulham_test = test_model['Fulham']
wolves_test = test_model['Wolves']
cardiff_test = test_model['Cardiff']

# %%
#Import Team specific CSVs, adjusted with 1 to reflect Team Win, and Shifted to prevent bias
arsenal_csv = Path("Resources/Project3/arsenal_test.csv")
astonvilla_csv = Path("Resources/Project3/astonvilla_test.csv")
bournemouth_csv = Path("Resources/Project3/bournemouth_test.csv")
brighton_csv = Path("Resources/Project3/brighton_test.csv")
chelsea_csv = Path("Resources/Project3/chelsea_test.csv")
crystal_csv = Path("Resources/Project3/crystal_test.csv")
everton_csv = Path("Resources/Project3/everton_test.csv")
leicester_csv = Path("Resources/Project3/leicester_test.csv")
liverpool_csv = Path("Resources/Project3/liverpool_test.csv")
mancity_csv = Path("Resources/Project3/mancity_test.csv")
manutd_csv = Path("Resources/Project3/manutd_test.csv")
norwich_csv = Path("Resources/Project3/norwich_test.csv")
south_csv = Path("Resources/Project3/south_test.csv")
totten_csv = Path("Resources/Project3/tot_test.csv")
watford_csv = Path("Resources/Project3/watford_test.csv")
west_csv = Path("Resources/Project3/west_test.csv")
wolves_csv = Path("Resources/Project3/wolves_test.csv")
#Same steps for Train Data
arsenal_csv_ = Path("Resources/Project3/arsenal_train.csv")
astonvilla_csv_ = Path("Resources/Project3/astonvilla_train.csv")
bournemouth_csv_ = Path("Resources/Project3/bournemouth_train.csv")
brighton_csv_ = Path("Resources/Project3/brighton_train.csv")
chelsea_csv_ = Path("Resources/Project3/chelsea_train.csv")
crystal_csv_ = Path("Resources/Project3/crystal_train.csv")
everton_csv_ = Path("Resources/Project3/everton_train.csv")
leicester_csv_ = Path("Resources/Project3/leicester_train.csv")
liverpool_csv_ = Path("Resources/Project3/liverpool_train.csv")
mancity_csv_ = Path("Resources/Project3/mancity_train.csv")
manutd_csv_ = Path("Resources/Project3/manutd_train.csv")
norwich_csv_ = Path("Resources/Project3/norwich_train.csv")
south_csv_ = Path("Resources/Project3/south_train.csv")
totten_csv_ = Path("Resources/Project3/tot_train.csv")
watford_csv_ = Path("Resources/Project3/watford_train.csv")
west_csv_ = Path("Resources/Project3/west_train.csv")
wolves_csv_ = Path("Resources/Project3/wolves_train.csv")

# %%
#Create corrected dataframes
arsenal_test_df = pd.read_csv(arsenal_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
astonvilla_test_df = pd.read_csv(astonvilla_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
bournemouth_test_df = pd.read_csv(bournemouth_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
brighton_test_df = pd.read_csv(brighton_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
chelsea_test_df = pd.read_csv(chelsea_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
crystal_test_df = pd.read_csv(crystal_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
everton_test_df = pd.read_csv(everton_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
leicester_test_df = pd.read_csv(leicester_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
liverpool_test_df = pd.read_csv(liverpool_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
mancity_test_df = pd.read_csv(mancity_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
manutd_test_df = pd.read_csv(manutd_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
norwich_test_df = pd.read_csv(norwich_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
south_test_df = pd.read_csv(south_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
totten_test_df = pd.read_csv(totten_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
watford_test_df = pd.read_csv(watford_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
west_test_df = pd.read_csv(west_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
wolves_test_df = pd.read_csv(wolves_csv, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
# Now for train data. 
arsenal_train_df = pd.read_csv(arsenal_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
astonvilla_train_df = pd.read_csv(astonvilla_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
bournemouth_train_df = pd.read_csv(bournemouth_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
brighton_train_df = pd.read_csv(brighton_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
chelsea_train_df = pd.read_csv(chelsea_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
crystal_train_df = pd.read_csv(crystal_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
everton_train_df = pd.read_csv(everton_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
leicester_train_df = pd.read_csv(leicester_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
liverpool_train_df = pd.read_csv(liverpool_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
mancity_train_df = pd.read_csv(mancity_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
manutd_train_df = pd.read_csv(manutd_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
norwich_train_df = pd.read_csv(norwich_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
south_train_df = pd.read_csv(south_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
totten_train_df = pd.read_csv(totten_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
watford_train_df = pd.read_csv(watford_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
west_train_df = pd.read_csv(west_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
wolves_train_df = pd.read_csv(wolves_csv_, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %%
liverpool_test_df.columns
# Out:
# Index(['fixture_id', 'home_team', 'away_team', 'results', 'home_goals',
#        'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
#        'test_home_total_shots', 'test_home_blocked_shots',
#        'test_home_shots_insidebox', 'test_home_shots_outsidebox',
#        'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
#        'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
#        'test_home_gk_saves', 'test_home_pass_percentage',
#        'test_away_shots_on_goal', 'test_away_shots_off_goal',
#        'test_away_total_shots', 'test_away_blocked_shots',
#        'test_away_shots_insidebox', 'test_away_shots_outsidebox',
#        'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
#        'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
#        'test_away_gk_saves', 'test_away_pass_percentage'],
#       dtype='object')

# %% [markdown]
# # Machine Learning Aspect

# %%
#Assign Multi Index
liverpool_train_df = liverpool_train_df.set_index(['home_team', 'away_team'], drop = True)
liverpool_test_df = liverpool_test_df.set_index(['home_team', 'away_team'], drop = True)

# %%
#Drop NA if applicable
liverpool_train_df = liverpool_train_df.fillna(0)
liverpool_test_df = liverpool_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
lp_y_train = liverpool_train_df['result']
lp_X_train = liverpool_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
lp_y_test = liverpool_test_df['results']
lp_X_test = liverpool_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
lp_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
lp_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
lp_classifier.fit(lp_X_train, lp_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {lp_classifier.score(lp_X_train, lp_y_train)}")
print(f"Testing Data Score: {lp_classifier.score(lp_X_test, lp_y_test)}")
# Out:
# Training Data Score: 0.7066666666666667
# Testing Data Score: 0.8888888888888888

# %%
lp_predictions = lp_classifier.predict(lp_X_test)
lp_results = pd.DataFrame({"Prediction": lp_predictions, "Actual": lp_y_test})
lp_results.head(20)
# Out:
#                              Prediction  Actual
# home_team away_team
# Liverpool Arsenal                     1       1
#           Newcastle                   1       1
#           Leicester                   1       1
#           Tottenham                   1       1
#           Manchester City             1       1
#           Brighton                    1       1
#           Everton                     1       1
#           Watford                     1       1
#           Wolves                      1       1
#           Sheffield Utd               1       1
#           Manchester United           1       1
#           Southampton                 1       1
#           West Ham                    1       1
#           Bournemouth                 1       1
#           Crystal Palace              1       1
#           Aston Villa                 1       1
#           Burnley                     1       0
#           Chelsea                     1       1
# ...

# %%
#Calculate Probabilities
lp_proba = lp_classifier.predict_proba(lp_X_test)
lp_proba
# Out:
# array([[0.38841126, 0.61158874],
#        [0.3603182 , 0.6396818 ],
#        [0.40042558, 0.59957442],
#        [0.41444946, 0.58555054],
#        [0.33720348, 0.66279652],
#        [0.37447784, 0.62552216],
#        [0.41178964, 0.58821036],
#        [0.38637903, 0.61362097],
#        [0.42613052, 0.57386948],
#        [0.48364907, 0.51635093],
#        [0.44568295, 0.55431705],
#        [0.40274485, 0.59725515],
#        [0.31816379, 0.68183621],
#        [0.3419655 , 0.6580345 ],
#        [0.4332458 , 0.5667542 ],
#        [0.44984157, 0.55015843],
#        [0.46554055, 0.53445945],
#        [0.38546148, 0.61453852],
#        [0.38299822, 0.61700178],
#        [0.41697003, 0.58302997],
#        [0.45000748, 0.54999252],
#        [0.41576918, 0.58423082],
#        [0.48882543, 0.51117457],
#        [0.37982586, 0.62017414],
#        [0.39120999, 0.60879001],
#        [0.4651051 , 0.5348949 ],
#        [0.48094376, 0.51905624],
#        [0.49694565, 0.50305435],
# ...

# %%
#Mathematical Formula for odds conversions.
lp_proba_df = pd.DataFrame(lp_proba)
lp_proba_imp_prob = (lp_proba_df - 1)*-1
lp_proba_odds = 1 / lp_proba_imp_prob
lp_proba_odds.head()
# Out:
#           0         1
# 0  1.635086  2.574591
# 1  1.563277  2.775325
# 2  1.667850  2.497343
# 3  1.707795  2.412839
# 4  1.508759  2.965568

# %%
#Assign Multi Index
wolves_train_df = wolves_train_df.set_index(['home_team', 'away_team'], drop = True)
wolves_test_df = wolves_test_df.set_index(['home_team', 'away_team'], drop = True)

# %%
#Drop NA if applicable
wolves_train_df = wolves_train_df.fillna(0)
wolves_test_df = wolves_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
wv_y_train = wolves_train_df['result']
wv_X_train = wolves_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
wv_y_test = wolves_test_df['result']
wv_X_test = wolves_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
wv_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
wv_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
wv_classifier.fit(wv_X_train, wv_y_train)
# Out:
# C:\Users\Ryan\anaconda3.64\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {wv_classifier.score(wv_X_train, wv_y_train)}")
print(f"Testing Data Score: {wv_classifier.score(wv_X_test, wv_y_test)}")
# Out:
# Training Data Score: 0.8888888888888888
# Testing Data Score: 0.4166666666666667

# %%
wv_predictions = wv_classifier.predict(wv_X_test)
wv_results = pd.DataFrame({"Prediction": wv_predictions, "Actual": wv_y_test})
wv_results.head(20)
# Out:
#                                 Prediction  Actual
# home_team      away_team
# Wolves         Burnley                   0       0
#                Chelsea                   0       0
#                Watford                   0       1
#                Southampton               0       0
#                Aston Villa               0       1
#                Sheffield Utd             0       0
#                West Ham                  0       1
#                Tottenham                 0       0
#                Manchester City           0       1
#                Newcastle                 0       0
#                Liverpool                 0       0
#                Leicester                 0       0
#                Norwich                   0       1
#                Brighton                  0       0
#                Bournemouth               0       1
#                Arsenal                   0       0
#                Everton                   0       1
# ...

# %%
#Calculate Probabilities
wv_proba = wv_classifier.predict_proba(wv_X_test)
wv_proba
#Mathematical Formula for odds conversions.
wv_proba_df = pd.DataFrame(wv_proba)
wv_proba_imp_prob = (wv_proba_df - 1)*-1
wv_proba_odds = 1 / wv_proba_imp_prob
wv_proba_odds.head()
# Out:
#      0    1
# 0 -inf  1.0
# 1 -inf  1.0
# 2 -inf  1.0
# 3 -inf  1.0
# 4 -inf  1.0

# %%
#Assign Multi Index
totten_train_df = totten_train_df.set_index(['home_team', 'away_team'], drop = True)
totten_test_df = totten_train_df.set_index(['home_team', 'away_team'], drop = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-560a2973c9e4> in <module>
#       1 #Assign Multi Index
#       2 totten_train_df = totten_train_df.set_index(['home_team', 'away_team'], drop = True)
# ----> 3 totten_test_df = totten_train_df.set_index(['home_team', 'away_team'], drop = True)
#
# ~\anaconda3.64\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['home_team', 'away_team'] are in the columns"

# %%
#Drop NA if applicable
totten_train_df = totten_train_df.fillna(0)
totten_test_df = totten_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
tt_y_train = totten_train_df['result']
tt_X_train = totten_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
tt_y_test = totten_test_df['result']
tt_X_test = totten_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
tt_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
tt_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
tt_classifier.fit(tt_X_train, tt_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {tt_classifier.score(tt_X_train, tt_y_train)}")
print(f"Testing Data Score: {tt_classifier.score(tt_X_test, tt_y_test)}")
# Out:
# Training Data Score: 0.72
# Testing Data Score: 0.6111111111111112

# %%
tt_predictions = tt_classifier.predict(tt_X_test)
tt_results = pd.DataFrame({"Prediction": tt_predictions, "Actual": tt_y_test})
tt_results.head(20)
# Out:
#                            Prediction  Actual
# date
# 2019-08-25 15:30:00+00:00           1       0
# 2019-09-14 14:00:00+00:00           1       1
# 2019-09-28 14:00:00+00:00           1       1
# 2019-10-19 14:00:00+00:00           1       0
# 2019-11-09 15:00:00+00:00           1       0
# 2019-11-30 15:00:00+00:00           1       1
# 2019-12-07 15:00:00+00:00           1       1
# 2019-12-22 16:30:00+00:00           1       0
# 2019-12-26 12:30:00+00:00           1       1
# 2020-01-11 17:30:00+00:00           1       0
# 2020-01-22 19:30:00+00:00           1       1
# 2020-02-02 16:30:00+00:00           1       1
# 2020-03-01 14:00:00+00:00           1       0
# 2020-06-19 19:15:00+00:00           1       0
# 2020-06-23 19:15:00+00:00           1       1
# 2020-07-06 19:00:00+00:00           1       1
# 2020-07-12 15:30:00+00:00           1       1
# 2020-07-19 15:00:00+00:00           1       1
# 2019-09-01 15:30:00+00:00           1       1
# ...

# %%
#Calculate Probabilities
tt_proba = tt_classifier.predict_proba(tt_X_test)
tt_proba
#Mathematical Formula for odds conversions.
tt_proba_df = pd.DataFrame(tt_proba)
tt_proba_imp_prob = (tt_proba_df - 1)*-1
tt_proba_odds = 1 / tt_proba_imp_prob
tt_proba_odds.head()
# Out:
#           0         1
# 0  1.238021  5.201305
# 1  1.348432  3.870001
# 2  1.308046  4.246264
# 3  1.344915  3.899262
# 4  1.396173  3.524151

# %%
#Assign Multi Index
arsenal_train_df = arsenal_train_df.set_index(['home_team', 'away_team'], drop = True)
arsenal_test_df = arsenal_test_df.set_index(['home_team', 'away_team'], drop = True)

# %%
#Drop NA if applicable
arsenal_train_df = arsenal_train_df.fillna(0)
arsenal_test_df = arsenal_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
ar_y_train = arsenal_train_df['result']
ar_X_train = arsenal_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
ar_y_test = arsenal_test_df['result']
ar_X_test = arsenal_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
ar_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
ar_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
ar_classifier.fit(ar_X_train, ar_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {ar_classifier.score(ar_X_train, ar_y_train)}")
print(f"Testing Data Score: {ar_classifier.score(ar_X_test, ar_y_test)}")
# Out:
# Training Data Score: 0.6933333333333334
# Testing Data Score: 0.5555555555555556

# %%
ar_predictions = ar_classifier.predict(ar_X_test)
ar_results = pd.DataFrame({"Prediction": ar_predictions, "Actual": ar_y_test})
ar_results.head(20)
# Out:
#                              Prediction  Actual
# home_team away_team
# Arsenal   Tottenham                   1       0
#           Aston Villa                 1       1
#           Bournemouth                 1       1
#           Crystal Palace              1       0
#           Wolves                      1       0
#           Southampton                 1       0
#           Brighton                    1       0
#           Manchester City             1       0
#           Chelsea                     1       0
#           Manchester United           1       1
#           Sheffield Utd               1       0
#           Newcastle                   1       1
#           Everton                     1       1
#           West Ham                    1       1
#           Norwich                     1       1
#           Leicester                   1       0
#           Liverpool                   1       1
#           Watford                     1       1
# ...

# %%
#Calculate Probabilities
ar_proba = ar_classifier.predict_proba(ar_X_test)
ar_proba
#Mathematical Formula for odds conversions.
ar_proba_df = pd.DataFrame(ar_proba)
ar_proba_imp_prob = (ar_proba_df - 1)*-1
ar_proba_odds = 1 / ar_proba_imp_prob
ar_proba_odds.head()
# Out:
#           0          1
# 0  1.070414  15.201820
# 1  1.062172  17.084398
# 2  1.167516   6.969580
# 3  1.217190   5.604265
# 4  1.169442   6.901736

# %%
#Assign Multi Index
west_train_df = west_train_df.set_index(['home_team', 'away_team'], drop = True)
west_test_df = west_test_df.set_index(['home_team', 'away_team'], drop = True)

# %%
#Drop NA if applicable
west_train_df = west_train_df.fillna(0)
west_test_df = west_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
wh_y_train = west_train_df['result']
wh_X_train = west_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
wh_y_test = west_test_df['result']
wh_X_test = west_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
wh_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
wh_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
wh_classifier.fit(wh_X_train, wh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {wh_classifier.score(wh_X_train, wh_y_train)}")
print(f"Testing Data Score: {wh_classifier.score(wh_X_test, wh_y_test)}")
# Out:
# Training Data Score: 0.4866666666666667
# Testing Data Score: 0.3888888888888889

# %%
wh_predictions = wh_classifier.predict(wh_X_test)
wh_results = pd.DataFrame({"Prediction": wh_predictions, "Actual": wh_y_test})
wh_results.head(20)
# Out:
#                                Prediction  Actual
# home_team   away_team
# West Ham    Norwich                     1       1
#             Manchester United           1       1
#             Crystal Palace              1       0
#             Sheffield Utd               1       0
#             Newcastle                   1       0
#             Tottenham                   1       0
#             Arsenal                     1       0
#             Liverpool                   1       0
#             Leicester                   1       0
#             Bournemouth                 1       1
#             Everton                     1       0
#             Brighton                    1       0
#             Southampton                 1       1
#             Wolves                      1       0
#             Chelsea                     1       1
#             Burnley                     1       0
#             Watford                     1       1
# ...

# %%
#Calculate Probabilities
wh_proba = wh_classifier.predict_proba(wh_X_test)
wh_proba
#Mathematical Formula for odds conversions.
wh_proba_df = pd.DataFrame(wh_proba)
wh_proba_imp_prob = (wh_proba_df - 1)*-1
wh_proba_odds = 1 / wh_proba_imp_prob
wh_proba_odds.head()
# Out:
#           0         1
# 0  1.719202  2.390430
# 1  1.719172  2.390488
# 2  1.719142  2.390547
# 3  1.719111  2.390605
# 4  1.719096  2.390634

# %%
#Assign Multi Index
crystal_train_df = crystal_train_df.set_index(['home_team', 'away_team'], drop = True)
crystal_test_df = crystal_test_df.set_index(['home_team', 'away_team'], drop = True)

# %%
#Drop NA if applicable
crystal_train_df = crystal_train_df.fillna(0)
crystal_test_df = crystal_test_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
cr_y_train = crystal_train_df['result']
cr_X_train = crystal_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
cr_y_test = crystal_test_df['result']
cr_X_test = crystal_test_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
cr_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
cr_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
cr_classifier.fit(cr_X_train, cr_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {cr_classifier.score(cr_X_train, cr_y_train)}")
print(f"Testing Data Score: {cr_classifier.score(cr_X_test, cr_y_test)}")
# Out:
# Training Data Score: 0.6933333333333334
# Testing Data Score: 0.5789473684210527

# %%
cr_predictions = cr_classifier.predict(cr_X_test)
cr_results = pd.DataFrame({"Prediction": cr_predictions, "Actual": cr_y_test})
cr_results.head(20)
# Out:
#                                   Prediction  Actual
# home_team      away_team
# Crystal Palace Everton                     0       0
#                Aston Villa                 0       1
#                Wolves                      0       0
#                Norwich                     0       1
#                Manchester City             0       0
#                Leicester                   0       0
#                Liverpool                   1       0
#                Bournemouth                 0       1
#                Brighton                    0       0
#                West Ham                    0       1
#                Arsenal                     0       0
#                Southampton                 0       0
#                Sheffield Utd               0       0
#                Newcastle                   0       1
#                Watford                     0       1
#                Burnley                     0       0
# ...

# %%
#Calculate Probabilities
cr_proba = cr_classifier.predict_proba(cr_X_test)
cr_proba
#Mathematical Formula for odds conversions.
cr_proba_df = pd.DataFrame(cr_proba)
cr_proba_imp_prob = (cr_proba_df - 1)*-1
cr_proba_odds = 1 / cr_proba_imp_prob
cr_proba_odds.head()
# Out:
#           0         1
# 0  7.243196  1.160174
# 1  5.995311  1.200188
# 2  4.148574  1.317604
# 3  4.162388  1.316217
# 4  4.801860  1.263029

# %% [markdown]
#  # Prediction Aspect

# %%
#Import Team specific CSVs, adjusted with 1 to reflect Team Win, and Shifted to prevent bias. Fixed with prediction
arsenal_csv_1 = Path("Resources/Project3/arsenal_pred.csv")
tottenham_csv_1 = Path("Resources/Project3/tot_pred.csv")
west_csv_1 = Path("Resources/Project3/west_pred.csv")
crystal_csv_1 = Path("Resources/Project3/crystal_pred.csv")

# %%
#Import data frames
arsenal_pred_df = pd.read_csv(arsenal_csv_1, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
tottenham_pred_df = pd.read_csv(tottenham_csv_1, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
west_pred_df = pd.read_csv(west_csv_1, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
crystal_pred_df = pd.read_csv(crystal_csv_1, index_col='date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %%
#Assign Multi Index
crystal_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
crystal_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-e591eee0b409> in <module>
#       1 #Assign Multi Index
#       2 crystal_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
# ----> 3 crystal_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
#
# ~\anaconda3.64\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['home_team', 'away_team'] are in the columns"

# %%
#Drop NA if applicable
crystal_pred_df = crystal_pred_df.fillna(0)
crystal_pred_df = crystal_pred_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
cp_y_train = crystal_train_df['result']
cp_X_train = crystal_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
cp_y_test = crystal_pred_df['result']
cp_X_test = crystal_pred_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
cp_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
cp_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
cp_classifier.fit(cp_X_train, cp_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {cp_classifier.score(cp_X_train, cp_y_train)}")
print(f"Testing Data Score: {cp_classifier.score(cp_X_test, cp_y_test)}")
# Out:
# Training Data Score: 0.6933333333333334
# Testing Data Score: 0.5897435897435898

# %%
cp_predictions = cp_classifier.predict(cp_X_test)
cp_results = pd.DataFrame({"Prediction": cp_predictions, "Actual": cp_y_test})
cp_results.tail(20)
# Out:
#                                   Prediction  Actual
# home_team         away_team
# Sheffield Utd     Crystal Palace           0       0
# Manchester United Crystal Palace           0       1
# Tottenham         Crystal Palace           1       0
# West Ham          Crystal Palace           0       1
# Arsenal           Crystal Palace           1       1
# Chelsea           Crystal Palace           0       0
# Burnley           Crystal Palace           0       1
# Watford           Crystal Palace           0       1
# Newcastle         Crystal Palace           0       0
# Southampton       Crystal Palace           0       1
# Norwich           Crystal Palace           0       1
# Manchester City   Crystal Palace           1       1
# Everton           Crystal Palace           0       0
# Brighton          Crystal Palace           1       1
# Bournemouth       Crystal Palace           0       1
# Liverpool         Crystal Palace           1       0
# ...

# %%
#Calculate Probabilities
cp_proba = cp_classifier.predict_proba(cp_X_test)
cp_proba
#Mathematical Formula for odds conversions.
cp_proba_df = pd.DataFrame(cp_proba)
cp_proba_imp_prob = (cp_proba_df - 1)*-1
cp_proba_odds = 1 / cp_proba_imp_prob
cp_proba_odds.tail()
# Out:
#            0         1
# 34  1.874788  2.143134
# 35  2.297718  1.770584
# 36  2.228103  1.814264
# 37  6.920744  1.168898
# 38  3.838088  1.352350

# %%
#Assign Multi Index
west_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
west_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-741c16ee100f> in <module>
#       1 #Assign Multi Index
# ----> 2 west_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
#       3 west_pred_df = crystal_pred_df.set_index(['home_team', 'away_team'], drop = True)
#
# ~\anaconda3.64\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['home_team', 'away_team'] are in the columns"

# %%
#Drop NA if applicable
west_pred_df = west_pred_df.fillna(0)
west_pred_df = west_pred_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
wp_y_train = west_train_df['result']
wp_X_train = west_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
wp_y_test = west_pred_df['result']
wp_X_test = west_pred_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
wp_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
wp_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
wp_classifier.fit(wp_X_train, wp_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {wp_classifier.score(wp_X_train, wp_y_train)}")
print(f"Testing Data Score: {wp_classifier.score(wp_X_test, wp_y_test)}")
# Out:
# Training Data Score: 0.4866666666666667
# Testing Data Score: 0.40540540540540543

# %%
wp_predictions = wp_classifier.predict(wp_X_test)
wp_results = pd.DataFrame({"Prediction": wp_predictions, "Actual": wp_y_test})
wp_results.tail(20)
# Out:
#                            Prediction  Actual
# date
# 2020-07-26 15:00:00+00:00           1       0
# 2019-08-24 14:00:00+00:00           1       1
# 2019-09-16 19:00:00+00:00           1       1
# 2019-09-28 14:00:00+00:00           1       1
# 2019-10-19 11:30:00+00:00           1       0
# 2019-11-09 15:00:00+00:00           1       0
# 2019-11-30 15:00:00+00:00           1       1
# 2019-12-04 19:30:00+00:00           1       0
# 2019-12-14 17:30:00+00:00           1       1
# 2019-12-26 15:00:00+00:00           1       0
# 2020-01-10 20:00:00+00:00           1       0
# 2020-01-22 19:30:00+00:00           1       0
# 2020-02-19 19:30:00+00:00           1       0
# 2020-02-24 20:00:00+00:00           1       0
# 2020-03-07 15:00:00+00:00           1       0
# 2020-06-23 19:15:00+00:00           1       0
# 2020-07-05 13:15:00+00:00           1       1
# 2020-07-11 11:30:00+00:00           1       1
# 2020-07-22 17:00:00+00:00           1       1
# ...

# %%
#Calculate Probabilities
wp_proba = wp_classifier.predict_proba(wp_X_test)
wp_proba
#Mathematical Formula for odds conversions.
wp_proba_df = pd.DataFrame(wp_proba)
wp_proba_imp_prob = (wp_proba_df - 1)*-1
wp_proba_odds = 1 / wp_proba_imp_prob
wp_proba_odds.tail()
# Out:
#            0         1
# 32  1.718796  2.391215
# 33  1.718770  2.391265
# 34  1.718740  2.391323
# 35  1.718712  2.391379
# 36  1.718681  2.391437

# %%
#Averaging of West vs Crystal Game
west_odds = (wp_proba_odds[0][36] + cp_proba_odds[1][38])/2
west_odds
# Out:
# 1.5355156257129476

# %%
crystal_odds = (wp_proba_odds[1][36] + cp_proba_odds[0][38]/2)
crystal_odds
# Out:
# 4.310481319349577

# %%
#Assign Multi Index
arsenal_pred_df = arsenal_pred_df.set_index(['home_team', 'away_team'], drop = True)
arsenal_pred_df = arsenal_pred_df.set_index(['home_team', 'away_team'], drop = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-7a9da9603bab> in <module>
#       1 #Assign Multi Index
#       2 arsenal_pred_df = arsenal_pred_df.set_index(['home_team', 'away_team'], drop = True)
# ----> 3 arsenal_pred_df = arsenal_pred_df.set_index(['home_team', 'away_team'], drop = True)
#
# ~\anaconda3.64\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['home_team', 'away_team'] are in the columns"

# %%
#Drop NA if applicable
arsenal_pred_df = arsenal_pred_df.fillna(0)
arsenal_pred_df = arsenal_pred_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
ap_y_train = arsenal_train_df['result']
ap_X_train = arsenal_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
ap_y_test = arsenal_pred_df['result']
ap_X_test = arsenal_pred_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
ap_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
ap_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
ap_classifier.fit(ap_X_train, ap_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {ap_classifier.score(ap_X_train, ap_y_train)}")
print(f"Testing Data Score: {ap_classifier.score(ap_X_test, ap_y_test)}")
# Out:
# Training Data Score: 0.6933333333333334
# Testing Data Score: 0.5405405405405406

# %%
ap_predictions = ap_classifier.predict(ap_X_test)
ap_results = pd.DataFrame({"Prediction": ap_predictions, "Actual": ap_y_test})
ap_results.tail(20)
# Out:
#                              Prediction  Actual
# home_team         away_team
# Arsenal           Watford             1       1
# Liverpool         Arsenal             1       0
# Watford           Arsenal             1       1
# Manchester United Arsenal             1       1
# Sheffield Utd     Arsenal             1       0
# Leicester         Arsenal             1       0
# Norwich           Arsenal             1       1
# West Ham          Arsenal             1       1
# Everton           Arsenal             1       1
# Bournemouth       Arsenal             1       1
# Crystal Palace    Arsenal             1       1
# Chelsea           Arsenal             1       1
# Burnley           Arsenal             1       1
# Manchester City   Arsenal             1       0
# Brighton          Arsenal             1       0
# Southampton       Arsenal             1       1
# Wolves            Arsenal             1       1
# Tottenham         Arsenal             1       0
# ...

# %%
#Calculate Probabilities
ap_proba = ap_classifier.predict_proba(ap_X_test)
ap_proba
#Mathematical Formula for odds conversions.
ap_proba_df = pd.DataFrame(ap_proba)
ap_proba_imp_prob = (ap_proba_df - 1)*-1
ap_proba_odds = 1 / ap_proba_imp_prob
ap_proba_odds.tail()
# Out:
#            0          1
# 32  1.117814   9.487936
# 33  1.185063   6.403563
# 34  1.201089   5.972929
# 35  1.066035  16.143468
# 36  1.084069  12.895050

# %%
#Assign Multi Index
tottenham_pred_df = tottenham_pred_df.set_index(['home_team', 'away_team'], drop = True)
tottenham_pred_df = tottenham_pred_df.set_index(['home_team', 'away_team'], drop = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-a4c6224fddc3> in <module>
#       1 #Assign Multi Index
#       2 tottenham_pred_df = tottenham_pred_df.set_index(['home_team', 'away_team'], drop = True)
# ----> 3 tottenham_pred_df = tottenham_pred_df.set_index(['home_team', 'away_team'], drop = True)
#
# ~\anaconda3.64\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['home_team', 'away_team'] are in the columns"

# %%
#Drop NA if applicable
tottenham_pred_df = tottenham_pred_df.fillna(0)
tottenham_pred_df = tottenham_pred_df.fillna(0)

# %%
#Declare Independent and Dependent Variables
tp_y_train = totten_train_df['result']
tp_X_train = totten_train_df[['fixture_id', 'home_goals', 'away_goals','home_shots_on_goal', 'home_shots_off_goal','home_total_shots', 'home_blocked_shots', 'home_shots_insidebox','home_shots_outsidebox', 'home_fouls', 'home_cornerkicks','home_offsides', 'home_possession', 'home_yellowcards', 'home_redcards','home_gk_saves', 'home_pass_percentage', 'away_shots_on_goal',
       'away_shots_off_goal', 'away_total_shots', 'away_blocked_shots',
       'away_shots_insidebox', 'away_shots_outsidebox', 'away_fouls',
       'away_cornerkicks', 'away_offsides', 'away_possession',
       'away_yellowcards', 'away_redcards', 'away_gk_saves',
       'away_pass_percentage']]
tp_y_test = tottenham_pred_df['result']
tp_X_test = tottenham_pred_df[['fixture_id', 'home_goals',
       'away_goals', 'test_home_shots_on_goal', 'test_home_shots_off_goal',
       'test_home_total_shots', 'test_home_blocked_shots',
       'test_home_shots_insidebox', 'test_home_shots_outsidebox',
       'test_home_fouls', 'test_home_cornerkicks', 'test_home_offsides',
       'test_home_possession', 'test_home_yellowcards', 'test_home_redcards',
       'test_home_gk_saves', 'test_home_pass_percentage',
       'test_away_shots_on_goal', 'test_away_shots_off_goal',
       'test_away_total_shots', 'test_away_blocked_shots',
       'test_away_shots_insidebox', 'test_away_shots_outsidebox',
       'test_away_fouls', 'test_away_cornerkicks', 'test_away_offsides',
       'test_away_possession', 'test_away_yellowcards', 'test_away_redcards',
       'test_away_gk_saves', 'test_away_pass_percentage']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
tp_classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
tp_classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
tp_classifier.fit(tp_X_train, tp_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {tp_classifier.score(tp_X_train, tp_y_train)}")
print(f"Testing Data Score: {tp_classifier.score(tp_X_test, tp_y_test)}")
# Out:
# Training Data Score: 0.72
# Testing Data Score: 0.5945945945945946

# %%
tp_predictions = tp_classifier.predict(tp_X_test)
tp_results = pd.DataFrame({"Prediction": tp_predictions, "Actual": tp_y_test})
tp_results.head(20)
# Out:
#                              Prediction  Actual
# home_team away_team
# Tottenham Newcastle                   1       0
#           Crystal Palace              1       1
#           Southampton                 1       1
#           Watford                     1       0
#           Sheffield Utd               1       0
#           Bournemouth                 1       1
#           Burnley                     1       1
#           Chelsea                     1       0
#           Brighton                    1       1
#           Liverpool                   1       0
#           Norwich                     1       1
#           Manchester City             1       1
#           Wolves                      1       0
#           Manchester United           1       0
#           West Ham                    1       1
#           Everton                     1       1
#           Arsenal                     1       1
#           Leicester                   1       1
# ...

# %%
#Calculate Probabilities
tp_proba = tp_classifier.predict_proba(tp_X_test)
tp_proba
#Mathematical Formula for odds conversions.
tp_proba_df = pd.DataFrame(tp_proba)
tp_proba_imp_prob = (tp_proba_df - 1)*-1
tp_proba_odds = 1 / tp_proba_imp_prob
tp_proba_odds.head(20)
# Out:
#            0         1
# 0   1.238021  5.201305
# 1   1.348432  3.870001
# 2   1.308046  4.246264
# 3   1.344915  3.899262
# 4   1.396173  3.524151
# 5   1.313878  4.185948
# 6   1.275081  4.635298
# 7   1.386310  3.588594
# 8   1.401116  3.493045
# 9   1.357309  3.798698
# 10  1.348562  3.868926
# 11  1.331159  4.019698
# 12  1.360368  3.774942
# 13  1.305536  4.272935
# 14  1.300950  4.322811
# 15  1.329892  4.031298
# 16  1.310507  4.220540
# 17  1.288742  4.463304
# 18  1.270288  4.699762
# 19  1.205257  5.871946

# %%
#Averaging of Totten vs Arsen
totten_odds = (tp_proba_odds[0][36] + ap_proba_odds[1][36])/2
totten_odds
# Out:
# 7.123889341641151

# %%
#Averaging of Totten vs Arsen
arsenal_odds = (tp_proba_odds[1][36] + ap_proba_odds[0][36])/2
arsenal_odds
# Out:
# 2.45955521721089

# %%
#Create DataFrame for Games on 12/6 
final_df = pd.DataFrame({
    "Game" : ["Westbrom vs Crystal Palace", "Tottenham vs Arsenal"],
    
    "Our Odds Home" : [1.53, 7.12],
    "Our Odds Away" : [4.31, 2.459],
    "Bet365 Odds Home" : [1.5, 1.25],
    "Bet365 Odds Away" : [1.4 ,1.72]
    
})

final_df.head()

final_df.head(20)
# Out:
#                          Game  Our Odds Home  Our Odds Away  Bet365 Odds Home  \
# 0  Westbrom vs Crystal Palace           1.53          4.310              1.50
# 1        Tottenham vs Arsenal           7.12          2.459              1.25
#
#    Bet365 Odds Away
# 0              1.40
# 1              1.72

# %% [markdown]
# ## Since our model is showing greater "odds" compared to Bet365, we are not being compensated enough for our level of risk. Because of this, we will not bet on any of these games.
