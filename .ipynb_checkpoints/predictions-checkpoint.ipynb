# %% [markdown]
# # Prework

# %%
# Import libraries
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
#Load CSVs
file_path_2019 = Path("RESOURCES/2019.csv")
file_path_2018 = Path("RESOURCES/2018.csv")
file_path_2017 = Path("RESOURCES/2017.csv")
file_path_2016 = Path("RESOURCES/2016.csv")
file_path_2015 = Path("RESOURCES/2015.csv")
file_path_2014 = Path("RESOURCES/2014.csv")
file_path_2013 = Path("RESOURCES/2013.csv")
file_path_2012 = Path("RESOURCES/2012.csv")
file_path_2011 = Path("RESOURCES/2011.csv")
#Read in CSVs
df_2019 = pd.read_csv(file_path_2019, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True) 
df_2018 = pd.read_csv(file_path_2018, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2017 = pd.read_csv(file_path_2017, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2016 = pd.read_csv(file_path_2016, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2015 = pd.read_csv(file_path_2015, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2014 = pd.read_csv(file_path_2014, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2013 = pd.read_csv(file_path_2013, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2012 = pd.read_csv(file_path_2012, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)
df_2011 = pd.read_csv(file_path_2011, index_col='Date', infer_datetime_format=True, dayfirst=True, parse_dates=True)

# %% [markdown]
# # Cleaning Data

# %%
#Concat Data
train_epl_df = pd.concat([df_2018, df_2017, df_2016, df_2015, df_2014, df_2013, df_2012, df_2011],axis="index", join="inner")

# %%
train_epl_df.sort_index(inplace=True)

# %%
#Pull the Testing Data for 2019
test_epl_df = (df_2019)
test_epl_df.sort_index(inplace=True)

# %%
# Check data for nulls, check for sum, for Train Data
train_epl_df.isnull().sum()
train_epl_df.dropna(inplace=True)
train_epl_df.isnull().sum().head()
# Out:
# Div         0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# FTAG        0
# dtype: int64

# %%
# Check data for nulls, check for sum, for Test Data
test_epl_df.isnull().sum()
test_epl_df.dropna(inplace=True)
test_epl_df.isnull().sum().head()
# Out:
# Div         0
# Time        0
# HomeTeam    0
# AwayTeam    0
# FTHG        0
# dtype: int64

# %%
#To check the columns for the Train dataframe
train_epl_df.head()
print(train_epl_df.columns.values)
# Out:
# ['Div' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR'
#  'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR' 'AR'
#  'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'WHH' 'WHD'
#  'WHA' 'VCH' 'VCD' 'VCA' 'Bb1X2' 'BbMxH' 'BbAvH' 'BbMxD' 'BbAvD' 'BbMxA'
#  'BbAvA' 'BbOU' 'BbMx>2.5' 'BbAv>2.5' 'BbMx<2.5' 'BbAv<2.5' 'BbAH' 'BbAHh'
#  'BbMxAHH' 'BbAvAHH' 'BbMxAHA' 'BbAvAHA']

# %%
#Drop Excess columns Train Data
train_epl_df = train_epl_df.drop(columns=['Div', 'Referee', 'HS', 'AS', 'HC', 'AC', 
                                        'BWA','BWH', 'BWD', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA',
                                        'Bb1X2', 'BbMxH', 'BbMxD', 'BbAvH','BbAvD', 'BbMxA', 'BbAvA',
                                         'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5',
                                         'BbAHh', 'BbAHh', 'BbAH', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
                                         ])
train_epl_df.head()
# Out:
#                HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HST  AST  \
# Date
# 2010-08-14       Wolves      Stoke     2     1   H     2     0   H    7    6
# 2010-08-14  Aston Villa   West Ham     3     0   H     2     0   H   11    2
# 2010-08-14    Blackburn    Everton     1     0   H     1     0   H    2   12
# 2010-08-14       Bolton     Fulham     0     0   D     0     0   D    9    7
# 2010-08-14      Chelsea  West Brom     6     0   H     2     0   H   13    4
#
#             ...  HY  AY  HR  AR  B365H  B365D  B365A   WHH   WHD    WHA
# Date        ...
# 2010-08-14  ...   0   2   0   0   2.30   3.25    3.2  2.30  3.20   3.20
# 2010-08-14  ...   1   2   0   0   2.00   3.30    4.0  1.91  3.25   4.33
# 2010-08-14  ...   2   1   0   0   2.88   3.25    2.5  2.88  3.20   2.50
# 2010-08-14  ...   1   3   0   0   2.20   3.30    3.4  2.15  3.20   3.50
# 2010-08-14  ...   1   0   0   0   1.17   7.00   17.0  1.17  6.50  19.00
#
# [5 rows x 22 columns]

# %%
#Check new columns for Train Data
train_epl_df.head()
print(train_epl_df.columns.values)
# Out:
# ['HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR' 'HST' 'AST'
#  'HF' 'AF' 'HY' 'AY' 'HR' 'AR' 'B365H' 'B365D' 'B365A' 'WHH' 'WHD' 'WHA']

# %%
#To check the columns for the test dataframe
test_epl_df.head()
print(test_epl_df.columns.values)
# Out:
# ['Div' 'Time' 'HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG'
#  'HTR' 'Referee' 'HS' 'AS' 'HST' 'AST' 'HF' 'AF' 'HC' 'AC' 'HY' 'AY' 'HR'
#  'AR' 'B365H' 'B365D' 'B365A' 'BWH' 'BWD' 'BWA' 'IWH' 'IWD' 'IWA' 'PSH'
#  'PSD' 'PSA' 'WHH' 'WHD' 'WHA' 'VCH' 'VCD' 'VCA' 'MaxH' 'MaxD' 'MaxA'
#  'AvgH' 'AvgD' 'AvgA' 'B365>2.5' 'B365<2.5' 'P>2.5' 'P<2.5' 'Max>2.5'
#  'Max<2.5' 'Avg>2.5' 'Avg<2.5' 'AHh' 'B365AHH' 'B365AHA' 'PAHH' 'PAHA'
#  'MaxAHH' 'MaxAHA' 'AvgAHH' 'AvgAHA' 'B365CH' 'B365CD' 'B365CA' 'BWCH'
#  'BWCD' 'BWCA' 'IWCH' 'IWCD' 'IWCA' 'PSCH' 'PSCD' 'PSCA' 'WHCH' 'WHCD'
#  'WHCA' 'VCCH' 'VCCD' 'VCCA' 'MaxCH' 'MaxCD' 'MaxCA' 'AvgCH' 'AvgCD'
#  'AvgCA' 'B365C>2.5' 'B365C<2.5' 'PC>2.5' 'PC<2.5' 'MaxC>2.5' 'MaxC<2.5'
#  'AvgC>2.5' 'AvgC<2.5' 'AHCh' 'B365CAHH' 'B365CAHA' 'PCAHH' 'PCAHA'
#  'MaxCAHH' 'MaxCAHA' 'AvgCAHH' 'AvgCAHA']

# %%
#Drop Excess columns half time (Test Data)
test_epl_df = test_epl_df.drop(columns=['Div', 'Time', 'Referee', 'HS', 'AS', 'HC', 'AC', 
                                        'Max>2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH','PAHA',
                                         'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'VCH', 'VCD', 'VCA', 
                                        'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5','B365<2.5','P>2.5','P<2.5','Max<2.5',
                                         'MaxAHH', 'MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH',
                                         'BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD',
                                         'WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD',
                                         'AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5',
                                        'AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA',
                                         'MaxCAHH','MaxCAHA','AvgCAHH','AvgCAHA'])
                                         
test_epl_df.head()
# Out:
#                   HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# Date
# 2019-08-09       Liverpool           Norwich     4     1   H     4     0   H
# 2019-08-10        West Ham          Man City     0     5   A     0     1   A
# 2019-08-10     Bournemouth  Sheffield United     1     1   D     0     0   D
# 2019-08-10         Burnley       Southampton     3     0   H     0     0   D
# 2019-08-10  Crystal Palace           Everton     0     0   D     0     0   D
#
#             HST  AST  ...  HY  AY  HR  AR  B365H  B365D  B365A    WHH  WHD  \
# Date                  ...
# 2019-08-09    7    5  ...   0   2   0   0   1.14  10.00  19.00   1.12  8.5
# 2019-08-10    3    9  ...   2   2   0   0  12.00   6.50   1.22  13.00  6.0
# 2019-08-10    3    3  ...   2   1   0   0   1.95   3.60   3.60   2.00  3.5
# 2019-08-10    4    3  ...   0   0   0   0   2.62   3.20   2.75   2.70  3.2
# 2019-08-10    2    3  ...   2   1   0   1   3.00   3.25   2.37   3.10  3.3
#
# ...

# %%
#Check new columns for Train Data
test_epl_df.head()
print(test_epl_df.columns.values)
# Out:
# ['HomeTeam' 'AwayTeam' 'FTHG' 'FTAG' 'FTR' 'HTHG' 'HTAG' 'HTR' 'HST' 'AST'
#  'HF' 'AF' 'HY' 'AY' 'HR' 'AR' 'B365H' 'B365D' 'B365A' 'WHH' 'WHD' 'WHA']

# %%
#Rename Columns 
train_epl_df = train_epl_df.rename(columns={
    "FTHG": "FT_HomeGoals", "FTAG": "FT_AwayGoals", "FTR": "FT_Result", "HTHG": "HT_HomeGoals", "HTAG": "HT_AwayGoals", "HTR": "HT_Result", "HST": "HomeShotsonTarget", "AST": "AwayShotsonTarget",
    "HF": "HomeFouls", "AF": "AwayFouls", "HY": "HomeYellowCards", "AY": "AwayYellowCards", "HR": "HomeRedCards", "AR": "AwayRedCards",
    "B365H" : "Bet365_HomeWin_Odds", "B365D": "Bet365_Draw_Odds", "B365A": "Bet365_AwayWin_Odds", "WHH": "WilliamHill_HomeWin_Odds", "WHD": "WilliamHill_HomeDraw_Odds", "WHA": "WilliamHill_AwayWin_Odds"})
train_epl_df.head()
# Out:
#                HomeTeam   AwayTeam  FT_HomeGoals  FT_AwayGoals FT_Result  \
# Date
# 2010-08-14       Wolves      Stoke             2             1         H
# 2010-08-14  Aston Villa   West Ham             3             0         H
# 2010-08-14    Blackburn    Everton             1             0         H
# 2010-08-14       Bolton     Fulham             0             0         D
# 2010-08-14      Chelsea  West Brom             6             0         H
#
#             HT_HomeGoals  HT_AwayGoals HT_Result  HomeShotsonTarget  \
# Date
# 2010-08-14             2             0         H                  7
# 2010-08-14             2             0         H                 11
# 2010-08-14             1             0         H                  2
# 2010-08-14             0             0         D                  9
# 2010-08-14             2             0         H                 13
#
#             AwayShotsonTarget  ...  HomeYellowCards  AwayYellowCards  \
# ...

# %%
#Rename Columns for test Data
test_epl_df = test_epl_df.rename(columns={
    "FTHG": "FT_HomeGoals", "FTAG": "FT_AwayGoals", "FTR": "FT_Result", "HTHG": "HT_HomeGoals", "HTAG": "HT_AwayGoals", "HTR": "HT_Result", "HST": "HomeShotsonTarget", "AST": "AwayShotsonTarget",
    "HF": "HomeFouls", "AF": "AwayFouls", "HY": "HomeYellowCards", "AY": "AwayYellowCards", "HR": "HomeRedCards", "AR": "AwayRedCards",
    "B365H" : "Bet365_HomeWin_Odds", "B365D": "Bet365_Draw_Odds", "B365A": "Bet365_AwayWin_Odds", "WHH": "WilliamHill_HomeWin_Odds", "WHD": "WilliamHill_HomeDraw_Odds", "WHA": "WilliamHill_AwayWin_Odds"})
test_epl_df.head()
# Out:
#                   HomeTeam          AwayTeam  FT_HomeGoals  FT_AwayGoals  \
# Date
# 2019-08-09       Liverpool           Norwich             4             1
# 2019-08-10        West Ham          Man City             0             5
# 2019-08-10     Bournemouth  Sheffield United             1             1
# 2019-08-10         Burnley       Southampton             3             0
# 2019-08-10  Crystal Palace           Everton             0             0
#
#            FT_Result  HT_HomeGoals  HT_AwayGoals HT_Result  HomeShotsonTarget  \
# Date
# 2019-08-09         H             4             0         H                  7
# 2019-08-10         A             0             1         A                  3
# 2019-08-10         D             0             0         D                  3
# 2019-08-10         H             0             0         D                  4
# 2019-08-10         D             0             0         D                  2
#
# ...

# %%
#Assign Value of 1/0 for Result Column based off of Function
def conditions(s):
    if (s['FT_Result'] == "H"):
        return 1
    else:
        return 0

# %%
#Assign funciton to each train/test dataframe
train_epl_df['Result'] = train_epl_df.apply(conditions, axis=1)
test_epl_df['Result'] = test_epl_df.apply(conditions, axis=1)

# %% [markdown]
# # Separate DataFrames based on Team; Home vs Away, between Train and Test Data

# %%
#Create DataFrames for Each Team by HomeTeam for Train Data
everton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Everton"]
astonvilla_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Aston Villa"]
leicester_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Leicester"]
arsenal_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Arsenal"]
liverpool_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Liverpool"]
tottenham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Tottenham"]
chelsea_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Chelsea"]
leeds_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Leeds"]
newcastle_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Newcastle"]
westham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "West Ham"]
southampton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Southampton"]
crystal_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Crystal Palace"]
wolves_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Wolves"]
mancity_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Man City"]
brighton_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Brighton"]
manutd_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Man United"]
westbrom_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "West Brom"]
burnley_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Burnley"]
sheffield_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Sheffield United"]
fulham_home_df = train_epl_df.loc[train_epl_df["HomeTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by HomeTeam for Test Data
everton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Everton"]
astonvilla_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Aston Villa"]
leicester_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Leicester"]
arsenal_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Arsenal"]
liverpool_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Liverpool"]
tottenham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Tottenham"]
chelsea_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Chelsea"]
leeds_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Leeds"]
newcastle_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Newcastle"]
westham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "West Ham"]
southampton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Southampton"]
crystal_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Crystal Palace"]
wolves_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Wolves"]
mancity_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Man City"]
brighton_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Brighton"]
manutd_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Man United"]
westbrom_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "West Brom"]
burnley_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Burnley"]
sheffield_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Sheffield United"]
fulham_home_t_df = test_epl_df.loc[test_epl_df["HomeTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by AwayTeam for Train Data
everton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Everton"]
astonvilla_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Aston Villa"]
leicester_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Leicester"]
arsenal_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Arsenal"]
liverpool_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Liverpool"]
tottenham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Tottenham"]
chelsea_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Chelsea"]
leeds_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Leeds"]
newcastle_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Newcastle"]
westham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "West Ham"]
southampton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Southampton"]
crystal_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Crystal Palace"]
wolves_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Wolves"]
mancity_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Man City"]
brighton_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Brighton"]
manutd_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Man United"]
westbrom_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "West Brom"]
burnley_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Burnley"]
sheffield_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Sheffield United"]
fulham_away_df = train_epl_df.loc[train_epl_df["AwayTeam"] == "Fulham"]

# %%
#Create DataFrames for Each Team by AwayTeam for Test Data
everton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Everton"]
astonvilla_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Aston Villa"]
leicester_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Leicester"]
arsenal_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Arsenal"]
liverpool_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Liverpool"]
tottenham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Tottenham"]
chelsea_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Chelsea"]
leeds_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Leeds"]
newcastle_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Newcastle"]
westham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "West Ham"]
southampton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Southampton"]
crystal_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Crystal Palace"]
wolves_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Wolves"]
mancity_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Man City"]
brighton_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Brighton"]
manutd_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Man United"]
westbrom_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "West Brom"]
burnley_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Burnley"]
sheffield_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Sheffield United"]
fulham_away_t_df = test_epl_df.loc[test_epl_df["AwayTeam"] == "Fulham"]

# %% [markdown]
# # Machine Learning Home/Team Away Analysis

# %% [markdown]
# ## Liverpool

# %%
#Shift Liverpool Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
liverpool_home_df = liverpool_home_df.shift(periods=-1)
liverpool_away_df = liverpool_away_df.shift(periods=-1)
liverpool_home_t_df = liverpool_home_t_df.shift(periods=-1)
liverpool_away_t_df = liverpool_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#liverpool_home_df.to_csv('Liverpool_Home.csv')
#liverpool_home_t_df.to_csv('Liverpool_Home_T.csv')
#liverpool_away_t_df.to_csv('Liverpool_Away_T.csv')
#liverpool_away_df.to_csv('Liverpool_Away.csv')

# %%
#Read in newly adjusted Liverpool CSVs
liverpool_home_p = Path("RESOURCES/TeamCSVs/Liverpool_Home.csv")
liverpool_home_p_t = Path("RESOURCES/TeamCSVs/Liverpool_Home_T.csv")
liverpool_away_p = Path("RESOURCES/TeamCSVs/Liverpool_Away.csv")
liverpool_away_p_t = Path("RESOURCES/TeamCSVs/Liverpool_Away_T.csv")
#Read in CSVs
liverpool_home = pd.read_csv(liverpool_home_p)
liverpool_home_t = pd.read_csv(liverpool_home_p_t)
liverpool_away = pd.read_csv(liverpool_away_p)
liverpool_away_t = pd.read_csv(liverpool_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
liverpool_home = liverpool_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_home_t = liverpool_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_away = liverpool_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
liverpool_away_t = liverpool_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
liverpool_home = liverpool_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_home_t = liverpool_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_away = liverpool_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
liverpool_away_t = liverpool_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
lph_y_train = liverpool_home['Result']
lph_X_train = liverpool_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
lph_y_test = liverpool_home_t['Result']
lph_X_test = liverpool_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
#Usage of Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(lph_X_train, lph_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(lph_X_train, lph_y_train)}")
print(f"Testing Data Score: {classifier.score(lph_X_test, lph_y_test)}")
# Out:
# Training Data Score: 0.8590604026845637
# Testing Data Score: 0.8823529411764706

# %%
predictions = classifier.predict(lph_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": lph_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam  AwayTeam
# 8/24/2019  Liverpool Arsenal                    1       1
# 9/14/2019  Liverpool Newcastle                  1       1
# 10/5/2019  Liverpool Leicester                  1       1
# 10/27/2019 Liverpool Tottenham                  1       1
# 11/10/2019 Liverpool Man City                   0       1
# 11/30/2019 Liverpool Brighton                   1       1
# 12/4/2019  Liverpool Everton                    1       1
# 12/14/2019 Liverpool Watford                    0       1
# 12/29/2019 Liverpool Wolves                     1       1
# 1/2/2020   Liverpool Sheffield United           1       1
# 1/19/2020  Liverpool Man United                 1       1
# 2/1/2020   Liverpool Southampton                1       1
# 2/24/2020  Liverpool West Ham                   1       1
# 3/7/2020   Liverpool Bournemouth                1       1
# 6/24/2020  Liverpool Crystal Palace             1       1
# ...

# %%
#Declare Dependent/Independent Variables
lpa_y_train = liverpool_away['Result']
lpa_X_train = liverpool_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
lpa_y_test = liverpool_away_t['Result']
lpa_X_test = liverpool_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(lpa_X_train, lpa_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(lpa_X_train, lpa_y_train)}")
print(f"Testing Data Score: {classifier.score(lpa_X_test, lpa_y_test)}")
# Out:
# Training Data Score: 0.8066666666666666
# Testing Data Score: 0.8823529411764706

# %%
predictions = classifier.predict(lpa_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": lpa_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/31/2019  Burnley          Liverpool           0       0
# 9/22/2019  Chelsea          Liverpool           1       0
# 9/28/2019  Sheffield United Liverpool           0       0
# 10/20/2019 Man United       Liverpool           0       0
# 11/2/2019  Aston Villa      Liverpool           0       0
# 11/23/2019 Crystal Palace   Liverpool           0       0
# 12/7/2019  Bournemouth      Liverpool           0       0
# 12/26/2019 Leicester        Liverpool           1       0
# 1/11/2020  Tottenham        Liverpool           0       0
# 1/23/2020  Wolves           Liverpool           0       0
# 1/29/2020  West Ham         Liverpool           1       0
# 2/15/2020  Norwich          Liverpool           1       1
# 2/29/2020  Watford          Liverpool           1       0
# 6/21/2020  Everton          Liverpool           1       1
# 7/2/2020   Man City         Liverpool           0       0
# ...

# %% [markdown]
# ## Wolves

# %%
#Shift Wolves Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
wolves_home_df = wolves_home_df.shift(periods=-1)
wolves_away_df = wolves_away_df.shift(periods=-1)
wolves_home_t_df = wolves_home_t_df.shift(periods=-1)
wolves_away_t_df = wolves_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#wolves_home_df.to_csv('Wolves_Home.csv')
#wolves_home_t_df.to_csv('Wolves_Home_T.csv')
#wolves_away_t_df.to_csv('Wolves_Away_T.csv')
#wolves_away_df.to_csv('Wolves_Away_.csv')

# %%
#Read in newly adjusted Liverpool CSVs
wolves_home_p = Path("RESOURCES/TeamCSVs/Wolves_Home.csv")
wolves_home_p_t = Path("RESOURCES/TeamCSVs/Wolves_Home_T.csv")
wolves_away_p = Path("RESOURCES/TeamCSVs/Wolves_Away_.csv")
wolves_away_p_t = Path("RESOURCES/TeamCSVs/Wolves_Away_T.csv")
#Read in CSVs
wolves_home = pd.read_csv(wolves_home_p)
wolves_home_t = pd.read_csv(wolves_home_p_t)
wolves_away = pd.read_csv(wolves_away_p)
wolves_away_t = pd.read_csv(wolves_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
wolves_home= wolves_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_home_t = wolves_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_away = wolves_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
wolves_away_t = wolves_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
wolves_home = wolves_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_home_t = wolves_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_away = wolves_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
wolves_away_t = wolves_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
wvh_y_train = wolves_home['Result']
wvh_X_train = wolves_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
wvh_y_test = wolves_home_t['Result']
wvh_X_test = wolves_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(wvh_X_train, wvh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(wvh_X_train, wvh_y_train)}")
print(f"Testing Data Score: {classifier.score(wvh_X_test, wvh_y_test)}")
# Out:
# Training Data Score: 0.8181818181818182
# Testing Data Score: 0.7647058823529411

# %%
predictions = classifier.predict(wvh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": wvh_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 8/25/2019  Wolves   Burnley                    0       0
# 9/14/2019  Wolves   Chelsea                    0       1
# 9/28/2019  Wolves   Watford                    0       0
# 10/19/2019 Wolves   Southampton                1       1
# 11/10/2019 Wolves   Aston Villa                0       0
# 12/1/2019  Wolves   Sheffield United           0       1
# 12/4/2019  Wolves   West Ham                   0       0
# 12/15/2019 Wolves   Tottenham                  0       1
# 12/27/2019 Wolves   Man City                   0       0
# 1/11/2020  Wolves   Newcastle                  0       0
# 1/23/2020  Wolves   Liverpool                  0       0
# 2/14/2020  Wolves   Leicester                  1       1
# 2/23/2020  Wolves   Norwich                    0       0
# 3/7/2020   Wolves   Brighton                   0       1
# 6/24/2020  Wolves   Bournemouth                0       0
# ...

# %%
#Declare Dependent/Independent Variables
wva_y_train = wolves_away['Result']
wva_X_train = wolves_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
wva_y_test = wolves_away_t['Result']
wva_X_test = wolves_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(wva_X_train, wva_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(wva_X_train, wva_y_train)}")
print(f"Testing Data Score: {classifier.score(wva_X_test, wva_y_test)}")
# Out:
# Training Data Score: 0.8545454545454545
# Testing Data Score: 0.7058823529411765

# %%
predictions = classifier.predict(wva_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": wva_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam         AwayTeam
# 9/1/2019   Everton          Wolves             1       0
# 9/22/2019  Crystal Palace   Wolves             0       0
# 10/6/2019  Man City         Wolves             1       0
# 10/27/2019 Newcastle        Wolves             0       0
# 11/2/2019  Arsenal          Wolves             0       0
# 11/23/2019 Bournemouth      Wolves             1       0
# 12/8/2019  Brighton         Wolves             0       0
# 12/21/2019 Norwich          Wolves             1       1
# 12/29/2019 Liverpool        Wolves             1       1
# 1/1/2020   Watford          Wolves             0       0
# 1/18/2020  Southampton      Wolves             0       0
# 2/1/2020   Man United       Wolves             0       0
# 3/1/2020   Tottenham        Wolves             0       0
# 6/20/2020  West Ham         Wolves             0       0
# 6/27/2020  Aston Villa      Wolves             1       1
# ...

# %% [markdown]
# ## Everton

# %%
#Shift Everton Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
everton_home_df = everton_home_df.shift(periods=-1)
everton_away_df = everton_away_df.shift(periods=-1)
everton_home_t_df = everton_home_t_df.shift(periods=-1)
everton_away_t_df = everton_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#everton_home_df.to_csv('Everton_Home.csv')
#everton_home_t_df.to_csv('Everton_Home_T.csv')
#everton_away_t_df.to_csv('Everton_Away_T.csv')
#everton_away_df.to_csv('Everton_Away_.csv')

# %%
#Read in newly adjusted Everton CSVs
everton_home_p = Path("RESOURCES/TeamCSVs/Everton_Home.csv")
everton_home_p_t = Path("RESOURCES/TeamCSVs/Everton_Home_T.csv")
everton_away_p = Path("RESOURCES/TeamCSVs/Everton_Away_.csv")
everton_away_p_t = Path("RESOURCES/TeamCSVs/Everton_Away_T.csv")
#Read in CSVs
everton_home = pd.read_csv(everton_home_p)
everton_home_t = pd.read_csv(everton_home_p_t)
everton_away = pd.read_csv(everton_away_p)
everton_away_t = pd.read_csv(everton_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
everton_home= everton_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
everton_home_t = everton_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
everton_away = everton_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
everton_away_t = everton_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
everton_home = everton_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
everton_home_t = everton_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
everton_away = everton_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
everton_away_t = everton_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
eth_y_train = everton_home['Result']
eth_X_train = everton_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
eth_y_test = everton_home_t['Result']
eth_X_test = everton_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(eth_X_train, eth_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(eth_X_train, eth_y_train)}")
print(f"Testing Data Score: {classifier.score(eth_X_test, eth_y_test)}")
# Out:
# Training Data Score: 0.78
# Testing Data Score: 0.8235294117647058

# %%
predictions = classifier.predict(eth_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": eth_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 9/1/2019   Everton  Wolves                     0       0
# 9/21/2019  Everton  Sheffield United           0       0
# 9/28/2019  Everton  Man City                   1       1
# 10/19/2019 Everton  West Ham                   0       0
# 11/3/2019  Everton  Tottenham                  0       0
# 11/23/2019 Everton  Norwich                    1       1
# 12/7/2019  Everton  Chelsea                    0       0
# 12/21/2019 Everton  Arsenal                    0       1
# 12/26/2019 Everton  Burnley                    0       1
# 1/11/2020  Everton  Brighton                   1       0
# 1/21/2020  Everton  Newcastle                  1       1
# 2/8/2020   Everton  Crystal Palace             0       0
# 3/1/2020   Everton  Man United                 0       0
# 6/21/2020  Everton  Liverpool                  1       1
# 7/1/2020   Everton  Leicester                  0       0
# ...

# %%
#Declare Dependent/Independent Variables
eta_y_train = everton_away['Result']
eta_X_train = everton_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
eta_y_test = everton_away_t['Result']
eta_X_test = everton_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(eta_X_train, eta_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(eta_X_train, eta_y_train)}")
print(f"Testing Data Score: {classifier.score(eta_X_test, eta_y_test)}")
# Out:
# Training Data Score: 0.7315436241610739
# Testing Data Score: 0.7058823529411765

# %%
predictions = classifier.predict(eta_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": eta_y_test})
results.head(20)
# Out:
#                                  Prediction  Actual
# Date       HomeTeam    AwayTeam
# 8/23/2019  Aston Villa Everton            1       1
# 9/15/2019  Bournemouth Everton            1       1
# 10/5/2019  Burnley     Everton            0       1
# 10/26/2019 Brighton    Everton            0       0
# 11/9/2019  Southampton Everton            0       1
# 12/1/2019  Leicester   Everton            0       1
# 12/4/2019  Liverpool   Everton            0       0
# 12/15/2019 Man United  Everton            0       0
# 12/28/2019 Newcastle   Everton            1       1
# 1/1/2020   Man City    Everton            0       0
# 1/18/2020  West Ham    Everton            0       0
# 2/1/2020   Watford     Everton            0       1
# 2/23/2020  Arsenal     Everton            1       1
# 3/8/2020   Chelsea     Everton            0       0
# 6/24/2020  Norwich     Everton            1       1
# 7/6/2020   Tottenham   Everton            1       1
# ...

# %% [markdown]
# ## Aston Villa

# %%
#Shift Aston Villa Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
astonvilla_home_df = astonvilla_home_df.shift(periods=-1)
astonvilla_away_df = astonvilla_away_df.shift(periods=-1)
astonvilla_home_t_df = astonvilla_home_t_df.shift(periods=-1)
astonvilla_away_t_df = astonvilla_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#astonvilla_home_df.to_csv('AstonVilla_Home.csv')
#astonvilla_home_t_df.to_csv('AstonVilla_Home_T.csv')
#astonvilla_away_t_df.to_csv('AstonVilla_Away_T.csv')
#astonvilla_away_df.to_csv('AstonVilla_Away_.csv')

# %%
#Read in newly adjusted Everton CSVs
astonvilla_home_p = Path("RESOURCES/TeamCSVs/AstonVilla_Home.csv")
astonvilla_home_p_t = Path("RESOURCES/TeamCSVs/AstonVilla_Home_T.csv")
astonvilla_away_p = Path("RESOURCES/TeamCSVs/AstonVilla_Away_.csv")
astonvilla_away_p_t = Path("RESOURCES/TeamCSVs/AstonVilla_Away_T.csv")
#Read in CSVs
astonvilla_home = pd.read_csv(astonvilla_home_p)
astonvilla_home_t = pd.read_csv(astonvilla_home_p_t)
astonvilla_away = pd.read_csv(astonvilla_away_p)
astonvilla_away_t = pd.read_csv(astonvilla_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
astonvilla_home= astonvilla_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
astonvilla_home_t = astonvilla_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
astonvilla_away = astonvilla_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
astonvilla_away_t = astonvilla_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
astonvilla_home = astonvilla_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
astonvilla_home_t = astonvilla_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
astonvilla_away = astonvilla_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
astonvilla_away_t = astonvilla_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
avh_y_train = astonvilla_home['Result']
avh_X_train = astonvilla_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
avh_y_test = astonvilla_home_t['Result']
avh_X_test = astonvilla_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(avh_X_train, avh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(avh_X_train, avh_y_train)}")
print(f"Testing Data Score: {classifier.score(avh_X_test, avh_y_test)}")
# Out:
# Training Data Score: 0.8387096774193549
# Testing Data Score: 0.7647058823529411

# %%
predictions = classifier.predict(avh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": avh_y_test})
results.head(20)
# Out:
#                                          Prediction  Actual
# Date       HomeTeam    AwayTeam
# 8/23/2019  Aston Villa Everton                    0       0
# 9/16/2019  Aston Villa West Ham                   0       0
# 9/28/2019  Aston Villa Burnley                    1       1
# 10/19/2019 Aston Villa Brighton                   0       0
# 11/2/2019  Aston Villa Liverpool                  0       1
# 11/25/2019 Aston Villa Newcastle                  0       0
# 12/8/2019  Aston Villa Leicester                  0       0
# 12/21/2019 Aston Villa Southampton                0       1
# 12/26/2019 Aston Villa Norwich                    0       0
# 1/12/2020  Aston Villa Man City                   0       1
# 1/21/2020  Aston Villa Watford                    0       0
# 2/16/2020  Aston Villa Tottenham                  0       0
# 6/17/2020  Aston Villa Sheffield United           0       0
# 6/21/2020  Aston Villa Chelsea                    0       0
# ...

# %%
#Declare Dependent/Independent Variables
ava_y_train = astonvilla_away['Result']
ava_X_train = astonvilla_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
ava_y_test = astonvilla_away_t['Result']
ava_X_test = astonvilla_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
classifier.fit(ava_X_train, ava_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(ava_X_train, ava_y_train)}")
print(f"Testing Data Score: {classifier.score(ava_X_test, ava_y_test)}")
# Out:
# Training Data Score: 0.7717391304347826
# Testing Data Score: 0.5882352941176471

# %%
predictions = classifier.predict(ava_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": ava_y_test})
results.head(20)
# Out:
#                                          Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/31/2019  Crystal Palace   Aston Villa           0       1
# 9/22/2019  Arsenal          Aston Villa           0       0
# 10/5/2019  Norwich          Aston Villa           1       1
# 10/26/2019 Man City         Aston Villa           0       1
# 11/10/2019 Wolves           Aston Villa           0       0
# 12/1/2019  Man United       Aston Villa           0       1
# 12/4/2019  Chelsea          Aston Villa           1       1
# 12/14/2019 Sheffield United Aston Villa           1       1
# 12/28/2019 Watford          Aston Villa           0       0
# 1/1/2020   Burnley          Aston Villa           0       0
# 1/18/2020  Brighton         Aston Villa           0       1
# 2/1/2020   Bournemouth      Aston Villa           1       1
# 2/22/2020  Southampton      Aston Villa           1       1
# 3/9/2020   Leicester        Aston Villa           0       0
# ...

# %% [markdown]
# ## Leicester

# %%
#Shift Leicester Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
leicester_home_df = leicester_home_df.shift(periods=-1)
leicester_away_df = leicester_away_df.shift(periods=-1)
leicester_home_t_df = leicester_home_t_df.shift(periods=-1)
leicester_away_t_df = leicester_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#leicester_home_df.to_csv('Leicester_Home.csv')
#leicester_home_t_df.to_csv('Leicester_Home_T.csv')
#leicester_away_t_df.to_csv('Leicester_Away_T.csv')
#leicester_away_df.to_csv('Leicester_Away_.csv')

# %%
#Read in newly adjusted Leicester CSVs
leicester_home_p = Path("RESOURCES/TeamCSVs/Leicester_Home.csv")
leicester_home_p_t = Path("RESOURCES/TeamCSVs/Leicester_Home_T.csv")
leicester_away_p = Path("RESOURCES/TeamCSVs/Leicester_Away_.csv")
leicester_away_p_t = Path("RESOURCES/TeamCSVs/Leicester_Away_T.csv")
#Read in CSVs
leicester_home = pd.read_csv(leicester_home_p)
leicester_home_t = pd.read_csv(leicester_home_p_t)
leicester_away = pd.read_csv(leicester_away_p)
leicester_away_t = pd.read_csv(leicester_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
leicester_home= leicester_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
leicester_home_t = leicester_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
leicester_away = leicester_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
leicester_away_t = leicester_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
leicester_home = leicester_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
leicester_home_t = leicester_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
leicester_away = leicester_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
leicester_away_t = leicester_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
leh_y_train = leicester_home['Result']
leh_X_train = leicester_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
leh_y_test = leicester_home_t['Result']
leh_X_test = leicester_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(leh_X_train, leh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(leh_X_train, leh_y_train)}")
print(f"Testing Data Score: {classifier.score(leh_X_test, leh_y_test)}")
# Out:
# Training Data Score: 0.8783783783783784
# Testing Data Score: 0.8823529411764706

# %%
predictions = classifier.predict(leh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": leh_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam  AwayTeam
# 8/31/2019  Leicester Bournemouth                0       1
# 9/21/2019  Leicester Tottenham                  1       1
# 9/29/2019  Leicester Newcastle                  1       1
# 10/19/2019 Leicester Burnley                    1       1
# 11/9/2019  Leicester Arsenal                    1       1
# 12/1/2019  Leicester Everton                    0       1
# 12/4/2019  Leicester Watford                    0       0
# 12/14/2019 Leicester Norwich                    0       0
# 12/26/2019 Leicester Liverpool                  0       0
# 1/11/2020  Leicester Southampton                1       1
# 1/22/2020  Leicester West Ham                   0       0
# 2/1/2020   Leicester Chelsea                    0       0
# 2/22/2020  Leicester Man City                   1       1
# 3/9/2020   Leicester Aston Villa                0       0
# 6/23/2020  Leicester Brighton                   1       1
# ...

# %%
#Declare Dependent/Independent Variables
lea_y_train = leicester_away['Result']
lea_X_train = leicester_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
lea_y_test = leicester_away_t['Result']
lea_X_test = leicester_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(lea_X_train, lea_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(lea_X_train, lea_y_train)}")
print(f"Testing Data Score: {classifier.score(lea_X_test, lea_y_test)}")
# Out:
# Training Data Score: 0.7432432432432432
# Testing Data Score: 0.7058823529411765

# %%
predictions = classifier.predict(lea_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": lea_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/24/2019  Sheffield United Leicester           1       1
# 9/14/2019  Man United       Leicester           1       1
# 10/5/2019  Liverpool        Leicester           0       0
# 10/25/2019 Southampton      Leicester           0       0
# 11/3/2019  Crystal Palace   Leicester           0       0
# 11/23/2019 Brighton         Leicester           0       0
# 12/8/2019  Aston Villa      Leicester           0       1
# 12/21/2019 Man City         Leicester           1       0
# 12/28/2019 West Ham         Leicester           0       0
# 1/1/2020   Newcastle        Leicester           1       1
# 1/19/2020  Burnley          Leicester           1       0
# 2/14/2020  Wolves           Leicester           1       1
# 2/28/2020  Norwich          Leicester           0       0
# 6/20/2020  Watford          Leicester           0       1
# 7/1/2020   Everton          Leicester           0       0
# ...

# %% [markdown]
# ## Arsenal

# %%
#Shift Arsenal Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
arsenal_home_df = arsenal_home_df.shift(periods=-1)
arsenal_away_df = arsenal_away_df.shift(periods=-1)
arsenal_home_t_df = arsenal_home_t_df.shift(periods=-1)
arsenal_away_t_df = arsenal_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#arsenal_home_df.to_csv('Arsenal_Home.csv')
#arsenal_home_t_df.to_csv('Arsenal_Home_T.csv')
#arsenal_away_t_df.to_csv('Arsenal_Away_T.csv')
#arsenal_away_df.to_csv('Arsenal_Away_.csv')

# %%
#Read in newly adjusted Leicester CSVs
arsenal_home_p = Path("RESOURCES/TeamCSVs/Arsenal_Home.csv")
arsenal_home_p_t = Path("RESOURCES/TeamCSVs/Arsenal_Home_T.csv")
arsenal_away_p = Path("RESOURCES/TeamCSVs/Arsenal_Away_.csv")
arsenal_away_p_t = Path("RESOURCES/TeamCSVs/Arsenal_Away_T.csv")
#Read in CSVs
arsenal_home = pd.read_csv(arsenal_home_p)
arsenal_home_t = pd.read_csv(arsenal_home_p_t)
arsenal_away = pd.read_csv(arsenal_away_p)
arsenal_away_t = pd.read_csv(arsenal_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
arsenal_home= arsenal_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
arsenal_home_t = arsenal_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
arsenal_away = arsenal_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
arsenal_away_t = arsenal_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
arsenal_home = arsenal_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
arsenal_home_t = arsenal_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
arsenal_away = arsenal_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
arsenal_away_t = arsenal_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
arh_y_train = arsenal_home['Result']
arh_X_train = arsenal_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
arh_y_test = arsenal_home_t['Result']
arh_X_test = arsenal_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(arh_X_train, arh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(arh_X_train, arh_y_train)}")
print(f"Testing Data Score: {classifier.score(arh_X_test, arh_y_test)}")
# Out:
# Training Data Score: 0.7986577181208053
# Testing Data Score: 0.6470588235294118

# %%
predictions = classifier.predict(arh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": arh_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 9/1/2019   Arsenal  Tottenham                  1       1
# 9/22/2019  Arsenal  Aston Villa                0       1
# 10/6/2019  Arsenal  Bournemouth                1       0
# 10/27/2019 Arsenal  Crystal Palace             1       0
# 11/2/2019  Arsenal  Wolves                     1       0
# 11/23/2019 Arsenal  Southampton                0       0
# 12/5/2019  Arsenal  Brighton                   0       0
# 12/15/2019 Arsenal  Man City                   1       0
# 12/29/2019 Arsenal  Chelsea                    1       1
# 1/1/2020   Arsenal  Man United                 1       0
# 1/18/2020  Arsenal  Sheffield United           1       1
# 2/16/2020  Arsenal  Newcastle                  1       1
# 2/23/2020  Arsenal  Everton                    1       1
# 3/7/2020   Arsenal  West Ham                   1       1
# 7/1/2020   Arsenal  Norwich                    0       0
# ...

# %%
#Declare Dependent/Independent Variables
ara_y_train = arsenal_away['Result']
ara_X_train = arsenal_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
ara_y_test = arsenal_away_t['Result']
ara_X_test = arsenal_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(ara_X_train, ara_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(ara_X_train, ara_y_train)}")
print(f"Testing Data Score: {classifier.score(ara_X_test, ara_y_test)}")
# Out:
# Training Data Score: 0.74
# Testing Data Score: 0.7058823529411765

# %%
predictions = classifier.predict(ara_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": ara_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/24/2019  Liverpool        Arsenal            0       0
# 9/15/2019  Watford          Arsenal            1       0
# 9/30/2019  Man United       Arsenal            1       1
# 10/21/2019 Sheffield United Arsenal            1       1
# 11/9/2019  Leicester        Arsenal            0       0
# 12/1/2019  Norwich          Arsenal            0       0
# 12/9/2019  West Ham         Arsenal            1       0
# 12/21/2019 Everton          Arsenal            1       0
# 12/26/2019 Bournemouth      Arsenal            1       0
# 1/11/2020  Crystal Palace   Arsenal            0       0
# 1/21/2020  Chelsea          Arsenal            1       0
# 2/2/2020   Burnley          Arsenal            1       1
# 6/17/2020  Man City         Arsenal            1       1
# 6/20/2020  Brighton         Arsenal            0       0
# 6/25/2020  Southampton      Arsenal            0       0
# ...

# %% [markdown]
# ## Tottenham

# %%
#Shift Tottenham Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
tottenham_home_df = tottenham_home_df.shift(periods=-1)
tottenham_away_df = tottenham_away_df.shift(periods=-1)
tottenham_home_t_df =tottenham_home_t_df.shift(periods=-1)
tottenham_away_t_df = tottenham_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#tottenham_home_df.to_csv('Tottenham_Home.csv')
#tottenham_home_t_df.to_csv('Tottenham_Home_T.csv')
#tottenham_away_t_df.to_csv('Tottenham_Away_T.csv')
#tottenham_away_df.to_csv('Tottenham_Away_.csv')

# %%
#Read in newly adjusted Tottenham CSVs
tottenham_home_p = Path("RESOURCES/TeamCSVs/Tottenham_Home.csv")
tottenham_home_p_t = Path("RESOURCES/TeamCSVs/Tottenham_Home_T.csv")
tottenham_away_p = Path("RESOURCES/TeamCSVs/Tottenham_Away_.csv")
tottenham_away_p_t = Path("RESOURCES/TeamCSVs/Tottenham_Away_T.csv")
#Read in CSVs
tottenham_home = pd.read_csv(tottenham_home_p)
tottenham_home_t = pd.read_csv(tottenham_home_p_t)
tottenham_away = pd.read_csv(tottenham_away_p)
tottenham_away_t = pd.read_csv(tottenham_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
tottenham_home= tottenham_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
tottenham_home_t = tottenham_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
tottenham_away = tottenham_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
tottenham_away_t = tottenham_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
tottenham_home = tottenham_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
tottenham_home_t = tottenham_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
tottenham_away = tottenham_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
tottenham_away_t = tottenham_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
toh_y_train = tottenham_home['Result']
toh_X_train = tottenham_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
toh_y_test = tottenham_home_t['Result']
toh_X_test = tottenham_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(toh_X_train, toh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(toh_X_train, toh_y_train)}")
print(f"Testing Data Score: {classifier.score(toh_X_test, toh_y_test)}")
# Out:
# Training Data Score: 0.8322147651006712
# Testing Data Score: 0.8823529411764706

# %%
predictions = classifier.predict(toh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": toh_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam  AwayTeam
# 8/25/2019  Tottenham Newcastle                  1       1
# 9/14/2019  Tottenham Crystal Palace             1       1
# 9/28/2019  Tottenham Southampton                0       0
# 10/19/2019 Tottenham Watford                    0       0
# 11/9/2019  Tottenham Sheffield United           1       1
# 11/30/2019 Tottenham Bournemouth                1       1
# 12/7/2019  Tottenham Burnley                    0       0
# 12/22/2019 Tottenham Chelsea                    1       1
# 12/26/2019 Tottenham Brighton                   0       0
# 1/11/2020  Tottenham Liverpool                  1       1
# 1/22/2020  Tottenham Norwich                    1       1
# 2/2/2020   Tottenham Man City                   1       0
# 3/1/2020   Tottenham Wolves                     0       0
# 6/19/2020  Tottenham Man United                 1       1
# 6/23/2020  Tottenham West Ham                   0       1
# ...

# %%
#Declare Dependent/Independent Variables
toa_y_train = tottenham_away['Result']
toa_X_train = tottenham_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
toa_y_test = tottenham_away_t['Result']
toa_X_test = tottenham_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(toa_X_train, toa_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(toa_X_train, toa_y_train)}")
print(f"Testing Data Score: {classifier.score(toa_X_test, toa_y_test)}")
# Out:
# Training Data Score: 0.7986577181208053
# Testing Data Score: 0.5294117647058824

# %%
predictions = classifier.predict(toa_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": toa_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam         AwayTeam
# 9/1/2019   Arsenal          Tottenham           0       1
# 9/21/2019  Leicester        Tottenham           1       1
# 10/5/2019  Brighton         Tottenham           0       1
# 10/27/2019 Liverpool        Tottenham           1       0
# 11/3/2019  Everton          Tottenham           0       0
# 11/23/2019 West Ham         Tottenham           0       1
# 12/4/2019  Man United       Tottenham           0       0
# 12/15/2019 Wolves           Tottenham           0       0
# 12/28/2019 Norwich          Tottenham           1       1
# 1/1/2020   Southampton      Tottenham           1       0
# 1/18/2020  Watford          Tottenham           0       0
# 2/16/2020  Aston Villa      Tottenham           0       1
# 2/22/2020  Chelsea          Tottenham           0       0
# 3/7/2020   Burnley          Tottenham           0       1
# 7/2/2020   Sheffield United Tottenham           1       0
# ...

# %% [markdown]
# ## Chelsea

# %%
#Shift Chelsea Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
chelsea_home_df = chelsea_home_df.shift(periods=-1)
chelsea_away_df = chelsea_away_df.shift(periods=-1)
chelsea_home_t_df =chelsea_home_t_df.shift(periods=-1)
chelsea_away_t_df = chelsea_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#chelsea_home_df.to_csv('Chelsea_Home.csv')
#chelsea_home_t_df.to_csv('Chelsea_Home_T.csv')
#chelsea_away_t_df.to_csv('Chelsea_Away_T.csv')
#chelsea_away_df.to_csv('Chelsea_Away_.csv')

# %%
#Read in newly adjusted Tottenham CSVs
chelsea_home_p = Path("RESOURCES/TeamCSVs/Chelsea_Home.csv")
chelsea_home_p_t = Path("RESOURCES/TeamCSVs/Chelsea_Home_T.csv")
chelsea_away_p = Path("RESOURCES/TeamCSVs/Chelsea_Away_.csv")
chelsea_away_p_t = Path("RESOURCES/TeamCSVs/Chelsea_Away_T.csv")
#Read in CSVs
chelsea_home = pd.read_csv(chelsea_home_p)
chelsea_home_t = pd.read_csv(chelsea_home_p_t)
chelsea_away = pd.read_csv(chelsea_away_p)
chelsea_away_t = pd.read_csv(chelsea_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
chelsea_home= chelsea_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
chelsea_home_t =chelsea_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
chelsea_away = chelsea_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
chelsea_away_t = chelsea_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Declare Independent and Dependent Variables
chh_y_train = chelsea_home['Result']
chh_X_train = chelsea_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
chh_y_test = chelsea_home_t['Result']
chh_X_test = chelsea_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(chh_X_train, chh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(chh_X_train, chh_y_train)}")
print(f"Testing Data Score: {classifier.score(chh_X_test, chh_y_test)}")
# Out:
# Training Data Score: 0.8456375838926175
# Testing Data Score: 0.7647058823529411

# %%
predictions = classifier.predict(chh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": chh_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 8/31/2019  Chelsea  Sheffield United           0       0
# 9/22/2019  Chelsea  Liverpool                  0       1
# 9/28/2019  Chelsea  Brighton                   0       1
# 10/19/2019 Chelsea  Newcastle                  1       1
# 11/9/2019  Chelsea  Crystal Palace             0       0
# 11/30/2019 Chelsea  West Ham                   1       1
# 12/4/2019  Chelsea  Aston Villa                0       0
# 12/14/2019 Chelsea  Bournemouth                0       0
# 12/26/2019 Chelsea  Southampton                1       1
# 1/11/2020  Chelsea  Burnley                    1       0
# 1/21/2020  Chelsea  Arsenal                    0       0
# 2/17/2020  Chelsea  Man United                 1       1
# 2/22/2020  Chelsea  Tottenham                  1       1
# 3/8/2020   Chelsea  Everton                    1       1
# 6/25/2020  Chelsea  Man City                   1       1
# ...

# %%
#Declare Dependent/Independent Variables
cha_y_train = chelsea_away['Result']
cha_X_train = chelsea_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
cha_y_test = chelsea_away_t['Result']
cha_X_test = chelsea_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(cha_X_train, cha_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(cha_X_train, cha_y_train)}")
print(f"Testing Data Score: {classifier.score(cha_X_test, cha_y_test)}")
# Out:
# Training Data Score: 0.82
# Testing Data Score: 0.7647058823529411

# %%
predictions = classifier.predict(cha_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": cha_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/24/2019  Norwich          Chelsea            0       0
# 9/14/2019  Wolves           Chelsea            0       0
# 10/6/2019  Southampton      Chelsea            0       0
# 10/26/2019 Burnley          Chelsea            0       0
# 11/2/2019  Watford          Chelsea            0       1
# 11/23/2019 Man City         Chelsea            0       1
# 12/7/2019  Everton          Chelsea            0       0
# 12/22/2019 Tottenham        Chelsea            0       0
# 12/29/2019 Arsenal          Chelsea            0       0
# 1/1/2020   Brighton         Chelsea            1       1
# 1/18/2020  Newcastle        Chelsea            0       0
# 2/1/2020   Leicester        Chelsea            0       0
# 2/29/2020  Bournemouth      Chelsea            0       0
# 6/21/2020  Aston Villa      Chelsea            0       1
# 7/1/2020   West Ham         Chelsea            0       0
# ...

# %% [markdown]
# ## Southampton

# %%
#Shift Southampton Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well.
southampton_home_df = southampton_home_df.shift(periods=-1)
southampton_away_df = southampton_away_df.shift(periods=-1)
southampton_home_t_df = southampton_home_t_df.shift(periods=-1)
southampton_away_t_df = southampton_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV.
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#southampton_home_df.to_csv('southampton_Home.csv')
#southampton_home_t_df.to_csv('southampton_Home_T.csv')
#southampton_away_t_df.to_csv('southampton_Away_T.csv')
#southampton_away_df.to_csv('southampton_Away_.csv')

# %%
#Read in newly adjusted Leicester CSVs
southampton_home_p = Path("RESOURCES/TeamCSVs/southampton_Home.csv")
southampton_home_p_t = Path("RESOURCES/TeamCSVs/southampton_Home_T.csv")
southampton_away_p = Path("RESOURCES/TeamCSVs/southampton_Away_.csv")
southampton_away_p_t = Path("RESOURCES/TeamCSVs/southampton_Away_T.csv")
#Read in CSVs
southampton_home = pd.read_csv(southampton_home_p)
southampton_home_t = pd.read_csv(southampton_home_p_t)
southampton_away = pd.read_csv(southampton_away_p)
southampton_away_t = pd.read_csv(southampton_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
southampton_home= southampton_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
southampton_home_t = southampton_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
southampton_away = southampton_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
southampton_away_t = southampton_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
southampton_home = southampton_home.drop(['FT_Result', 'HT_Result'], axis = 1)
southampton_home_t = southampton_home_t.drop(['FT_Result', 'HT_Result'], axis = 1)
southampton_away = southampton_away.drop(['FT_Result', 'HT_Result'], axis = 1)
southampton_away_t = southampton_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
soh_y_train = southampton_home['Result']
soh_X_train = southampton_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
soh_y_test = southampton_home_t['Result']
soh_X_test = southampton_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(soh_X_train, soh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(soh_X_train, soh_y_train)}")
print(f"Testing Data Score: {classifier.score(soh_X_test, soh_y_test)}")
# Out:
# Training Data Score: 0.8660714285714286
# Testing Data Score: 0.7647058823529411

# %%
predictions = classifier.predict(soh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": soh_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam    AwayTeam
# 8/31/2019  Southampton Man United               0       0
# 9/20/2019  Southampton Bournemouth              0       0
# 10/6/2019  Southampton Chelsea                  0       0
# 10/25/2019 Southampton Leicester                0       0
# 11/9/2019  Southampton Everton                  0       1
# 11/30/2019 Southampton Watford                  1       1
# 12/4/2019  Southampton Norwich                  0       0
# 12/14/2019 Southampton West Ham                 0       0
# 12/28/2019 Southampton Crystal Palace           0       1
# 1/1/2020   Southampton Tottenham                1       0
# 1/18/2020  Southampton Wolves                   0       0
# 2/15/2020  Southampton Burnley                  1       1
# 2/22/2020  Southampton Aston Villa              0       0
# 3/7/2020   Southampton Newcastle                0       0
# 6/25/2020  Southampton Arsenal                  0       1
# ...

# %%
#Declare Independent and Dependent Variables
soa_y_train = southampton_away['Result']
soa_X_train = southampton_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
soa_y_test = southampton_away_t['Result']
soa_X_test = southampton_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(soa_X_train, soa_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(soa_X_train, soa_y_train)}")
print(f"Testing Data Score: {classifier.score(soa_X_test, soa_y_test)}")
# Out:
# Training Data Score: 0.6576576576576577
# Testing Data Score: 0.8235294117647058

# %%
predictions = classifier.predict(soa_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": soa_y_test})
results.head(20)
# Out:
#                                          Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/24/2019  Brighton         Southampton           0       0
# 9/14/2019  Sheffield United Southampton           0       1
# 9/28/2019  Tottenham        Southampton           0       0
# 10/19/2019 Wolves           Southampton           0       1
# 11/2/2019  Man City         Southampton           0       0
# 11/23/2019 Arsenal          Southampton           0       1
# 12/8/2019  Newcastle        Southampton           0       0
# 12/21/2019 Aston Villa      Southampton           0       0
# 12/26/2019 Chelsea          Southampton           0       0
# 1/11/2020  Leicester        Southampton           0       0
# 1/21/2020  Crystal Palace   Southampton           1       1
# 2/1/2020   Liverpool        Southampton           1       1
# 2/29/2020  West Ham         Southampton           0       0
# 6/19/2020  Norwich          Southampton           0       0
# ...

# %% [markdown]
# ## Newcastle

# %%
#Shift Newcastle Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
newcastle_home_df = newcastle_home_df.shift(periods=-1)
newcastle_away_df = newcastle_away_df.shift(periods=-1)
newcastle_home_t_df = newcastle_home_t_df.shift(periods=-1)
newcastle_away_t_df = newcastle_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing NewCastle, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#newcastle_home_df.to_csv('Newcastle_Home.csv')
#newcastle_home_t_df.to_csv('Newcastle_Home_T.csv')
#newcastle_away_t_df.to_csv('Newcastle_Away_T.csv')
#newcastle_away_df.to_csv('Newcastle_Away_.csv')

# %%
#Read in newly adjusted Newcastle CSVs
newcastle_home_p = Path("RESOURCES/TeamCSVs/Newcastle_Home.csv")
newcastle_home_p_t = Path("RESOURCES/TeamCSVs/Newcastle_Home_T.csv")
newcastle_away_p = Path("RESOURCES/TeamCSVs/Newcastle_Away_.csv")
newcastle_away_p_t = Path("RESOURCES/TeamCSVs/Newcastle_Away_T.csv")
#Read in CSVs
newcastle_home = pd.read_csv(newcastle_home_p)
newcastle_home_t = pd.read_csv(newcastle_home_p_t)
newcastle_away = pd.read_csv(newcastle_away_p)
newcastle_away_t = pd.read_csv(newcastle_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
newcastle_home= newcastle_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
newcastle_home_t = newcastle_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
newcastle_away = newcastle_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
newcastle_away_t = newcastle_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
newcastle_home = newcastle_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
newcastle_home_t = newcastle_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
newcastle_away = newcastle_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
newcastle_away_t = newcastle_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
neh_y_train = newcastle_home['Result']
neh_X_train = newcastle_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
neh_y_test = newcastle_home_t['Result']
neh_X_test = newcastle_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(neh_X_train, neh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(neh_X_train, neh_y_train)}")
print(f"Testing Data Score: {classifier.score(neh_X_test, neh_y_test)}")
# Out:
# Training Data Score: 0.8015267175572519
# Testing Data Score: 0.7058823529411765

# %%
predictions = classifier.predict(neh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": neh_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam  AwayTeam
# 8/31/2019  Newcastle Watford                    0       0
# 9/21/2019  Newcastle Brighton                   0       1
# 10/6/2019  Newcastle Man United                 0       0
# 10/27/2019 Newcastle Wolves                     1       1
# 11/9/2019  Newcastle Bournemouth                1       0
# 11/30/2019 Newcastle Man City                   1       1
# 12/8/2019  Newcastle Southampton                0       1
# 12/21/2019 Newcastle Crystal Palace             0       0
# 12/28/2019 Newcastle Everton                    0       0
# 1/1/2020   Newcastle Leicester                  0       1
# 1/18/2020  Newcastle Chelsea                    0       0
# 2/1/2020   Newcastle Norwich                    0       0
# 2/29/2020  Newcastle Burnley                    1       1
# 6/21/2020  Newcastle Sheffield United           0       0
# 6/24/2020  Newcastle Aston Villa                1       0
# ...

# %%
#Declare Dependent/Independent Variables
nea_y_train = newcastle_away['Result']
nea_X_train = newcastle_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
nea_y_test = newcastle_away_t['Result']
nea_X_test = newcastle_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(nea_X_train, nea_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
predictions = classifier.predict(nea_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": nea_y_test})
results.head(20)
# Out:
#                                        Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/25/2019  Tottenham        Newcastle           1       1
# 9/14/2019  Liverpool        Newcastle           0       1
# 9/29/2019  Leicester        Newcastle           1       1
# 10/19/2019 Chelsea          Newcastle           0       0
# 11/2/2019  West Ham         Newcastle           1       1
# 11/25/2019 Aston Villa      Newcastle           0       0
# 12/5/2019  Sheffield United Newcastle           1       1
# 12/14/2019 Burnley          Newcastle           0       1
# 12/26/2019 Man United       Newcastle           0       0
# 1/11/2020  Wolves           Newcastle           0       0
# 1/21/2020  Everton          Newcastle           1       1
# 2/16/2020  Arsenal          Newcastle           0       1
# 2/22/2020  Crystal Palace   Newcastle           0       0
# 3/7/2020   Southampton      Newcastle           0       0
# 7/1/2020   Bournemouth      Newcastle           1       1
# ...

# %% [markdown]
# ## Westham

# %%
#Shift Westham Data by 1 to prevent LookAhead Bias. Has to be -1 since data is from latest (2018) to earliest (2011); have to use .tail() as well. 
westham_home_df = westham_home_df.shift(periods=-1)
westham_away_df = westham_away_df.shift(periods=-1)
westham_home_t_df = westham_home_t_df.shift(periods=-1)
westham_away_t_df = westham_away_t_df.shift(periods=-1)

# %%
#Export to Excel, to add a cell in prematch stats (HomeTeam/AwayTeam and Book Maker odds). Deleted top and bottom row from CSV. 
#Now, For Example, the 5/1/2011 (Game2), has LiverPool versing Westham, but has the results of the Liverpool/Tottenham (Game1), to use as features for Game2.
#Commenting out CSVs to prevent multiple saved files.

#westham_home_df.to_csv('Westham_Home.csv')
#westham_home_t_df.to_csv('Westham_Home_T.csv')
#westham_away_t_df.to_csv('Westham_Away_T.csv')
#westham_away_df.to_csv('Westham_Away_.csv')

# %%
#Read in newly adjusted Westham CSVs
westham_home_p = Path("RESOURCES/TeamCSVs/Westham_Home.csv")
westham_home_p_t = Path("RESOURCES/TeamCSVs/Westham_Home_T.csv")
westham_away_p = Path("RESOURCES/TeamCSVs/Westham_Away_.csv")
westham_away_p_t = Path("RESOURCES/TeamCSVs/Westham_Away_T.csv")
#Read in CSVs
westham_home = pd.read_csv(westham_home_p)
westham_home_t = pd.read_csv(westham_home_p_t)
westham_away = pd.read_csv(westham_away_p)
westham_away_t = pd.read_csv(westham_away_p_t)

# %%
#Set Index of Date/HomeTeam/AwayTeam for organization
westham_home= westham_home.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
westham_home_t = westham_home_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
westham_away = westham_away.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)
westham_away_t = westham_away_t.set_index(['Date', 'HomeTeam', 'AwayTeam'], drop = True)

# %%
#Drop Columns that use Floats from DataSets
westham_home = westham_home.drop(['FT_Result', 'HT_Result'], axis = 1) 
westham_home_t = westham_home_t.drop(['FT_Result', 'HT_Result'], axis = 1) 
westham_away = westham_away.drop(['FT_Result', 'HT_Result'], axis = 1) 
westham_away_t = westham_away_t.drop(['FT_Result', 'HT_Result'], axis = 1)

# %%
#Declare Independent and Dependent Variables
weh_y_train = westham_home['Result']
weh_X_train = westham_home[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]
weh_y_test = westham_home_t['Result']
weh_X_test = westham_home_t[['FT_HomeGoals', 'HT_HomeGoals','HomeShotsonTarget', 'HomeFouls','HomeYellowCards', 'HomeRedCards','Bet365_HomeWin_Odds', 'WilliamHill_HomeWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(weh_X_train, weh_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
print(f"Training Data Score: {classifier.score(weh_X_train, weh_y_train)}")
print(f"Testing Data Score: {classifier.score(weh_X_test, weh_y_test)}")
# Out:
# Training Data Score: 0.7692307692307693
# Testing Data Score: 0.8235294117647058

# %%
predictions = classifier.predict(weh_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": weh_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam AwayTeam
# 8/31/2019  West Ham Norwich                    1       1
# 9/22/2019  West Ham Man United                 0       0
# 10/5/2019  West Ham Crystal Palace             0       0
# 10/26/2019 West Ham Sheffield United           1       0
# 11/2/2019  West Ham Newcastle                  1       0
# 11/23/2019 West Ham Tottenham                  0       0
# 12/9/2019  West Ham Arsenal                    0       0
# 12/28/2019 West Ham Leicester                  1       1
# 1/1/2020   West Ham Bournemouth                0       0
# 1/18/2020  West Ham Everton                    0       0
# 1/29/2020  West Ham Liverpool                  1       0
# 2/1/2020   West Ham Brighton                   1       1
# 2/29/2020  West Ham Southampton                0       0
# 6/20/2020  West Ham Wolves                     1       1
# 7/1/2020   West Ham Chelsea                    0       0
# ...

# %%
#Declare Dependent/Independent Variables
wea_y_train = westham_away['Result']
wea_X_train = westham_away[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]
wea_y_test = westham_away_t['Result']
wea_X_test = westham_away_t[['FT_AwayGoals', 'HT_AwayGoals','AwayShotsonTarget', 'AwayFouls','AwayYellowCards', 'AwayRedCards','Bet365_AwayWin_Odds', 'WilliamHill_AwayWin_Odds']]

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)
classifier
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
classifier.fit(wea_X_train, wea_y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
predictions = classifier.predict(wea_X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": wea_y_test})
results.head(20)
# Out:
#                                       Prediction  Actual
# Date       HomeTeam         AwayTeam
# 8/24/2019  Watford          West Ham           1       0
# 9/16/2019  Aston Villa      West Ham           0       0
# 9/28/2019  Bournemouth      West Ham           1       1
# 10/19/2019 Everton          West Ham           1       1
# 11/9/2019  Burnley          West Ham           0       0
# 11/30/2019 Chelsea          West Ham           1       1
# 12/4/2019  Wolves           West Ham           0       0
# 12/14/2019 Southampton      West Ham           0       1
# 12/26/2019 Crystal Palace   West Ham           1       1
# 1/10/2020  Sheffield United West Ham           0       1
# 1/22/2020  Leicester        West Ham           1       1
# 2/19/2020  Man City         West Ham           0       1
# 2/24/2020  Liverpool        West Ham           1       1
# 3/7/2020   Arsenal          West Ham           1       1
# 6/23/2020  Tottenham        West Ham           0       0
# ...
